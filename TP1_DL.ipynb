# %% [markdown]
# <div style="text-align:center; border-bottom: 2px solid #FF7E7E;">
#     <h1><font color='#FF0000'>TP 1 : DEEP LEARNING</font></h1>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">réalisé par :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Assklou Meriem</li>
# <li>El Hariri Omar</li>
# <li>Louardi Ikram</li>
# <li>Mesrar Hamza </li>
# <li>Nabouzi Yasser</li>
# </ul>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">Encadre par  :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Prof. Khalfi Hamza</li>
# </ul>
# </div>
# </div>

# %% [markdown]
# <div style="padding-top:1px;padding-left:20px;">

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 1 – Formalisation mathematique</font></h2>
# </div>

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. A quoi servent les ensembles d’apprentissage, de validation et de test ?
#
# </font>

# %% [markdown]
# - Les ensembles d'apprentissage, de validation et de test sont utilisés respectivement pour entraîner un modèle, ajuster les hyperparamètres, et évaluer sa performance finale. Ils contribuent à éviter le surajustement et fournissent une évaluation impartiale sur des données non vues pendant l'entraînement.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. Quelle est l’influence du nombre $N$ d’exemples ?
#
# </font>

# %% [markdown]
# - Le nombre $ N $ d'exemples dans l'ensemble d'apprentissage peut influencer la performance du modèle. Un nombre insuffisant peut entraîner un surajustement, tandis qu'un grand nombre peut aider le modèle à généraliser mieux aux nouvelles données,

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 3. Pourquoi est-il important d’ajouter des fonctions d’activation entre des transformations lineaires ?
#
# </font>

# %% [markdown]
# - L'ajout de fonctions d'activation entre des transformations linéaires introduit une non-linéarité, permettant au modèle d'apprendre des motifs complexes et de représenter des relations non linéaires entre les caractéristiques.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 4. Quelles sont les tailles $ n_{x}, n_{h}, n_{y} $ sur la figure 1  ? En pratique, comment ces tailles sont-elles choisies ?
#
# </font>

# %% [markdown]
# <div style="text-align:center;">
# <img src="./model.png"  width="600">
# </div>

# %% [markdown]
# - $ n_{x} $ = 2 : Nombre d'entrées $ (n_{x}) $ Correspond au nombre de Variables dans les données .
# - $ n_{h} $ = 4 : Nombre de neurones cachés .
# - $ n_{y} $ : Nombre de sorties  (pour la classification ce nombre egale a nombre des classes dans les données)

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 5. Que représentent les vecteurs $ y $ et $ \hat{y} $ ? Quelle est la différence entre ces deux quantités ?
#
# </font>

# %% [markdown]
# - $ \hat{y} $ : est généralement la sortie du modèle après avoir appliqué la fonction d'activation softmax.un vecteur de probabilités normalisées. représente la probabilité estimée d'appartenir à la classe correspondante.
# - $ y $ : représente le vecteur des vraies étiquettes de classe associées aux exemples d'entraînement.
# - $ \hat{y} $ est la prédiction du modèle, tandis que $ y $ est la vérité de terrain.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 6. Pourquoi utiliser une fonction $ SoftMax $ en sortie ?
#
# </font>

# %% [markdown]
# - La fonction $ softmax $ est utilisée en sortie des réseaux de neurones pour convertir les scores en probabilités, facilitant l'interprétation des prédictions et permettant l'utilisation de la rétropropagation avec une fonction de perte comme l'entropie croisée pour l'entraînement

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 7. Écrire les équations mathématiques permettant d'effectuer la passe forward du réseau de neurones, produisant successivement $ \tilde{h}, \hat{h}, \tilde{y}, $ et $ \hat{y} $ à partir de $ x $.
#
# </font>

# %% [markdown]
# - Combinaison linéaire pour la couche cachée :
#
#     $$ \tilde{h} = W_{h} \times x + b_{h} $$
#
# - Activation de la couche cachée ( avec la fonction d'activation tanh ) :
#
#     $$ \hat{h} = tanh(\tilde{h}) $$
#
# - Combinaison linéaire pour la couche de sortie :
#
#   $$ \tilde{y} = W_{y} \times \hat{h} + b_{y} $$
#
# - Activation de la couche de sortie avec softmax :
#
#    $$ \hat{y} = softmax(\tilde{y}) $$

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 8. Pendant l’apprentissage, on cherche à minimiser la fonction de coût. Pour l’entropie croisée et l’erreur quadratique, comment les $ \hat{y}_i $ doivent-ils varier pour faire diminuer la loss ?
#
# </font>

# %% [markdown]
# - Pour minimiser l'entropie croisée, $ \hat{y}_i $  les doivent s'ajuster vers les valeurs réelles, augmentant lorsque $ y_i $
# est 1 et diminuant lorsque $ \hat{y} $  est 0. Pour l'erreur quadratique, l'ajustement vise à réduire la différence quadratique entre
# $ \hat{y}_i $  et $ y_i $

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 9. En quoi ces fonctions sont-elles plus adaptées aux problèmes de classification ou de régression ?
#
# </font>

# %% [markdown]
# - L'entropie croisée est adaptée à la classification en mesurant la divergence de probabilité, tandis que l'erreur quadratique est appropriée à la régression en évaluant les écarts entre prédictions et valeurs réelles.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 10. Quels semblent etre les avantages et inconvenients des diverses variantes de descente de gradient entre les versions classique, stochastique sur mini-batch et stochastique online ? Laquelle semble la plus raisonnable a utiliser dans le cas general ?
#
# </font>

# %% [markdown]
# | Method                                         | Avantages                                                      | Inconvénients                                                                                                                                                               |
# | ---------------------------------------------- | -------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Descente de Gradient Classique (Batch Gradient Descent) | - Convergence stable vers un minimum global en utilisant l'ensemble des données d'entraînement. | - Peut être coûteuse en termes de mémoire et de calcul, surtout pour de grands ensembles de données. - Les mises à jour ne sont effectuées qu'après avoir parcouru l'ensemble des données. |
# | Descente de Gradient Stochastique (Stochastic Gradient Descent - SGD) sur Mini-Batch | - Moins exigeante en termes de mémoire et de calcul, mise à jour des poids à chaque mini-batch, ce qui peut conduire à une convergence plus rapide. | - Moins stable que la descente de gradient classique en raison de l'aspect stochastique. - Les mises à jour fréquentes peuvent rendre la convergence plus bruitée, mais peuvent être utiles pour sortir de minima locaux. |
# | Descente de Gradient Stochastique Online     | - Mise à jour des poids après chaque exemple d'entraînement, adaptée aux flux de données en ligne. - Réagit rapidement aux changements de distribution. | - Plus sujette au bruit, peut converger vers des minima locaux. - Peut être moins stable que SGD sur mini-batch.     |

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 2 – Implémentation </font></h2>
# </div>

# %%
import torch.nn as nn #  module neuronal
import torch.nn.functional as F #utililitaire de loss fonctionelle
import torch.optim as optim # algorithme d'optimisation
import torch.utils.data as data # dataset,  dataLoader
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_classification

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.1 Forward et backward manuels</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones</font></h3>

# %%
def init_params(nx, nh, ny):
   # nx :  Le nombre de variables d'entrée.
   # nh: Le nombre de neurones dans la couche cachée.
   # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx))
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1))
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh))
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1))

    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3><font color='#1E90FF'> B. la fonction qui effectue la propagation avant</font></h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1'] #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                           # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2']# Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0) # Application de la fonction softmax

    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }

    return outputs

# %% [markdown]
# <h3><font color='#1E90FF'> C. la fonction de Perte et Taux de Précision</font></h3>

# %%
def loss_accuracy(Yhat, Y):

    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0)) #La perte est calculée en utilisant la cross-entropy

    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)

    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)

     #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3><font color='#1E90FF'> D. Propagation du Gradient pour la Mise à Jour des Paramètres</font></h3>

# %%
def backward(params, outputs,  Y):

    # Initialisation des gradients à zéro
    dW1 = torch.zeros_like(params['W1'])
    dB1 = torch.zeros_like(params['B1'])
    dW2 = torch.zeros_like(params['W2'])
    dB2 = torch.zeros_like(params['B2'])

    # Calcul du gradient de la couche de sortie
    dZ2 = outputs['Yhat'] - Y
    dW2 += torch.mm(dZ2, outputs['A1'].t()) / Y.shape[1]
    dB2 += torch.sum(dZ2, dim=1, keepdim=True) / Y.shape[1]

    # Calcul du gradient de la couche cachée
    dZ1 = torch.mm(params['W2'].t(), dZ2) * (1 - torch.tanh(outputs['Z1'])**2)
    dW1 += torch.mm(dZ1, outputs['X'].t()) / Y.shape[1]
    dB1 += torch.sum(dZ1, dim=1, keepdim=True) / Y.shape[1]

    gradients = {
        'dW1': dW1,
        'dB1': dB1,
        'dW2': dW2,
        'dB2': dB2
    }

    return gradients

# %% [markdown]
# <h3><font color='#1E90FF'> E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres</font></h3>

# %%
def sgd(params, grads, eta):
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            params[par] = params[par] - eta * grads['d' + par] # Mise à Jour des Paramètres

    return params

# %% [markdown]
# <h3><font color='#1E90FF'> F. Application</font></h3>

# %%
N_epoch = 200 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)
#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()
# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )

        j = i * batch
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta)
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc = acc*100 / (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc)
    loss_history.append(loss)

    # affichage du frontière de décision pour chaque 20 epoch
    if epoch % 20 == 0:
        # Générer une grille d'échantillonnage pour l'espace de caractéristiques
        x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
        y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

        # Préparer les données pour les prédictions sur la grille
        grid_data = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32).t()
        grid_cach = forward(params, grid_data)
        Z = torch.argmax(grid_cach['Yhat'], dim=0)
        Z = Z.reshape(xx.shape)

        # Affichage de la frontière de décision et des points de données
        plt.contourf(xx, yy, Z, alpha=0.3)
        plt.scatter(X[0, :], X[1, :], c=Y_tensor.numpy(), edgecolors='k', marker='o')
        plt.xlabel('X 1')
        plt.ylabel('X 2')
        plt.title('Frontière de Décision du Modèle')
        plt.show()
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.9559022188186646
# la precision sur train dans epoch 0 est:  27.0
# loss sur train dans epoch 1 est:  0.8768455386161804
# la precision sur train dans epoch 1 est:  30.000000000000007
# loss sur train dans epoch 2 est:  0.8099921941757202
# la precision sur train dans epoch 2 est:  33.0
# loss sur train dans epoch 3 est:  0.753142237663269
# la precision sur train dans epoch 3 est:  37.0
# loss sur train dans epoch 4 est:  0.7044634819030762
# la precision sur train dans epoch 4 est:  45.99999999999999
# loss sur train dans epoch 5 est:  0.6624492406845093
# la precision sur train dans epoch 5 est:  66.99999999999999
# loss sur train dans epoch 6 est:  0.6258721947669983
# la precision sur train dans epoch 6 est:  79.0
# loss sur train dans epoch 7 est:  0.5937389731407166
# la precision sur train dans epoch 7 est:  88.00000000000001
# loss sur train dans epoch 8 est:  0.5652500987052917
# la precision sur train dans epoch 8 est:  98.00000000000001
# loss sur train dans epoch 9 est:  0.5397642850875854
# la precision sur train dans epoch 9 est:  96.99999999999999
# loss sur train dans epoch 10 est:  0.5167678594589233
# la precision sur train dans epoch 10 est:  96.00000000000001
# loss sur train dans epoch 11 est:  0.495849072933197
# la precision sur train dans epoch 11 est:  96.00000000000001
# loss sur train dans epoch 12 est:  0.47667866945266724
# la precision sur train dans epoch 12 est:  95.0
# loss sur train dans epoch 13 est:  0.4589918553829193
# la precision sur train dans epoch 13 est:  93.00000000000001
# loss sur train dans epoch 14 est:  0.44257599115371704
# la precision sur train dans epoch 14 est:  93.00000000000001
# loss sur train dans epoch 15 est:  0.4272591173648834
# la precision sur train dans epoch 15 est:  93.00000000000001
# loss sur train dans epoch 16 est:  0.4129021167755127
# la precision sur train dans epoch 16 est:  93.00000000000001
# loss sur train dans epoch 17 est:  0.39939171075820923
# la precision sur train dans epoch 17 est:  94.0
# loss sur train dans epoch 18 est:  0.3866351246833801
# la precision sur train dans epoch 18 est:  94.0
# loss sur train dans epoch 19 est:  0.3745558559894562
# la precision sur train dans epoch 19 est:  94.0
# loss sur train dans epoch 20 est:  0.36309048533439636
# la precision sur train dans epoch 20 est:  94.0
# loss sur train dans epoch 21 est:  0.35218602418899536
# la precision sur train dans epoch 21 est:  94.0
# loss sur train dans epoch 22 est:  0.3417976498603821
# la precision sur train dans epoch 22 est:  94.0
# loss sur train dans epoch 23 est:  0.3318871259689331
# la precision sur train dans epoch 23 est:  94.0
# loss sur train dans epoch 24 est:  0.3224216401576996
# la precision sur train dans epoch 24 est:  94.0
# loss sur train dans epoch 25 est:  0.3133724629878998
# la precision sur train dans epoch 25 est:  94.0
# loss sur train dans epoch 26 est:  0.30471450090408325
# la precision sur train dans epoch 26 est:  94.0
# loss sur train dans epoch 27 est:  0.29642534255981445
# la precision sur train dans epoch 27 est:  94.0
# loss sur train dans epoch 28 est:  0.288484662771225
# la precision sur train dans epoch 28 est:  95.0
# loss sur train dans epoch 29 est:  0.2808743119239807
# la precision sur train dans epoch 29 est:  95.0
# loss sur train dans epoch 30 est:  0.27357742190361023
# la precision sur train dans epoch 30 est:  95.0
# loss sur train dans epoch 31 est:  0.2665786147117615
# la precision sur train dans epoch 31 est:  95.0
# loss sur train dans epoch 32 est:  0.2598634660243988
# la precision sur train dans epoch 32 est:  95.0
# loss sur train dans epoch 33 est:  0.253418505191803
# la precision sur train dans epoch 33 est:  96.0
# loss sur train dans epoch 34 est:  0.24723103642463684
# la precision sur train dans epoch 34 est:  96.0
# loss sur train dans epoch 35 est:  0.24128928780555725
# la precision sur train dans epoch 35 est:  96.0
# loss sur train dans epoch 36 est:  0.23558178544044495
# la precision sur train dans epoch 36 est:  96.0
# loss sur train dans epoch 37 est:  0.2300979644060135
# la precision sur train dans epoch 37 est:  96.0
# loss sur train dans epoch 38 est:  0.2248276174068451
# la precision sur train dans epoch 38 est:  96.0
# loss sur train dans epoch 39 est:  0.21976104378700256
# la precision sur train dans epoch 39 est:  96.0
# loss sur train dans epoch 40 est:  0.2148890197277069
# la precision sur train dans epoch 40 est:  96.0
# loss sur train dans epoch 41 est:  0.21020278334617615
# la precision sur train dans epoch 41 est:  96.0
# loss sur train dans epoch 42 est:  0.20569391548633575
# la precision sur train dans epoch 42 est:  96.0
# loss sur train dans epoch 43 est:  0.20135441422462463
# la precision sur train dans epoch 43 est:  96.0
# loss sur train dans epoch 44 est:  0.19717667996883392
# la precision sur train dans epoch 44 est:  96.0
# loss sur train dans epoch 45 est:  0.19315345585346222
# la precision sur train dans epoch 45 est:  96.0
# loss sur train dans epoch 46 est:  0.1892777681350708
# la precision sur train dans epoch 46 est:  96.0
# loss sur train dans epoch 47 est:  0.185543030500412
# la precision sur train dans epoch 47 est:  96.0
# loss sur train dans epoch 48 est:  0.1819429099559784
# la precision sur train dans epoch 48 est:  96.0
# loss sur train dans epoch 49 est:  0.17847144603729248
# la precision sur train dans epoch 49 est:  96.99999999999999
# loss sur train dans epoch 50 est:  0.17512290179729462
# la precision sur train dans epoch 50 est:  96.99999999999999
# loss sur train dans epoch 51 est:  0.17189182341098785
# la precision sur train dans epoch 51 est:  96.99999999999999
# loss sur train dans epoch 52 est:  0.16877304017543793
# la precision sur train dans epoch 52 est:  96.99999999999999
# loss sur train dans epoch 53 est:  0.16576161980628967
# la precision sur train dans epoch 53 est:  96.99999999999999
# loss sur train dans epoch 54 est:  0.16285285353660583
# la precision sur train dans epoch 54 est:  96.99999999999999
# loss sur train dans epoch 55 est:  0.16004228591918945
# la precision sur train dans epoch 55 est:  96.99999999999999
# loss sur train dans epoch 56 est:  0.1573256403207779
# la precision sur train dans epoch 56 est:  96.99999999999999
# loss sur train dans epoch 57 est:  0.15469887852668762
# la precision sur train dans epoch 57 est:  96.99999999999999
# loss sur train dans epoch 58 est:  0.15215815603733063
# la precision sur train dans epoch 58 est:  96.99999999999999
# loss sur train dans epoch 59 est:  0.14969979226589203
# la precision sur train dans epoch 59 est:  96.99999999999999
# loss sur train dans epoch 60 est:  0.14732030034065247
# la precision sur train dans epoch 60 est:  96.99999999999999
# loss sur train dans epoch 61 est:  0.1450164020061493
# la precision sur train dans epoch 61 est:  96.99999999999999
# loss sur train dans epoch 62 est:  0.14278489351272583
# la precision sur train dans epoch 62 est:  96.99999999999999
# loss sur train dans epoch 63 est:  0.1406228244304657
# la precision sur train dans epoch 63 est:  96.99999999999999
# loss sur train dans epoch 64 est:  0.1385272741317749
# la precision sur train dans epoch 64 est:  96.99999999999999
# loss sur train dans epoch 65 est:  0.13649557530879974
# la precision sur train dans epoch 65 est:  96.99999999999999
# loss sur train dans epoch 66 est:  0.1345251202583313
# la precision sur train dans epoch 66 est:  96.99999999999999
# loss sur train dans epoch 67 est:  0.1326133906841278
# la precision sur train dans epoch 67 est:  98.00000000000001
# loss sur train dans epoch 68 est:  0.130758136510849
# la precision sur train dans epoch 68 est:  98.00000000000001
# loss sur train dans epoch 69 est:  0.12895706295967102
# la precision sur train dans epoch 69 est:  98.00000000000001
# loss sur train dans epoch 70 est:  0.12720802426338196
# la precision sur train dans epoch 70 est:  98.00000000000001
# loss sur train dans epoch 71 est:  0.12550900876522064
# la precision sur train dans epoch 71 est:  98.00000000000001
# loss sur train dans epoch 72 est:  0.12385811656713486
# la precision sur train dans epoch 72 est:  98.00000000000001
# loss sur train dans epoch 73 est:  0.12225345522165298
# la precision sur train dans epoch 73 est:  98.00000000000001
# loss sur train dans epoch 74 est:  0.12069326639175415
# la precision sur train dans epoch 74 est:  98.00000000000001
# loss sur train dans epoch 75 est:  0.11917589604854584
# la precision sur train dans epoch 75 est:  98.00000000000001
# loss sur train dans epoch 76 est:  0.11769971996545792
# la precision sur train dans epoch 76 est:  98.00000000000001
# loss sur train dans epoch 77 est:  0.11626318842172623
# la precision sur train dans epoch 77 est:  98.00000000000001
# loss sur train dans epoch 78 est:  0.11486490815877914
# la precision sur train dans epoch 78 est:  98.00000000000001
# loss sur train dans epoch 79 est:  0.11350341886281967
# la precision sur train dans epoch 79 est:  98.00000000000001
# loss sur train dans epoch 80 est:  0.11217740923166275
# la precision sur train dans epoch 80 est:  98.00000000000001
# loss sur train dans epoch 81 est:  0.1108856201171875
# la precision sur train dans epoch 81 est:  98.00000000000001
# loss sur train dans epoch 82 est:  0.10962679237127304
# la precision sur train dans epoch 82 est:  98.00000000000001
# loss sur train dans epoch 83 est:  0.10839985311031342
# la precision sur train dans epoch 83 est:  98.00000000000001
# loss sur train dans epoch 84 est:  0.10720361769199371
# la precision sur train dans epoch 84 est:  98.00000000000001
# loss sur train dans epoch 85 est:  0.10603702068328857
# la precision sur train dans epoch 85 est:  98.00000000000001
# loss sur train dans epoch 86 est:  0.10489904880523682
# la precision sur train dans epoch 86 est:  98.00000000000001
# loss sur train dans epoch 87 est:  0.10378875583410263
# la precision sur train dans epoch 87 est:  98.00000000000001
# loss sur train dans epoch 88 est:  0.10270515829324722
# la precision sur train dans epoch 88 est:  98.00000000000001
# loss sur train dans epoch 89 est:  0.10164739191532135
# la precision sur train dans epoch 89 est:  98.00000000000001
# loss sur train dans epoch 90 est:  0.10061458498239517
# la precision sur train dans epoch 90 est:  98.00000000000001
# loss sur train dans epoch 91 est:  0.09960593283176422
# la precision sur train dans epoch 91 est:  98.00000000000001
# loss sur train dans epoch 92 est:  0.09862063080072403
# la precision sur train dans epoch 92 est:  98.00000000000001
# loss sur train dans epoch 93 est:  0.0976579338312149
# la precision sur train dans epoch 93 est:  98.00000000000001
# loss sur train dans epoch 94 est:  0.09671709686517715
# la precision sur train dans epoch 94 est:  98.00000000000001
# loss sur train dans epoch 95 est:  0.09579743444919586
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.0948982834815979
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.09401898086071014
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.09315893799066544
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.09231756627559662
# la precision sur train dans epoch 99 est:  99.0
# loss sur train dans epoch 100 est:  0.09149424731731415
# la precision sur train dans epoch 100 est:  99.0
# loss sur train dans epoch 101 est:  0.09068847447633743
# la precision sur train dans epoch 101 est:  99.0
# loss sur train dans epoch 102 est:  0.0898997113108635
# la precision sur train dans epoch 102 est:  99.0
# loss sur train dans epoch 103 est:  0.08912744373083115
# la precision sur train dans epoch 103 est:  99.0
# loss sur train dans epoch 104 est:  0.08837118744850159
# la precision sur train dans epoch 104 est:  99.0
# loss sur train dans epoch 105 est:  0.08763047307729721
# la precision sur train dans epoch 105 est:  99.0
# loss sur train dans epoch 106 est:  0.0869048535823822
# la precision sur train dans epoch 106 est:  99.0
# loss sur train dans epoch 107 est:  0.08619387447834015
# la precision sur train dans epoch 107 est:  99.0
# loss sur train dans epoch 108 est:  0.08549712598323822
# la precision sur train dans epoch 108 est:  99.0
# loss sur train dans epoch 109 est:  0.08481421321630478
# la precision sur train dans epoch 109 est:  99.0
# loss sur train dans epoch 110 est:  0.084144726395607
# la precision sur train dans epoch 110 est:  99.0
# loss sur train dans epoch 111 est:  0.083488330245018
# la precision sur train dans epoch 111 est:  99.0
# loss sur train dans epoch 112 est:  0.08284461498260498
# la precision sur train dans epoch 112 est:  99.0
# loss sur train dans epoch 113 est:  0.08221326768398285
# la precision sur train dans epoch 113 est:  99.0
# loss sur train dans epoch 114 est:  0.08159390091896057
# la precision sur train dans epoch 114 est:  99.0
# loss sur train dans epoch 115 est:  0.08098624646663666
# la precision sur train dans epoch 115 est:  99.0
# loss sur train dans epoch 116 est:  0.08038993924856186
# la precision sur train dans epoch 116 est:  99.0
# loss sur train dans epoch 117 est:  0.07980470359325409
# la precision sur train dans epoch 117 est:  99.0
# loss sur train dans epoch 118 est:  0.07923025637865067
# la precision sur train dans epoch 118 est:  99.0
# loss sur train dans epoch 119 est:  0.07866628468036652
# la precision sur train dans epoch 119 est:  99.0
# loss sur train dans epoch 120 est:  0.07811254262924194
# la precision sur train dans epoch 120 est:  99.0
# loss sur train dans epoch 121 est:  0.07756872475147247
# la precision sur train dans epoch 121 est:  99.0
# loss sur train dans epoch 122 est:  0.07703462243080139
# la precision sur train dans epoch 122 est:  99.0
# loss sur train dans epoch 123 est:  0.07650996744632721
# la precision sur train dans epoch 123 est:  99.0
# loss sur train dans epoch 124 est:  0.07599451392889023
# la precision sur train dans epoch 124 est:  99.0
# loss sur train dans epoch 125 est:  0.07548803836107254
# la precision sur train dans epoch 125 est:  99.0
# loss sur train dans epoch 126 est:  0.07499031722545624
# la precision sur train dans epoch 126 est:  99.0
# loss sur train dans epoch 127 est:  0.07450112700462341
# la precision sur train dans epoch 127 est:  99.0
# loss sur train dans epoch 128 est:  0.07402025908231735
# la precision sur train dans epoch 128 est:  99.0
# loss sur train dans epoch 129 est:  0.07354751229286194
# la precision sur train dans epoch 129 est:  99.0
# loss sur train dans epoch 130 est:  0.07308267802000046
# la precision sur train dans epoch 130 est:  99.0
# loss sur train dans epoch 131 est:  0.07262559235095978
# la precision sur train dans epoch 131 est:  99.0
# loss sur train dans epoch 132 est:  0.07217604666948318
# la precision sur train dans epoch 132 est:  99.0
# loss sur train dans epoch 133 est:  0.07173384726047516
# la precision sur train dans epoch 133 est:  99.0
# loss sur train dans epoch 134 est:  0.07129886746406555
# la precision sur train dans epoch 134 est:  99.0
# loss sur train dans epoch 135 est:  0.07087089866399765
# la precision sur train dans epoch 135 est:  99.0
# loss sur train dans epoch 136 est:  0.07044978439807892
# la precision sur train dans epoch 136 est:  99.0
# loss sur train dans epoch 137 est:  0.07003538310527802
# la precision sur train dans epoch 137 est:  99.0
# loss sur train dans epoch 138 est:  0.06962753087282181
# la precision sur train dans epoch 138 est:  99.0
# loss sur train dans epoch 139 est:  0.06922607123851776
# la precision sur train dans epoch 139 est:  99.0
# loss sur train dans epoch 140 est:  0.06883086264133453
# la precision sur train dans epoch 140 est:  99.0
# loss sur train dans epoch 141 est:  0.06844177097082138
# la precision sur train dans epoch 141 est:  99.0
# loss sur train dans epoch 142 est:  0.06805866956710815
# la precision sur train dans epoch 142 est:  99.0
# loss sur train dans epoch 143 est:  0.06768139451742172
# la precision sur train dans epoch 143 est:  99.0
# loss sur train dans epoch 144 est:  0.06730984151363373
# la precision sur train dans epoch 144 est:  99.0
# loss sur train dans epoch 145 est:  0.06694386154413223
# la precision sur train dans epoch 145 est:  99.0
# loss sur train dans epoch 146 est:  0.06658335030078888
# la precision sur train dans epoch 146 est:  99.0
# loss sur train dans epoch 147 est:  0.06622817367315292
# la precision sur train dans epoch 147 est:  99.0
# loss sur train dans epoch 148 est:  0.0658782348036766
# la precision sur train dans epoch 148 est:  99.0
# loss sur train dans epoch 149 est:  0.06553341448307037
# la precision sur train dans epoch 149 est:  99.0
# loss sur train dans epoch 150 est:  0.06519362330436707
# la precision sur train dans epoch 150 est:  99.0
# loss sur train dans epoch 151 est:  0.06485871970653534
# la precision sur train dans epoch 151 est:  99.0
# loss sur train dans epoch 152 est:  0.06452862918376923
# la precision sur train dans epoch 152 est:  99.0
# loss sur train dans epoch 153 est:  0.06420324742794037
# la precision sur train dans epoch 153 est:  99.0
# loss sur train dans epoch 154 est:  0.06388245522975922
# la precision sur train dans epoch 154 est:  99.0
# loss sur train dans epoch 155 est:  0.0635661780834198
# la precision sur train dans epoch 155 est:  99.0
# loss sur train dans epoch 156 est:  0.06325433403253555
# la precision sur train dans epoch 156 est:  99.0
# loss sur train dans epoch 157 est:  0.06294680386781693
# la precision sur train dans epoch 157 est:  99.0
# loss sur train dans epoch 158 est:  0.06264351308345795
# la precision sur train dans epoch 158 est:  99.0
# loss sur train dans epoch 159 est:  0.062344394624233246
# la precision sur train dans epoch 159 est:  99.0
# loss sur train dans epoch 160 est:  0.06204933673143387
# la precision sur train dans epoch 160 est:  99.0
# loss sur train dans epoch 161 est:  0.06175827234983444
# la precision sur train dans epoch 161 est:  99.0
# loss sur train dans epoch 162 est:  0.061471126973629
# la precision sur train dans epoch 162 est:  99.0
# loss sur train dans epoch 163 est:  0.061187803745269775
# la precision sur train dans epoch 163 est:  99.0
# loss sur train dans epoch 164 est:  0.06090825796127319
# la precision sur train dans epoch 164 est:  99.0
# loss sur train dans epoch 165 est:  0.06063238903880119
# la precision sur train dans epoch 165 est:  99.0
# loss sur train dans epoch 166 est:  0.0603601410984993
# la precision sur train dans epoch 166 est:  99.0
# loss sur train dans epoch 167 est:  0.06009144335985184
# la precision sur train dans epoch 167 est:  99.0
# loss sur train dans epoch 168 est:  0.059826213866472244
# la precision sur train dans epoch 168 est:  99.0
# loss sur train dans epoch 169 est:  0.05956443399190903
# la precision sur train dans epoch 169 est:  99.0
# loss sur train dans epoch 170 est:  0.05930596590042114
# la precision sur train dans epoch 170 est:  99.0
# loss sur train dans epoch 171 est:  0.05905080586671829
# la precision sur train dans epoch 171 est:  99.0
# loss sur train dans epoch 172 est:  0.05879887193441391
# la precision sur train dans epoch 172 est:  99.0
# loss sur train dans epoch 173 est:  0.05855009704828262
# la precision sur train dans epoch 173 est:  99.0
# loss sur train dans epoch 174 est:  0.058304429054260254
# la precision sur train dans epoch 174 est:  99.0
# loss sur train dans epoch 175 est:  0.05806180089712143
# la precision sur train dans epoch 175 est:  99.0
# loss sur train dans epoch 176 est:  0.05782218649983406
# la precision sur train dans epoch 176 est:  99.0
# loss sur train dans epoch 177 est:  0.057585496455430984
# la precision sur train dans epoch 177 est:  99.0
# loss sur train dans epoch 178 est:  0.05735171586275101
# la precision sur train dans epoch 178 est:  99.0
# loss sur train dans epoch 179 est:  0.057120759040117264
# la precision sur train dans epoch 179 est:  99.0
# loss sur train dans epoch 180 est:  0.05689258500933647
# la precision sur train dans epoch 180 est:  99.0
# loss sur train dans epoch 181 est:  0.056667160242795944
# la precision sur train dans epoch 181 est:  99.0
# loss sur train dans epoch 182 est:  0.056444425135850906
# la precision sur train dans epoch 182 est:  99.0
# loss sur train dans epoch 183 est:  0.05622432380914688
# la precision sur train dans epoch 183 est:  99.0
# loss sur train dans epoch 184 est:  0.056006819009780884
# la precision sur train dans epoch 184 est:  99.0
# loss sur train dans epoch 185 est:  0.05579187721014023
# la precision sur train dans epoch 185 est:  99.0
# loss sur train dans epoch 186 est:  0.05557941645383835
# la precision sur train dans epoch 186 est:  99.0
# loss sur train dans epoch 187 est:  0.055369455367326736
# la precision sur train dans epoch 187 est:  99.0
# loss sur train dans epoch 188 est:  0.055161893367767334
# la precision sur train dans epoch 188 est:  99.0
# loss sur train dans epoch 189 est:  0.05495671555399895
# la precision sur train dans epoch 189 est:  99.0
# loss sur train dans epoch 190 est:  0.05475388839840889
# la precision sur train dans epoch 190 est:  99.0
# loss sur train dans epoch 191 est:  0.05455334857106209
# la precision sur train dans epoch 191 est:  99.0
# loss sur train dans epoch 192 est:  0.05435507744550705
# la precision sur train dans epoch 192 est:  99.0
# loss sur train dans epoch 193 est:  0.054159026592969894
# la precision sur train dans epoch 193 est:  99.0
# loss sur train dans epoch 194 est:  0.053965162485837936
# la precision sur train dans epoch 194 est:  99.0
# loss sur train dans epoch 195 est:  0.05377345532178879
# la precision sur train dans epoch 195 est:  99.0
# loss sur train dans epoch 196 est:  0.053583867847919464
# la precision sur train dans epoch 196 est:  99.0
# loss sur train dans epoch 197 est:  0.053396355360746384
# la precision sur train dans epoch 197 est:  99.0
# loss sur train dans epoch 198 est:  0.05321088433265686
# la precision sur train dans epoch 198 est:  99.0
# loss sur train dans epoch 199 est:  0.05302744358778
# la precision sur train dans epoch 199 est:  99.0

# %% [markdown]
# <center>
# 	<h2 style="color:#e56b6f">
# 		<b>
# 			2.2 Simplification du backward avec <span style="color:#eaac8b"> torch.autograd</span>
# 		</b>
# 	</h2>
# </center>

# %% [markdown]
# <h3 style="color:#00a896;font-weight:bold;">
#
#  A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones
#
# </h3>

# %%
def init_params(nx, nh, ny):
    # nx :  Le nombre de variables d'entrée.
    # nh: Le nombre de neurones dans la couche cachée.
    # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    #activation du autograde pour la methode de toch
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx),requires_grad=True)
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1), requires_grad=True)
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh), requires_grad=True)
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1), requires_grad=True)
    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;" >
# 	B. la fonction qui effectue la propagation avant
# </h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1']  #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                            # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2'] # Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0)  # Application de la fonction softmax
    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }
    return outputs

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	C. la fonction de Perte et Taux de Précision
# </h3>

# %%
def loss_accuracy(Yhat, Y):
    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    #La perte est calculée en utilisant la cross-entropy
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0))
    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)
    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)
    #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	D. Propagation du Gradient pour la Mise à Jour des Paramètres
# </h3>

# %%
def backward_auto(params, outputs, Y):
    # Réinitialiser les gradients des paramètres
    for par in params:
        if params[par].grad is not None:
            params[par].grad.zero_()
    # Calculer la perte
    loss = loss_accuracy(outputs['Yhat'], Y)[0]
    # Rétropropagation automatique
    loss.backward()
    # Extraire les gradients des paramètres après rétropropagation
    gradients = {
        'dW1': params['W1'].grad,
        'dB1': params['B1'].grad,
        'dW2': params['W2'].grad,
        'dB2': params['B2'].grad,
    }

    return gradients

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres
# </h3>

# %%
def sgd(params, grads, eta):
    # Assurez-vous d'utiliser torch.no_grad() pour éviter de calculer les gradients lors de la mise à jour des paramètres
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            # Mise à jour des paramètres avec la descente de gradient
            params[par] = params[par] - eta * grads['d' + par]
            # Activer à nouveau le suivi des gradients pour les paramètres
            params[par].requires_grad_(True)
    return params

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	F. Application
# </h3>

# %%
N_epoch = 100 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)

#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
         # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
        j = i * batch

    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc  = acc * 100 /  (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc )
    loss_history.append(loss.item())

#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.6516510248184204
# la precision sur train dans epoch 0 est:  50.99999999999999
# loss sur train dans epoch 1 est:  0.6150525808334351
# la precision sur train dans epoch 1 est:  60.000000000000014
# loss sur train dans epoch 2 est:  0.5819052457809448
# la precision sur train dans epoch 2 est:  74.0
# loss sur train dans epoch 3 est:  0.5516648292541504
# la precision sur train dans epoch 3 est:  84.0
# loss sur train dans epoch 4 est:  0.5239126086235046
# la precision sur train dans epoch 4 est:  88.00000000000001
# loss sur train dans epoch 5 est:  0.49832233786582947
# la precision sur train dans epoch 5 est:  90.0
# loss sur train dans epoch 6 est:  0.47463640570640564
# la precision sur train dans epoch 6 est:  91.99999999999999
# loss sur train dans epoch 7 est:  0.45264777541160583
# la precision sur train dans epoch 7 est:  93.00000000000001
# loss sur train dans epoch 8 est:  0.43218690156936646
# la precision sur train dans epoch 8 est:  94.0
# loss sur train dans epoch 9 est:  0.41311222314834595
# la precision sur train dans epoch 9 est:  95.0
# loss sur train dans epoch 10 est:  0.3953034281730652
# la precision sur train dans epoch 10 est:  96.00000000000001
# loss sur train dans epoch 11 est:  0.37865617871284485
# la precision sur train dans epoch 11 est:  96.00000000000001
# loss sur train dans epoch 12 est:  0.3630787134170532
# la precision sur train dans epoch 12 est:  96.00000000000001
# loss sur train dans epoch 13 est:  0.34848928451538086
# la precision sur train dans epoch 13 est:  96.99999999999999
# loss sur train dans epoch 14 est:  0.33481407165527344
# la precision sur train dans epoch 14 est:  96.99999999999999
# loss sur train dans epoch 15 est:  0.3219861388206482
# la precision sur train dans epoch 15 est:  96.99999999999999
# loss sur train dans epoch 16 est:  0.30994415283203125
# la precision sur train dans epoch 16 est:  96.99999999999999
# loss sur train dans epoch 17 est:  0.29863184690475464
# la precision sur train dans epoch 17 est:  96.99999999999999
# loss sur train dans epoch 18 est:  0.28799715638160706
# la precision sur train dans epoch 18 est:  96.99999999999999
# loss sur train dans epoch 19 est:  0.2779921293258667
# la precision sur train dans epoch 19 est:  96.99999999999999
# loss sur train dans epoch 20 est:  0.26857250928878784
# la precision sur train dans epoch 20 est:  96.99999999999999
# loss sur train dans epoch 21 est:  0.25969716906547546
# la precision sur train dans epoch 21 est:  96.99999999999999
# loss sur train dans epoch 22 est:  0.25132814049720764
# la precision sur train dans epoch 22 est:  96.99999999999999
# loss sur train dans epoch 23 est:  0.2434302270412445
# la precision sur train dans epoch 23 est:  96.99999999999999
# loss sur train dans epoch 24 est:  0.23597100377082825
# la precision sur train dans epoch 24 est:  96.99999999999999
# loss sur train dans epoch 25 est:  0.22892017662525177
# la precision sur train dans epoch 25 est:  96.99999999999999
# loss sur train dans epoch 26 est:  0.22224998474121094
# la precision sur train dans epoch 26 est:  96.99999999999999
# loss sur train dans epoch 27 est:  0.2159346044063568
# la precision sur train dans epoch 27 est:  96.99999999999999
# loss sur train dans epoch 28 est:  0.209950253367424
# la precision sur train dans epoch 28 est:  98.00000000000001
# loss sur train dans epoch 29 est:  0.20427484810352325
# la precision sur train dans epoch 29 est:  98.00000000000001
# loss sur train dans epoch 30 est:  0.19888807833194733
# la precision sur train dans epoch 30 est:  98.00000000000001
# loss sur train dans epoch 31 est:  0.19377095997333527
# la precision sur train dans epoch 31 est:  98.00000000000001
# loss sur train dans epoch 32 est:  0.18890610337257385
# la precision sur train dans epoch 32 est:  98.00000000000001
# loss sur train dans epoch 33 est:  0.18427728116512299
# la precision sur train dans epoch 33 est:  98.00000000000001
# loss sur train dans epoch 34 est:  0.17986960709095
# la precision sur train dans epoch 34 est:  98.00000000000001
# loss sur train dans epoch 35 est:  0.17566919326782227
# la precision sur train dans epoch 35 est:  98.00000000000001
# loss sur train dans epoch 36 est:  0.17166319489479065
# la precision sur train dans epoch 36 est:  98.00000000000001
# loss sur train dans epoch 37 est:  0.16783972084522247
# la precision sur train dans epoch 37 est:  98.00000000000001
# loss sur train dans epoch 38 est:  0.1641877442598343
# la precision sur train dans epoch 38 est:  98.00000000000001
# loss sur train dans epoch 39 est:  0.16069704294204712
# la precision sur train dans epoch 39 est:  98.00000000000001
# loss sur train dans epoch 40 est:  0.15735802054405212
# la precision sur train dans epoch 40 est:  98.00000000000001
# loss sur train dans epoch 41 est:  0.15416191518306732
# la precision sur train dans epoch 41 est:  98.00000000000001
# loss sur train dans epoch 42 est:  0.15110044181346893
# la precision sur train dans epoch 42 est:  98.00000000000001
# loss sur train dans epoch 43 est:  0.14816595613956451
# la precision sur train dans epoch 43 est:  98.00000000000001
# loss sur train dans epoch 44 est:  0.1453513503074646
# la precision sur train dans epoch 44 est:  98.00000000000001
# loss sur train dans epoch 45 est:  0.14264997839927673
# la precision sur train dans epoch 45 est:  98.00000000000001
# loss sur train dans epoch 46 est:  0.14005562663078308
# la precision sur train dans epoch 46 est:  98.00000000000001
# loss sur train dans epoch 47 est:  0.13756254315376282
# la precision sur train dans epoch 47 est:  98.00000000000001
# loss sur train dans epoch 48 est:  0.13516530394554138
# la precision sur train dans epoch 48 est:  98.00000000000001
# loss sur train dans epoch 49 est:  0.13285884261131287
# la precision sur train dans epoch 49 est:  98.00000000000001
# loss sur train dans epoch 50 est:  0.1306384801864624
# la precision sur train dans epoch 50 est:  98.00000000000001
# loss sur train dans epoch 51 est:  0.12849974632263184
# la precision sur train dans epoch 51 est:  98.00000000000001
# loss sur train dans epoch 52 est:  0.12643852829933167
# la precision sur train dans epoch 52 est:  98.00000000000001
# loss sur train dans epoch 53 est:  0.1244509220123291
# la precision sur train dans epoch 53 est:  98.00000000000001
# loss sur train dans epoch 54 est:  0.12253334373235703
# la precision sur train dans epoch 54 est:  98.00000000000001
# loss sur train dans epoch 55 est:  0.12068233639001846
# la precision sur train dans epoch 55 est:  98.00000000000001
# loss sur train dans epoch 56 est:  0.11889465153217316
# la precision sur train dans epoch 56 est:  98.00000000000001
# loss sur train dans epoch 57 est:  0.11716733127832413
# la precision sur train dans epoch 57 est:  98.00000000000001
# loss sur train dans epoch 58 est:  0.11549750715494156
# la precision sur train dans epoch 58 est:  98.00000000000001
# loss sur train dans epoch 59 est:  0.11388250440359116
# la precision sur train dans epoch 59 est:  98.00000000000001
# loss sur train dans epoch 60 est:  0.11231980472803116
# la precision sur train dans epoch 60 est:  98.00000000000001
# loss sur train dans epoch 61 est:  0.11080703884363174
# la precision sur train dans epoch 61 est:  98.00000000000001
# loss sur train dans epoch 62 est:  0.10934194177389145
# la precision sur train dans epoch 62 est:  98.00000000000001
# loss sur train dans epoch 63 est:  0.10792243480682373
# la precision sur train dans epoch 63 est:  98.00000000000001
# loss sur train dans epoch 64 est:  0.10654650628566742
# la precision sur train dans epoch 64 est:  98.00000000000001
# loss sur train dans epoch 65 est:  0.1052122563123703
# la precision sur train dans epoch 65 est:  98.00000000000001
# loss sur train dans epoch 66 est:  0.1039179190993309
# la precision sur train dans epoch 66 est:  98.00000000000001
# loss sur train dans epoch 67 est:  0.10266178846359253
# la precision sur train dans epoch 67 est:  98.00000000000001
# loss sur train dans epoch 68 est:  0.10144229233264923
# la precision sur train dans epoch 68 est:  98.00000000000001
# loss sur train dans epoch 69 est:  0.10025787353515625
# la precision sur train dans epoch 69 est:  98.00000000000001
# loss sur train dans epoch 70 est:  0.09910713881254196
# la precision sur train dans epoch 70 est:  98.00000000000001
# loss sur train dans epoch 71 est:  0.09798870980739594
# la precision sur train dans epoch 71 est:  99.0
# loss sur train dans epoch 72 est:  0.09690126776695251
# la precision sur train dans epoch 72 est:  99.0
# loss sur train dans epoch 73 est:  0.09584362059831619
# la precision sur train dans epoch 73 est:  99.0
# loss sur train dans epoch 74 est:  0.09481458365917206
# la precision sur train dans epoch 74 est:  99.0
# loss sur train dans epoch 75 est:  0.09381307661533356
# la precision sur train dans epoch 75 est:  99.0
# loss sur train dans epoch 76 est:  0.09283801168203354
# la precision sur train dans epoch 76 est:  99.0
# loss sur train dans epoch 77 est:  0.0918884128332138
# la precision sur train dans epoch 77 est:  99.0
# loss sur train dans epoch 78 est:  0.09096331149339676
# la precision sur train dans epoch 78 est:  99.0
# loss sur train dans epoch 79 est:  0.09006179869174957
# la precision sur train dans epoch 79 est:  99.0
# loss sur train dans epoch 80 est:  0.0891830176115036
# la precision sur train dans epoch 80 est:  99.0
# loss sur train dans epoch 81 est:  0.08832614123821259
# la precision sur train dans epoch 81 est:  99.0
# loss sur train dans epoch 82 est:  0.08749035745859146
# la precision sur train dans epoch 82 est:  99.0
# loss sur train dans epoch 83 est:  0.08667493611574173
# la precision sur train dans epoch 83 est:  99.0
# loss sur train dans epoch 84 est:  0.08587916940450668
# la precision sur train dans epoch 84 est:  99.0
# loss sur train dans epoch 85 est:  0.08510236442089081
# la precision sur train dans epoch 85 est:  99.0
# loss sur train dans epoch 86 est:  0.08434385061264038
# la precision sur train dans epoch 86 est:  99.0
# loss sur train dans epoch 87 est:  0.08360303938388824
# la precision sur train dans epoch 87 est:  99.0
# loss sur train dans epoch 88 est:  0.08287928253412247
# la precision sur train dans epoch 88 est:  99.0
# loss sur train dans epoch 89 est:  0.08217205107212067
# la precision sur train dans epoch 89 est:  99.0
# loss sur train dans epoch 90 est:  0.08148076385259628
# la precision sur train dans epoch 90 est:  99.0
# loss sur train dans epoch 91 est:  0.08080492168664932
# la precision sur train dans epoch 91 est:  99.0
# loss sur train dans epoch 92 est:  0.080144003033638
# la precision sur train dans epoch 92 est:  99.0
# loss sur train dans epoch 93 est:  0.0794975534081459
# la precision sur train dans epoch 93 est:  99.0
# loss sur train dans epoch 94 est:  0.07886506617069244
# la precision sur train dans epoch 94 est:  99.0
# loss sur train dans epoch 95 est:  0.07824616134166718
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.0776403546333313
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.07704728841781616
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.07646654546260834
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.07589772343635559
# la precision sur train dans epoch 99 est:  99.0

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.3 Simplification du forward avec les couches </font><font color='#87CEFA'> torch.nn</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. Initialisation d'un Modèle de Réseau de Neurones pour la Classification  avec PyTorch</font></h3>

# %%
def init_model(nx, nh, ny):
    model = torch.nn.Sequential(
        torch.nn.Linear(nx, nh), # Couche linéaire d'entrée à la couche cachée
        torch.nn.ReLU(),         # Fonction d'activation ReLU pour la couche cachée max(0, z)
        torch.nn.Linear(nh, ny), # Couche linéaire de la couche cachée à la couche de sortie
        torch.nn.Sigmoid()       # Fonction d'activation Sigmoid pour la couche de sortie
        #torch.nn.Softmax(dim=1)
    )
    
    # Définition de la fonction de perte CrossEntropyLoss pour une tâche de classification multiclasse
    loss = torch.nn.CrossEntropyLoss()
    return model, loss

# %% [markdown]
# <h3><font color='#1E90FF'> B. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres</font></h3>

# %%
def sgd(model, eta):
    # Assurez-vous d'utiliser torch.no_grad() pour éviter de calculer les gradients lors de la mise à jour des paramètres
    with torch.no_grad():
        for param in model.parameters():
            # Mise à jour des paramètres avec la descente de gradient
            param -= eta * param.grad
        
        # Réinitialiser les gradients après la mise à jour des paramètres
        model.zero_grad()

# %% [markdown]
# <h3><font color='#1E90FF'> C. Application</font></h3>

# %%
N_epoch = 1000 #nombre des epoqu
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)
X = X_tensor
Y = Y_tensor

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle 
model , loss= init_model(2,4,2)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    los_glob = 0 #Réinitialiser la perte du modèle pour chaque époque.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[j:i * batch, :]
        Y_epoch = Y[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model(X_epoch)
        # calculer la perte pour le mini-batch actuel
        los_batch = loss(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los_batch.backward()
        sgd(model, eta )
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        los_glob += los_batch
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.   
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données 
        X_epoch = X[ j : N, :]
        Y_epoch = Y[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model(X_epoch)
        # calculer la perte pour le mini-batch actuel
        los_batch = loss(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los_batch.backward()
        sgd(model, eta )
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        los_glob += los_batch
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    los_glob /= (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch}: ", los_glob.item())
    loss_history.append(los_glob.item())
    
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0:  0.6546729207038879
# loss sur train dans epoch 1:  0.6529527902603149
# loss sur train dans epoch 2:  0.6512304544448853
# loss sur train dans epoch 3:  0.6495147943496704
# loss sur train dans epoch 4:  0.6478087306022644
# loss sur train dans epoch 5:  0.6461012363433838
# loss sur train dans epoch 6:  0.6444084644317627
# loss sur train dans epoch 7:  0.6427332758903503
# loss sur train dans epoch 8:  0.6410658955574036
# loss sur train dans epoch 9:  0.6394158005714417
# loss sur train dans epoch 10:  0.6377686858177185
# loss sur train dans epoch 11:  0.6361234784126282
# loss sur train dans epoch 12:  0.6344799995422363
# loss sur train dans epoch 13:  0.6328544616699219
# loss sur train dans epoch 14:  0.6312423944473267
# loss sur train dans epoch 15:  0.6296416521072388
# loss sur train dans epoch 16:  0.6280447244644165
# loss sur train dans epoch 17:  0.6264520883560181
# loss sur train dans epoch 18:  0.6248639822006226
# loss sur train dans epoch 19:  0.6232939958572388
# loss sur train dans epoch 20:  0.6217451691627502
# loss sur train dans epoch 21:  0.6202051043510437
# loss sur train dans epoch 22:  0.6186856031417847
# loss sur train dans epoch 23:  0.6171802282333374
# loss sur train dans epoch 24:  0.6156817674636841
# loss sur train dans epoch 25:  0.6141905784606934
# loss sur train dans epoch 26:  0.6127067804336548
# loss sur train dans epoch 27:  0.611230731010437
# loss sur train dans epoch 28:  0.6097626090049744
# loss sur train dans epoch 29:  0.6083024740219116
# loss sur train dans epoch 30:  0.6068507432937622
# loss sur train dans epoch 31:  0.6054073572158813
# loss sur train dans epoch 32:  0.6039727330207825
# loss sur train dans epoch 33:  0.6025468707084656
# loss sur train dans epoch 34:  0.6011301279067993
# loss sur train dans epoch 35:  0.5997224450111389
# loss sur train dans epoch 36:  0.5983240604400635
# loss sur train dans epoch 37:  0.5969350934028625
# loss sur train dans epoch 38:  0.5955556631088257
# loss sur train dans epoch 39:  0.5941858291625977
# loss sur train dans epoch 40:  0.5928257703781128
# loss sur train dans epoch 41:  0.5914778113365173
# loss sur train dans epoch 42:  0.5901418924331665
# loss sur train dans epoch 43:  0.5888158082962036
# loss sur train dans epoch 44:  0.5875037908554077
# loss sur train dans epoch 45:  0.5862017273902893
# loss sur train dans epoch 46:  0.5849095582962036
# loss sur train dans epoch 47:  0.5836274027824402
# loss sur train dans epoch 48:  0.5823551416397095
# loss sur train dans epoch 49:  0.5810929536819458
# loss sur train dans epoch 50:  0.5798407793045044
# loss sur train dans epoch 51:  0.5785984396934509
# loss sur train dans epoch 52:  0.5773659944534302
# loss sur train dans epoch 53:  0.5761435031890869
# loss sur train dans epoch 54:  0.5749307870864868
# loss sur train dans epoch 55:  0.5737278461456299
# loss sur train dans epoch 56:  0.5725346803665161
# loss sur train dans epoch 57:  0.5713511109352112
# loss sur train dans epoch 58:  0.5701771378517151
# loss sur train dans epoch 59:  0.5690127015113831
# loss sur train dans epoch 60:  0.5678576827049255
# loss sur train dans epoch 61:  0.5667119026184082
# loss sur train dans epoch 62:  0.5655754804611206
# loss sur train dans epoch 63:  0.5644480586051941
# loss sur train dans epoch 64:  0.5633297562599182
# loss sur train dans epoch 65:  0.5622212886810303
# loss sur train dans epoch 66:  0.5611250996589661
# loss sur train dans epoch 67:  0.5600403547286987
# loss sur train dans epoch 68:  0.5589640736579895
# loss sur train dans epoch 69:  0.5578961372375488
# loss sur train dans epoch 70:  0.5568366050720215
# loss sur train dans epoch 71:  0.5557972192764282
# loss sur train dans epoch 72:  0.5547639727592468
# loss sur train dans epoch 73:  0.553738534450531
# loss sur train dans epoch 74:  0.5527209043502808
# loss sur train dans epoch 75:  0.5517109632492065
# loss sur train dans epoch 76:  0.550708532333374
# loss sur train dans epoch 77:  0.5497135519981384
# loss sur train dans epoch 78:  0.5487259030342102
# loss sur train dans epoch 79:  0.5477465391159058
# loss sur train dans epoch 80:  0.5467759966850281
# loss sur train dans epoch 81:  0.5458124876022339
# loss sur train dans epoch 82:  0.5448557138442993
# loss sur train dans epoch 83:  0.5439055562019348
# loss sur train dans epoch 84:  0.5429619550704956
# loss sur train dans epoch 85:  0.5420253872871399
# loss sur train dans epoch 86:  0.541099488735199
# loss sur train dans epoch 87:  0.5401817560195923
# loss sur train dans epoch 88:  0.5392740368843079
# loss sur train dans epoch 89:  0.5383747816085815
# loss sur train dans epoch 90:  0.537481963634491
# loss sur train dans epoch 91:  0.5365975499153137
# loss sur train dans epoch 92:  0.5357189774513245
# loss sur train dans epoch 93:  0.534846305847168
# loss sur train dans epoch 94:  0.5339794158935547
# loss sur train dans epoch 95:  0.5331194996833801
# loss sur train dans epoch 96:  0.5322674512863159
# loss sur train dans epoch 97:  0.5314226150512695
# loss sur train dans epoch 98:  0.530583381652832
# loss sur train dans epoch 99:  0.5297495722770691
# loss sur train dans epoch 100:  0.5289211869239807
# loss sur train dans epoch 101:  0.5281022787094116
# loss sur train dans epoch 102:  0.5272886157035828
# loss sur train dans epoch 103:  0.5264798998832703
# loss sur train dans epoch 104:  0.5256830453872681
# loss sur train dans epoch 105:  0.5248931646347046
# loss sur train dans epoch 106:  0.5241101384162903
# loss sur train dans epoch 107:  0.5233339667320251
# loss sur train dans epoch 108:  0.5225629806518555
# loss sur train dans epoch 109:  0.5217971801757812
# loss sur train dans epoch 110:  0.5210379958152771
# loss sur train dans epoch 111:  0.5202835202217102
# loss sur train dans epoch 112:  0.519533634185791
# loss sur train dans epoch 113:  0.5187884569168091
# loss sur train dans epoch 114:  0.5180493593215942
# loss sur train dans epoch 115:  0.5173177123069763
# loss sur train dans epoch 116:  0.5165905356407166
# loss sur train dans epoch 117:  0.5158675909042358
# loss sur train dans epoch 118:  0.5151581764221191
# loss sur train dans epoch 119:  0.5144534111022949
# loss sur train dans epoch 120:  0.5137531757354736
# loss sur train dans epoch 121:  0.5130572319030762
# loss sur train dans epoch 122:  0.5123668909072876
# loss sur train dans epoch 123:  0.5116831064224243
# loss sur train dans epoch 124:  0.5110048055648804
# loss sur train dans epoch 125:  0.5103305578231812
# loss sur train dans epoch 126:  0.509660542011261
# loss sur train dans epoch 127:  0.5089945793151855
# loss sur train dans epoch 128:  0.508333683013916
# loss sur train dans epoch 129:  0.5076782703399658
# loss sur train dans epoch 130:  0.5070267915725708
# loss sur train dans epoch 131:  0.506379246711731
# loss sur train dans epoch 132:  0.5057369470596313
# loss sur train dans epoch 133:  0.5050989985466003
# loss sur train dans epoch 134:  0.5044658780097961
# loss sur train dans epoch 135:  0.5038372874259949
# loss sur train dans epoch 136:  0.5032123327255249
# loss sur train dans epoch 137:  0.5025910139083862
# loss sur train dans epoch 138:  0.5019733309745789
# loss sur train dans epoch 139:  0.5013591051101685
# loss sur train dans epoch 140:  0.500748336315155
# loss sur train dans epoch 141:  0.5001410841941833
# loss sur train dans epoch 142:  0.4995371401309967
# loss sur train dans epoch 143:  0.4989383816719055
# loss sur train dans epoch 144:  0.4983436167240143
# loss sur train dans epoch 145:  0.49775218963623047
# loss sur train dans epoch 146:  0.4971640706062317
# loss sur train dans epoch 147:  0.4965790808200836
# loss sur train dans epoch 148:  0.4959973394870758
# loss sur train dans epoch 149:  0.4954186975955963
# loss sur train dans epoch 150:  0.49484315514564514
# loss sur train dans epoch 151:  0.49427667260169983
# loss sur train dans epoch 152:  0.49371248483657837
# loss sur train dans epoch 153:  0.49315136671066284
# loss sur train dans epoch 154:  0.49259334802627563
# loss sur train dans epoch 155:  0.4920387864112854
# loss sur train dans epoch 156:  0.49148836731910706
# loss sur train dans epoch 157:  0.4909420907497406
# loss sur train dans epoch 158:  0.49039897322654724
# loss sur train dans epoch 159:  0.4898586869239807
# loss sur train dans epoch 160:  0.48932117223739624
# loss sur train dans epoch 161:  0.4887865483760834
# loss sur train dans epoch 162:  0.4882546365261078
# loss sur train dans epoch 163:  0.48772549629211426
# loss sur train dans epoch 164:  0.487199068069458
# loss sur train dans epoch 165:  0.4866752624511719
# loss sur train dans epoch 166:  0.486154168844223
# loss sur train dans epoch 167:  0.4856360852718353
# loss sur train dans epoch 168:  0.48512163758277893
# loss sur train dans epoch 169:  0.4846106171607971
# loss sur train dans epoch 170:  0.4841020703315735
# loss sur train dans epoch 171:  0.4835960865020752
# loss sur train dans epoch 172:  0.48309260606765747
# loss sur train dans epoch 173:  0.4825916290283203
# loss sur train dans epoch 174:  0.48209309577941895
# loss sur train dans epoch 175:  0.48159700632095337
# loss sur train dans epoch 176:  0.4811033308506012
# loss sur train dans epoch 177:  0.4806119501590729
# loss sur train dans epoch 178:  0.4801231026649475
# loss sur train dans epoch 179:  0.4796365201473236
# loss sur train dans epoch 180:  0.47915229201316833
# loss sur train dans epoch 181:  0.4786704182624817
# loss sur train dans epoch 182:  0.4781908094882965
# loss sur train dans epoch 183:  0.4777134358882904
# loss sur train dans epoch 184:  0.4772384762763977
# loss sur train dans epoch 185:  0.47676604986190796
# loss sur train dans epoch 186:  0.47629719972610474
# loss sur train dans epoch 187:  0.4758315980434418
# loss sur train dans epoch 188:  0.4753681719303131
# loss sur train dans epoch 189:  0.4749068319797516
# loss sur train dans epoch 190:  0.47444766759872437
# loss sur train dans epoch 191:  0.47399061918258667
# loss sur train dans epoch 192:  0.4735356271266937
# loss sur train dans epoch 193:  0.4730827808380127
# loss sur train dans epoch 194:  0.4726320207118988
# loss sur train dans epoch 195:  0.4721832275390625
# loss sur train dans epoch 196:  0.4717366099357605
# loss sur train dans epoch 197:  0.4712919294834137
# loss sur train dans epoch 198:  0.4708499014377594
# loss sur train dans epoch 199:  0.47041040658950806
# loss sur train dans epoch 200:  0.46997278928756714
# loss sur train dans epoch 201:  0.4695371985435486
# loss sur train dans epoch 202:  0.4691036641597748
# loss sur train dans epoch 203:  0.4686719477176666
# loss sur train dans epoch 204:  0.46824216842651367
# loss sur train dans epoch 205:  0.4678143858909607
# loss sur train dans epoch 206:  0.46738848090171814
# loss sur train dans epoch 207:  0.46696439385414124
# loss sur train dans epoch 208:  0.46654224395751953
# loss sur train dans epoch 209:  0.4661219120025635
# loss sur train dans epoch 210:  0.46570348739624023
# loss sur train dans epoch 211:  0.46528688073158264
# loss sur train dans epoch 212:  0.46487244963645935
# loss sur train dans epoch 213:  0.46446046233177185
# loss sur train dans epoch 214:  0.46405029296875
# loss sur train dans epoch 215:  0.46364182233810425
# loss sur train dans epoch 216:  0.4632352888584137
# loss sur train dans epoch 217:  0.46283045411109924
# loss sur train dans epoch 218:  0.46242737770080566
# loss sur train dans epoch 219:  0.46202605962753296
# loss sur train dans epoch 220:  0.46162647008895874
# loss sur train dans epoch 221:  0.4612286686897278
# loss sur train dans epoch 222:  0.46083250641822815
# loss sur train dans epoch 223:  0.4604381024837494
# loss sur train dans epoch 224:  0.4600454866886139
# loss sur train dans epoch 225:  0.45965448021888733
# loss sur train dans epoch 226:  0.4592651426792145
# loss sur train dans epoch 227:  0.4588783383369446
# loss sur train dans epoch 228:  0.45849308371543884
# loss sur train dans epoch 229:  0.4581095576286316
# loss sur train dans epoch 230:  0.45772767066955566
# loss sur train dans epoch 231:  0.45734745264053345
# loss sur train dans epoch 232:  0.4569687843322754
# loss sur train dans epoch 233:  0.45659178495407104
# loss sur train dans epoch 234:  0.456216424703598
# loss sur train dans epoch 235:  0.45584267377853394
# loss sur train dans epoch 236:  0.4554705023765564
# loss sur train dans epoch 237:  0.4550999701023102
# loss sur train dans epoch 238:  0.4547309875488281
# loss sur train dans epoch 239:  0.45436352491378784
# loss sur train dans epoch 240:  0.45399776101112366
# loss sur train dans epoch 241:  0.45363372564315796
# loss sur train dans epoch 242:  0.4532717764377594
# loss sur train dans epoch 243:  0.4529111981391907
# loss sur train dans epoch 244:  0.4525522291660309
# loss sur train dans epoch 245:  0.45219478011131287
# loss sur train dans epoch 246:  0.4518389105796814
# loss sur train dans epoch 247:  0.45148444175720215
# loss sur train dans epoch 248:  0.45113152265548706
# loss sur train dans epoch 249:  0.4507800042629242
# loss sur train dans epoch 250:  0.45043015480041504
# loss sur train dans epoch 251:  0.45008164644241333
# loss sur train dans epoch 252:  0.449734628200531
# loss sur train dans epoch 253:  0.44938912987709045
# loss sur train dans epoch 254:  0.4490450322628021
# loss sur train dans epoch 255:  0.448702335357666
# loss sur train dans epoch 256:  0.4483610987663269
# loss sur train dans epoch 257:  0.44802141189575195
# loss sur train dans epoch 258:  0.44768303632736206
# loss sur train dans epoch 259:  0.44734615087509155
# loss sur train dans epoch 260:  0.44701069593429565
# loss sur train dans epoch 261:  0.4466765522956848
# loss sur train dans epoch 262:  0.4463438391685486
# loss sur train dans epoch 263:  0.44601258635520935
# loss sur train dans epoch 264:  0.44568267464637756
# loss sur train dans epoch 265:  0.4453541338443756
# loss sur train dans epoch 266:  0.4450269639492035
# loss sur train dans epoch 267:  0.4447011351585388
# loss sur train dans epoch 268:  0.44437718391418457
# loss sur train dans epoch 269:  0.44405466318130493
# loss sur train dans epoch 270:  0.4437333047389984
# loss sur train dans epoch 271:  0.4434133470058441
# loss sur train dans epoch 272:  0.44309478998184204
# loss sur train dans epoch 273:  0.44277748465538025
# loss sur train dans epoch 274:  0.4424614906311035
# loss sur train dans epoch 275:  0.44214683771133423
# loss sur train dans epoch 276:  0.44183349609375
# loss sur train dans epoch 277:  0.44152146577835083
# loss sur train dans epoch 278:  0.44121068716049194
# loss sur train dans epoch 279:  0.4409011900424957
# loss sur train dans epoch 280:  0.44059306383132935
# loss sur train dans epoch 281:  0.44028615951538086
# loss sur train dans epoch 282:  0.4399805963039398
# loss sur train dans epoch 283:  0.43967658281326294
# loss sur train dans epoch 284:  0.4393737316131592
# loss sur train dans epoch 285:  0.4390720725059509
# loss sur train dans epoch 286:  0.4387718141078949
# loss sur train dans epoch 287:  0.4384726583957672
# loss sur train dans epoch 288:  0.4381747841835022
# loss sur train dans epoch 289:  0.4378780722618103
# loss sur train dans epoch 290:  0.43758267164230347
# loss sur train dans epoch 291:  0.43728843331336975
# loss sur train dans epoch 292:  0.43699541687965393
# loss sur train dans epoch 293:  0.436703622341156
# loss sur train dans epoch 294:  0.4364129602909088
# loss sur train dans epoch 295:  0.4361235499382019
# loss sur train dans epoch 296:  0.4358353614807129
# loss sur train dans epoch 297:  0.4355483055114746
# loss sur train dans epoch 298:  0.43526244163513184
# loss sur train dans epoch 299:  0.4349777102470398
# loss sur train dans epoch 300:  0.4346941411495209
# loss sur train dans epoch 301:  0.43441176414489746
# loss sur train dans epoch 302:  0.4341304898262024
# loss sur train dans epoch 303:  0.4338504672050476
# loss sur train dans epoch 304:  0.4335714876651764
# loss sur train dans epoch 305:  0.4332936704158783
# loss sur train dans epoch 306:  0.4330170154571533
# loss sur train dans epoch 307:  0.4327414631843567
# loss sur train dans epoch 308:  0.432466983795166
# loss sur train dans epoch 309:  0.43219369649887085
# loss sur train dans epoch 310:  0.43192142248153687
# loss sur train dans epoch 311:  0.43165040016174316
# loss sur train dans epoch 312:  0.43138042092323303
# loss sur train dans epoch 313:  0.43111151456832886
# loss sur train dans epoch 314:  0.43084365129470825
# loss sur train dans epoch 315:  0.43057695031166077
# loss sur train dans epoch 316:  0.43031129240989685
# loss sur train dans epoch 317:  0.4300467073917389
# loss sur train dans epoch 318:  0.42978325486183167
# loss sur train dans epoch 319:  0.429520845413208
# loss sur train dans epoch 320:  0.42925944924354553
# loss sur train dans epoch 321:  0.428999125957489
# loss sur train dans epoch 322:  0.42873984575271606
# loss sur train dans epoch 323:  0.4284816384315491
# loss sur train dans epoch 324:  0.4282244145870209
# loss sur train dans epoch 325:  0.42796826362609863
# loss sur train dans epoch 326:  0.4277130961418152
# loss sur train dans epoch 327:  0.4274566173553467
# loss sur train dans epoch 328:  0.42720794677734375
# loss sur train dans epoch 329:  0.4269624352455139
# loss sur train dans epoch 330:  0.4267174303531647
# loss sur train dans epoch 331:  0.42647337913513184
# loss sur train dans epoch 332:  0.42623043060302734
# loss sur train dans epoch 333:  0.4259883761405945
# loss sur train dans epoch 334:  0.4257473051548004
# loss sur train dans epoch 335:  0.42550724744796753
# loss sur train dans epoch 336:  0.42526817321777344
# loss sur train dans epoch 337:  0.42503005266189575
# loss sur train dans epoch 338:  0.42479291558265686
# loss sur train dans epoch 339:  0.4245566427707672
# loss sur train dans epoch 340:  0.42432135343551636
# loss sur train dans epoch 341:  0.4240870475769043
# loss sur train dans epoch 342:  0.42385369539260864
# loss sur train dans epoch 343:  0.4236212372779846
# loss sur train dans epoch 344:  0.423389732837677
# loss sur train dans epoch 345:  0.423159122467041
# loss sur train dans epoch 346:  0.42292943596839905
# loss sur train dans epoch 347:  0.4227007031440735
# loss sur train dans epoch 348:  0.42247289419174194
# loss sur train dans epoch 349:  0.42224591970443726
# loss sur train dans epoch 350:  0.422019898891449
# loss sur train dans epoch 351:  0.42179474234580994
# loss sur train dans epoch 352:  0.42157047986984253
# loss sur train dans epoch 353:  0.4213472008705139
# loss sur train dans epoch 354:  0.4211246967315674
# loss sur train dans epoch 355:  0.42090311646461487
# loss sur train dans epoch 356:  0.4206823706626892
# loss sur train dans epoch 357:  0.42046254873275757
# loss sur train dans epoch 358:  0.4202435612678528
# loss sur train dans epoch 359:  0.4200253486633301
# loss sur train dans epoch 360:  0.4198080897331238
# loss sur train dans epoch 361:  0.4195917248725891
# loss sur train dans epoch 362:  0.4193761348724365
# loss sur train dans epoch 363:  0.4191613793373108
# loss sur train dans epoch 364:  0.4189475476741791
# loss sur train dans epoch 365:  0.4187344014644623
# loss sur train dans epoch 366:  0.4185222089290619
# loss sur train dans epoch 367:  0.41831082105636597
# loss sur train dans epoch 368:  0.4181002080440521
# loss sur train dans epoch 369:  0.4178904592990875
# loss sur train dans epoch 370:  0.4176815152168274
# loss sur train dans epoch 371:  0.41747337579727173
# loss sur train dans epoch 372:  0.4172660708427429
# loss sur train dans epoch 373:  0.4170595109462738
# loss sur train dans epoch 374:  0.41685381531715393
# loss sur train dans epoch 375:  0.41664886474609375
# loss sur train dans epoch 376:  0.41644468903541565
# loss sur train dans epoch 377:  0.416241317987442
# loss sur train dans epoch 378:  0.4160386621952057
# loss sur train dans epoch 379:  0.4158368706703186
# loss sur train dans epoch 380:  0.4156358242034912
# loss sur train dans epoch 381:  0.4154355525970459
# loss sur train dans epoch 382:  0.41523605585098267
# loss sur train dans epoch 383:  0.4150373041629791
# loss sur train dans epoch 384:  0.41483932733535767
# loss sur train dans epoch 385:  0.4146420955657959
# loss sur train dans epoch 386:  0.41444557905197144
# loss sur train dans epoch 387:  0.41424980759620667
# loss sur train dans epoch 388:  0.41405487060546875
# loss sur train dans epoch 389:  0.41386061906814575
# loss sur train dans epoch 390:  0.4136670231819153
# loss sur train dans epoch 391:  0.41347432136535645
# loss sur train dans epoch 392:  0.41328221559524536
# loss sur train dans epoch 393:  0.41309085488319397
# loss sur train dans epoch 394:  0.41290026903152466
# loss sur train dans epoch 395:  0.4127103388309479
# loss sur train dans epoch 396:  0.4125211834907532
# loss sur train dans epoch 397:  0.412332683801651
# loss sur train dans epoch 398:  0.41214489936828613
# loss sur train dans epoch 399:  0.4119578003883362
# loss sur train dans epoch 400:  0.4117714464664459
# loss sur train dans epoch 401:  0.4115857481956482
# loss sur train dans epoch 402:  0.4114007353782654
# loss sur train dans epoch 403:  0.4112164378166199
# loss sur train dans epoch 404:  0.41103285551071167
# loss sur train dans epoch 405:  0.4108499586582184
# loss sur train dans epoch 406:  0.4106677174568176
# loss sur train dans epoch 407:  0.4104860723018646
# loss sur train dans epoch 408:  0.4103052020072937
# loss sur train dans epoch 409:  0.4101250171661377
# loss sur train dans epoch 410:  0.40994542837142944
# loss sur train dans epoch 411:  0.4097664952278137
# loss sur train dans epoch 412:  0.4095882475376129
# loss sur train dans epoch 413:  0.40941065549850464
# loss sur train dans epoch 414:  0.4092337191104889
# loss sur train dans epoch 415:  0.4090574383735657
# loss sur train dans epoch 416:  0.4088817536830902
# loss sur train dans epoch 417:  0.40870675444602966
# loss sur train dans epoch 418:  0.4085324704647064
# loss sur train dans epoch 419:  0.40835875272750854
# loss sur train dans epoch 420:  0.4081856310367584
# loss sur train dans epoch 421:  0.408013254404068
# loss sur train dans epoch 422:  0.40784135460853577
# loss sur train dans epoch 423:  0.40767019987106323
# loss sur train dans epoch 424:  0.40749961137771606
# loss sur train dans epoch 425:  0.40732961893081665
# loss sur train dans epoch 426:  0.40716028213500977
# loss sur train dans epoch 427:  0.406991571187973
# loss sur train dans epoch 428:  0.40682345628738403
# loss sur train dans epoch 429:  0.4066559374332428
# loss sur train dans epoch 430:  0.4064890444278717
# loss sur train dans epoch 431:  0.40632280707359314
# loss sur train dans epoch 432:  0.40615716576576233
# loss sur train dans epoch 433:  0.4059921205043793
# loss sur train dans epoch 434:  0.4058276116847992
# loss sur train dans epoch 435:  0.4056638181209564
# loss sur train dans epoch 436:  0.40550050139427185
# loss sur train dans epoch 437:  0.4053378105163574
# loss sur train dans epoch 438:  0.40517574548721313
# loss sur train dans epoch 439:  0.40501418709754944
# loss sur train dans epoch 440:  0.4048532545566559
# loss sur train dans epoch 441:  0.40469279885292053
# loss sur train dans epoch 442:  0.4045329689979553
# loss sur train dans epoch 443:  0.40437373518943787
# loss sur train dans epoch 444:  0.4042150378227234
# loss sur train dans epoch 445:  0.40405696630477905
# loss sur train dans epoch 446:  0.4039004445075989
# loss sur train dans epoch 447:  0.4037436842918396
# loss sur train dans epoch 448:  0.4035870134830475
# loss sur train dans epoch 449:  0.4034322202205658
# loss sur train dans epoch 450:  0.4032772183418274
# loss sur train dans epoch 451:  0.40312275290489197
# loss sur train dans epoch 452:  0.40296825766563416
# loss sur train dans epoch 453:  0.40281566977500916
# loss sur train dans epoch 454:  0.4026627540588379
# loss sur train dans epoch 455:  0.402510404586792
# loss sur train dans epoch 456:  0.40235811471939087
# loss sur train dans epoch 457:  0.40220755338668823
# loss sur train dans epoch 458:  0.40205684304237366
# loss sur train dans epoch 459:  0.4019066393375397
# loss sur train dans epoch 460:  0.4017563760280609
# loss sur train dans epoch 461:  0.4016079902648926
# loss sur train dans epoch 462:  0.40145930647850037
# loss sur train dans epoch 463:  0.4013112187385559
# loss sur train dans epoch 464:  0.4011630415916443
# loss sur train dans epoch 465:  0.40101662278175354
# loss sur train dans epoch 466:  0.40087008476257324
# loss sur train dans epoch 467:  0.40072399377822876
# loss sur train dans epoch 468:  0.4005778729915619
# loss sur train dans epoch 469:  0.4004334807395935
# loss sur train dans epoch 470:  0.4002888798713684
# loss sur train dans epoch 471:  0.4001447260379791
# loss sur train dans epoch 472:  0.4000006318092346
# loss sur train dans epoch 473:  0.3998582065105438
# loss sur train dans epoch 474:  0.3997156023979187
# loss sur train dans epoch 475:  0.3995734751224518
# loss sur train dans epoch 476:  0.3994312584400177
# loss sur train dans epoch 477:  0.3992908298969269
# loss sur train dans epoch 478:  0.39915013313293457
# loss sur train dans epoch 479:  0.39900991320610046
# loss sur train dans epoch 480:  0.39887022972106934
# loss sur train dans epoch 481:  0.39873042702674866
# loss sur train dans epoch 482:  0.3985922932624817
# loss sur train dans epoch 483:  0.3984540104866028
# loss sur train dans epoch 484:  0.3983161449432373
# loss sur train dans epoch 485:  0.3981781601905823
# loss sur train dans epoch 486:  0.3980419635772705
# loss sur train dans epoch 487:  0.39790552854537964
# loss sur train dans epoch 488:  0.3977695107460022
# loss sur train dans epoch 489:  0.39763396978378296
# loss sur train dans epoch 490:  0.3974984288215637
# loss sur train dans epoch 491:  0.39736443758010864
# loss sur train dans epoch 492:  0.39723020792007446
# loss sur train dans epoch 493:  0.39709654450416565
# loss sur train dans epoch 494:  0.3969626724720001
# loss sur train dans epoch 495:  0.3968304991722107
# loss sur train dans epoch 496:  0.39669811725616455
# loss sur train dans epoch 497:  0.3965661823749542
# loss sur train dans epoch 498:  0.39643463492393494
# loss sur train dans epoch 499:  0.3963030278682709
# loss sur train dans epoch 500:  0.39617303013801575
# loss sur train dans epoch 501:  0.3960428237915039
# loss sur train dans epoch 502:  0.3959130346775055
# loss sur train dans epoch 503:  0.3957836627960205
# loss sur train dans epoch 504:  0.39565423130989075
# loss sur train dans epoch 505:  0.3955264091491699
# loss sur train dans epoch 506:  0.3953983187675476
# loss sur train dans epoch 507:  0.3952706456184387
# loss sur train dans epoch 508:  0.39514341950416565
# loss sur train dans epoch 509:  0.39501604437828064
# loss sur train dans epoch 510:  0.3948902487754822
# loss sur train dans epoch 511:  0.3947643041610718
# loss sur train dans epoch 512:  0.39463865756988525
# loss sur train dans epoch 513:  0.3945135474205017
# loss sur train dans epoch 514:  0.39438822865486145
# loss sur train dans epoch 515:  0.3942645192146301
# loss sur train dans epoch 516:  0.3941406011581421
# loss sur train dans epoch 517:  0.39401698112487793
# loss sur train dans epoch 518:  0.39389389753341675
# loss sur train dans epoch 519:  0.39377108216285706
# loss sur train dans epoch 520:  0.393648236989975
# loss sur train dans epoch 521:  0.39352691173553467
# loss sur train dans epoch 522:  0.39340537786483765
# loss sur train dans epoch 523:  0.3932841718196869
# loss sur train dans epoch 524:  0.39316338300704956
# loss sur train dans epoch 525:  0.3930424451828003
# loss sur train dans epoch 526:  0.39292311668395996
# loss sur train dans epoch 527:  0.39280346035957336
# loss sur train dans epoch 528:  0.3926842212677002
# loss sur train dans epoch 529:  0.39256536960601807
# loss sur train dans epoch 530:  0.392446905374527
# loss sur train dans epoch 531:  0.39232832193374634
# loss sur train dans epoch 532:  0.3922111392021179
# loss sur train dans epoch 533:  0.39209383726119995
# loss sur train dans epoch 534:  0.39197686314582825
# loss sur train dans epoch 535:  0.3918602168560028
# loss sur train dans epoch 536:  0.3917439877986908
# loss sur train dans epoch 537:  0.3916276693344116
# loss sur train dans epoch 538:  0.3915127217769623
# loss sur train dans epoch 539:  0.3913976550102234
# loss sur train dans epoch 540:  0.391282856464386
# loss sur train dans epoch 541:  0.3911684453487396
# loss sur train dans epoch 542:  0.3910544216632843
# loss sur train dans epoch 543:  0.39094021916389465
# loss sur train dans epoch 544:  0.390827476978302
# loss sur train dans epoch 545:  0.39071449637413025
# loss sur train dans epoch 546:  0.39060187339782715
# loss sur train dans epoch 547:  0.3904896378517151
# loss sur train dans epoch 548:  0.3903777003288269
# loss sur train dans epoch 549:  0.3902661204338074
# loss sur train dans epoch 550:  0.39015448093414307
# loss sur train dans epoch 551:  0.3900441527366638
# loss sur train dans epoch 552:  0.38993361592292786
# loss sur train dans epoch 553:  0.38982346653938293
# loss sur train dans epoch 554:  0.3897135853767395
# loss sur train dans epoch 555:  0.3896041214466095
# loss sur train dans epoch 556:  0.38949495553970337
# loss sur train dans epoch 557:  0.3893857002258301
# loss sur train dans epoch 558:  0.38927772641181946
# loss sur train dans epoch 559:  0.3891696333885193
# loss sur train dans epoch 560:  0.38906195759773254
# loss sur train dans epoch 561:  0.3889545798301697
# loss sur train dans epoch 562:  0.3888475298881531
# loss sur train dans epoch 563:  0.38874080777168274
# loss sur train dans epoch 564:  0.38863396644592285
# loss sur train dans epoch 565:  0.388528436422348
# loss sur train dans epoch 566:  0.3884226977825165
# loss sur train dans epoch 567:  0.3883172571659088
# loss sur train dans epoch 568:  0.3882122039794922
# loss sur train dans epoch 569:  0.38810744881629944
# loss sur train dans epoch 570:  0.3880029618740082
# loss sur train dans epoch 571:  0.3878987729549408
# loss sur train dans epoch 572:  0.387794554233551
# loss sur train dans epoch 573:  0.38769155740737915
# loss sur train dans epoch 574:  0.38758841156959534
# loss sur train dans epoch 575:  0.38748547434806824
# loss sur train dans epoch 576:  0.3873829245567322
# loss sur train dans epoch 577:  0.3872806429862976
# loss sur train dans epoch 578:  0.3871787190437317
# loss sur train dans epoch 579:  0.38707706332206726
# loss sur train dans epoch 580:  0.3869752287864685
# loss sur train dans epoch 581:  0.3868747651576996
# loss sur train dans epoch 582:  0.3867740333080292
# loss sur train dans epoch 583:  0.38667359948158264
# loss sur train dans epoch 584:  0.3865734934806824
# loss sur train dans epoch 585:  0.3864736557006836
# loss sur train dans epoch 586:  0.3863741159439087
# loss sur train dans epoch 587:  0.38627487421035767
# loss sur train dans epoch 588:  0.3861759603023529
# loss sur train dans epoch 589:  0.386077344417572
# loss sur train dans epoch 590:  0.3859785199165344
# loss sur train dans epoch 591:  0.3858809769153595
# loss sur train dans epoch 592:  0.38578322529792786
# loss sur train dans epoch 593:  0.3856857419013977
# loss sur train dans epoch 594:  0.3855885863304138
# loss sur train dans epoch 595:  0.38549166917800903
# loss sur train dans epoch 596:  0.3853950500488281
# loss sur train dans epoch 597:  0.3852987587451935
# loss sur train dans epoch 598:  0.38520264625549316
# loss sur train dans epoch 599:  0.3851069211959839
# loss sur train dans epoch 600:  0.3850114941596985
# loss sur train dans epoch 601:  0.3849157691001892
# loss sur train dans epoch 602:  0.384821355342865
# loss sur train dans epoch 603:  0.38472673296928406
# loss sur train dans epoch 604:  0.384632408618927
# loss sur train dans epoch 605:  0.3845382630825043
# loss sur train dans epoch 606:  0.3844445049762726
# loss sur train dans epoch 607:  0.3843509256839752
# loss sur train dans epoch 608:  0.38425764441490173
# loss sur train dans epoch 609:  0.3841646611690521
# loss sur train dans epoch 610:  0.38407188653945923
# loss sur train dans epoch 611:  0.3839794993400574
# loss sur train dans epoch 612:  0.38388723134994507
# loss sur train dans epoch 613:  0.3837953209877014
# loss sur train dans epoch 614:  0.38370367884635925
# loss sur train dans epoch 615:  0.38361188769340515
# loss sur train dans epoch 616:  0.38352125883102417
# loss sur train dans epoch 617:  0.3834303915500641
# loss sur train dans epoch 618:  0.3833397328853607
# loss sur train dans epoch 619:  0.3832494020462036
# loss sur train dans epoch 620:  0.383159339427948
# loss sur train dans epoch 621:  0.3830694854259491
# loss sur train dans epoch 622:  0.3829799294471741
# loss sur train dans epoch 623:  0.38289061188697815
# loss sur train dans epoch 624:  0.3828015923500061
# loss sur train dans epoch 625:  0.3827127516269684
# loss sur train dans epoch 626:  0.38262420892715454
# loss sur train dans epoch 627:  0.3825358748435974
# loss sur train dans epoch 628:  0.38244783878326416
# loss sur train dans epoch 629:  0.3823600709438324
# loss sur train dans epoch 630:  0.38227248191833496
# loss sur train dans epoch 631:  0.382185161113739
# loss sur train dans epoch 632:  0.38209813833236694
# loss sur train dans epoch 633:  0.3820113241672516
# loss sur train dans epoch 634:  0.3819247782230377
# loss sur train dans epoch 635:  0.38183847069740295
# loss sur train dans epoch 636:  0.3817519545555115
# loss sur train dans epoch 637:  0.3816665709018707
# loss sur train dans epoch 638:  0.3815809488296509
# loss sur train dans epoch 639:  0.3814956545829773
# loss sur train dans epoch 640:  0.38141050934791565
# loss sur train dans epoch 641:  0.3813256621360779
# loss sur train dans epoch 642:  0.3812410235404968
# loss sur train dans epoch 643:  0.3811565935611725
# loss sur train dans epoch 644:  0.38107240200042725
# loss sur train dans epoch 645:  0.3809884488582611
# loss sur train dans epoch 646:  0.38090476393699646
# loss sur train dans epoch 647:  0.3808212876319885
# loss sur train dans epoch 648:  0.3807380795478821
# loss sur train dans epoch 649:  0.38065505027770996
# loss sur train dans epoch 650:  0.38057225942611694
# loss sur train dans epoch 651:  0.3804897665977478
# loss sur train dans epoch 652:  0.3804074227809906
# loss sur train dans epoch 653:  0.3803253471851349
# loss sur train dans epoch 654:  0.3802434802055359
# loss sur train dans epoch 655:  0.380161851644516
# loss sur train dans epoch 656:  0.3800804018974304
# loss sur train dans epoch 657:  0.37999922037124634
# loss sur train dans epoch 658:  0.37991827726364136
# loss sur train dans epoch 659:  0.3798375129699707
# loss sur train dans epoch 660:  0.37975698709487915
# loss sur train dans epoch 661:  0.3796766996383667
# loss sur train dans epoch 662:  0.37959662079811096
# loss sur train dans epoch 663:  0.37951675057411194
# loss sur train dans epoch 664:  0.37943708896636963
# loss sur train dans epoch 665:  0.37935763597488403
# loss sur train dans epoch 666:  0.3792784810066223
# loss sur train dans epoch 667:  0.37919944524765015
# loss sur train dans epoch 668:  0.3791206479072571
# loss sur train dans epoch 669:  0.3790420889854431
# loss sur train dans epoch 670:  0.3789637088775635
# loss sur train dans epoch 671:  0.37888556718826294
# loss sur train dans epoch 672:  0.3788076341152191
# loss sur train dans epoch 673:  0.3787298798561096
# loss sur train dans epoch 674:  0.3786523640155792
# loss sur train dans epoch 675:  0.37857502698898315
# loss sur train dans epoch 676:  0.3784979283809662
# loss sur train dans epoch 677:  0.37842100858688354
# loss sur train dans epoch 678:  0.3783442974090576
# loss sur train dans epoch 679:  0.3782678246498108
# loss sur train dans epoch 680:  0.37819159030914307
# loss sur train dans epoch 681:  0.3781154751777649
# loss sur train dans epoch 682:  0.3780396282672882
# loss sur train dans epoch 683:  0.37796396017074585
# loss sur train dans epoch 684:  0.3778885006904602
# loss sur train dans epoch 685:  0.3778132200241089
# loss sur train dans epoch 686:  0.3777381181716919
# loss sur train dans epoch 687:  0.3776632249355316
# loss sur train dans epoch 688:  0.37758857011795044
# loss sur train dans epoch 689:  0.3775140941143036
# loss sur train dans epoch 690:  0.37743979692459106
# loss sur train dans epoch 691:  0.37736573815345764
# loss sur train dans epoch 692:  0.37729179859161377
# loss sur train dans epoch 693:  0.377218097448349
# loss sur train dans epoch 694:  0.37714463472366333
# loss sur train dans epoch 695:  0.3770712912082672
# loss sur train dans epoch 696:  0.3769982159137726
# loss sur train dans epoch 697:  0.3769252598285675
# loss sur train dans epoch 698:  0.37685254216194153
# loss sur train dans epoch 699:  0.3767799735069275
# loss sur train dans epoch 700:  0.37670761346817017
# loss sur train dans epoch 701:  0.37663543224334717
# loss sur train dans epoch 702:  0.37656348943710327
# loss sur train dans epoch 703:  0.3764916956424713
# loss sur train dans epoch 704:  0.3764200806617737
# loss sur train dans epoch 705:  0.37634867429733276
# loss sur train dans epoch 706:  0.3762774169445038
# loss sur train dans epoch 707:  0.3762063682079315
# loss sur train dans epoch 708:  0.37613552808761597
# loss sur train dans epoch 709:  0.37606483697891235
# loss sur train dans epoch 710:  0.3759942948818207
# loss sur train dans epoch 711:  0.3759239912033081
# loss sur train dans epoch 712:  0.37585383653640747
# loss sur train dans epoch 713:  0.37578386068344116
# loss sur train dans epoch 714:  0.37571412324905396
# loss sur train dans epoch 715:  0.3756445348262787
# loss sur train dans epoch 716:  0.37557512521743774
# loss sur train dans epoch 717:  0.37550589442253113
# loss sur train dans epoch 718:  0.37543681263923645
# loss sur train dans epoch 719:  0.3753679096698761
# loss sur train dans epoch 720:  0.3752991855144501
# loss sur train dans epoch 721:  0.37523066997528076
# loss sur train dans epoch 722:  0.375162273645401
# loss sur train dans epoch 723:  0.37509411573410034
# loss sur train dans epoch 724:  0.375026136636734
# loss sur train dans epoch 725:  0.37495824694633484
# loss sur train dans epoch 726:  0.37489053606987
# loss sur train dans epoch 727:  0.37482306361198425
# loss sur train dans epoch 728:  0.3747556805610657
# loss sur train dans epoch 729:  0.3746885657310486
# loss sur train dans epoch 730:  0.37462157011032104
# loss sur train dans epoch 731:  0.37455475330352783
# loss sur train dans epoch 732:  0.37448805570602417
# loss sur train dans epoch 733:  0.3744215965270996
# loss sur train dans epoch 734:  0.374355286359787
# loss sur train dans epoch 735:  0.3742890954017639
# loss sur train dans epoch 736:  0.37422317266464233
# loss sur train dans epoch 737:  0.3741573095321655
# loss sur train dans epoch 738:  0.3740916848182678
# loss sur train dans epoch 739:  0.37402617931365967
# loss sur train dans epoch 740:  0.37396082282066345
# loss sur train dans epoch 741:  0.37389567494392395
# loss sur train dans epoch 742:  0.3738306760787964
# loss sur train dans epoch 743:  0.37376582622528076
# loss sur train dans epoch 744:  0.37370115518569946
# loss sur train dans epoch 745:  0.3736365735530853
# loss sur train dans epoch 746:  0.3735722005367279
# loss sur train dans epoch 747:  0.3735080361366272
# loss sur train dans epoch 748:  0.3734440207481384
# loss sur train dans epoch 749:  0.3733800947666168
# loss sur train dans epoch 750:  0.37331634759902954
# loss sur train dans epoch 751:  0.373252809047699
# loss sur train dans epoch 752:  0.37318941950798035
# loss sur train dans epoch 753:  0.37312614917755127
# loss sur train dans epoch 754:  0.37306299805641174
# loss sur train dans epoch 755:  0.3730000853538513
# loss sur train dans epoch 756:  0.37293726205825806
# loss sur train dans epoch 757:  0.3728746473789215
# loss sur train dans epoch 758:  0.3728121519088745
# loss sur train dans epoch 759:  0.37274983525276184
# loss sur train dans epoch 760:  0.37268760800361633
# loss sur train dans epoch 761:  0.37262552976608276
# loss sur train dans epoch 762:  0.3725636899471283
# loss sur train dans epoch 763:  0.37250199913978577
# loss sur train dans epoch 764:  0.372440367937088
# loss sur train dans epoch 765:  0.3723789155483246
# loss sur train dans epoch 766:  0.3723176121711731
# loss sur train dans epoch 767:  0.3722565174102783
# loss sur train dans epoch 768:  0.3721955418586731
# loss sur train dans epoch 769:  0.37213465571403503
# loss sur train dans epoch 770:  0.3720739483833313
# loss sur train dans epoch 771:  0.3720134198665619
# loss sur train dans epoch 772:  0.3719530701637268
# loss sur train dans epoch 773:  0.3718928098678589
# loss sur train dans epoch 774:  0.37183263897895813
# loss sur train dans epoch 775:  0.3717726767063141
# loss sur train dans epoch 776:  0.371712863445282
# loss sur train dans epoch 777:  0.3716531991958618
# loss sur train dans epoch 778:  0.3715936541557312
# loss sur train dans epoch 779:  0.37153422832489014
# loss sur train dans epoch 780:  0.3714750111103058
# loss sur train dans epoch 781:  0.371415913105011
# loss sur train dans epoch 782:  0.37135690450668335
# loss sur train dans epoch 783:  0.37129807472229004
# loss sur train dans epoch 784:  0.3712393641471863
# loss sur train dans epoch 785:  0.37118080258369446
# loss sur train dans epoch 786:  0.3711223900318146
# loss sur train dans epoch 787:  0.37106412649154663
# loss sur train dans epoch 788:  0.371006041765213
# loss sur train dans epoch 789:  0.37094801664352417
# loss sur train dans epoch 790:  0.37089014053344727
# loss sur train dans epoch 791:  0.3708323836326599
# loss sur train dans epoch 792:  0.3707748055458069
# loss sur train dans epoch 793:  0.37071728706359863
# loss sur train dans epoch 794:  0.3706600069999695
# loss sur train dans epoch 795:  0.3706028163433075
# loss sur train dans epoch 796:  0.37054580450057983
# loss sur train dans epoch 797:  0.37048882246017456
# loss sur train dans epoch 798:  0.3704320192337036
# loss sur train dans epoch 799:  0.3703753650188446
# loss sur train dans epoch 800:  0.37031885981559753
# loss sur train dans epoch 801:  0.3702624440193176
# loss sur train dans epoch 802:  0.37020620703697205
# loss sur train dans epoch 803:  0.37015002965927124
# loss sur train dans epoch 804:  0.3700941205024719
# loss sur train dans epoch 805:  0.3700382113456726
# loss sur train dans epoch 806:  0.3699824810028076
# loss sur train dans epoch 807:  0.3699268698692322
# loss sur train dans epoch 808:  0.3698713481426239
# loss sur train dans epoch 809:  0.36981603503227234
# loss sur train dans epoch 810:  0.36976081132888794
# loss sur train dans epoch 811:  0.3697057068347931
# loss sur train dans epoch 812:  0.3696507513523102
# loss sur train dans epoch 813:  0.36959588527679443
# loss sur train dans epoch 814:  0.369541198015213
# loss sur train dans epoch 815:  0.36948657035827637
# loss sur train dans epoch 816:  0.36943209171295166
# loss sur train dans epoch 817:  0.3693777620792389
# loss sur train dans epoch 818:  0.3693235516548157
# loss sur train dans epoch 819:  0.3692694306373596
# loss sur train dans epoch 820:  0.3692155182361603
# loss sur train dans epoch 821:  0.36916160583496094
# loss sur train dans epoch 822:  0.3691079318523407
# loss sur train dans epoch 823:  0.36905431747436523
# loss sur train dans epoch 824:  0.3690008521080017
# loss sur train dans epoch 825:  0.36894744634628296
# loss sur train dans epoch 826:  0.3688942790031433
# loss sur train dans epoch 827:  0.36884111166000366
# loss sur train dans epoch 828:  0.36878812313079834
# loss sur train dans epoch 829:  0.36873525381088257
# loss sur train dans epoch 830:  0.36868250370025635
# loss sur train dans epoch 831:  0.3686298429965973
# loss sur train dans epoch 832:  0.3685773015022278
# loss sur train dans epoch 833:  0.3685249388217926
# loss sur train dans epoch 834:  0.3684726357460022
# loss sur train dans epoch 835:  0.36842045187950134
# loss sur train dans epoch 836:  0.36836838722229004
# loss sur train dans epoch 837:  0.36831650137901306
# loss sur train dans epoch 838:  0.36826467514038086
# loss sur train dans epoch 839:  0.36821332573890686
# loss sur train dans epoch 840:  0.36816203594207764
# loss sur train dans epoch 841:  0.36811092495918274
# loss sur train dans epoch 842:  0.36806002259254456
# loss sur train dans epoch 843:  0.368009090423584
# loss sur train dans epoch 844:  0.3679582476615906
# loss sur train dans epoch 845:  0.36790764331817627
# loss sur train dans epoch 846:  0.3678571581840515
# loss sur train dans epoch 847:  0.36780667304992676
# loss sur train dans epoch 848:  0.36775630712509155
# loss sur train dans epoch 849:  0.3677062392234802
# loss sur train dans epoch 850:  0.3676561415195465
# loss sur train dans epoch 851:  0.36760619282722473
# loss sur train dans epoch 852:  0.36755627393722534
# loss sur train dans epoch 853:  0.36750656366348267
# loss sur train dans epoch 854:  0.36745697259902954
# loss sur train dans epoch 855:  0.3674074709415436
# loss sur train dans epoch 856:  0.3673580586910248
# loss sur train dans epoch 857:  0.36730873584747314
# loss sur train dans epoch 858:  0.367259681224823
# loss sur train dans epoch 859:  0.3672105669975281
# loss sur train dans epoch 860:  0.3671615719795227
# loss sur train dans epoch 861:  0.3671127259731293
# loss sur train dans epoch 862:  0.367063969373703
# loss sur train dans epoch 863:  0.36701545119285583
# loss sur train dans epoch 864:  0.36696693301200867
# loss sur train dans epoch 865:  0.36691850423812866
# loss sur train dans epoch 866:  0.3668702244758606
# loss sur train dans epoch 867:  0.3668219745159149
# loss sur train dans epoch 868:  0.36677396297454834
# loss sur train dans epoch 869:  0.3667260408401489
# loss sur train dans epoch 870:  0.3666781783103943
# loss sur train dans epoch 871:  0.36663034558296204
# loss sur train dans epoch 872:  0.3665827512741089
# loss sur train dans epoch 873:  0.3665351867675781
# loss sur train dans epoch 874:  0.3664877414703369
# loss sur train dans epoch 875:  0.36644044518470764
# loss sur train dans epoch 876:  0.36639323830604553
# loss sur train dans epoch 877:  0.3663460612297058
# loss sur train dans epoch 878:  0.3662990927696228
# loss sur train dans epoch 879:  0.3662521541118622
# loss sur train dans epoch 880:  0.3662053644657135
# loss sur train dans epoch 881:  0.3661586344242096
# loss sur train dans epoch 882:  0.3661120533943176
# loss sur train dans epoch 883:  0.36606553196907043
# loss sur train dans epoch 884:  0.3660191297531128
# loss sur train dans epoch 885:  0.3659728467464447
# loss sur train dans epoch 886:  0.3659266531467438
# loss sur train dans epoch 887:  0.36588054895401
# loss sur train dans epoch 888:  0.3658345937728882
# loss sur train dans epoch 889:  0.36578863859176636
# loss sur train dans epoch 890:  0.36574286222457886
# loss sur train dans epoch 891:  0.3656971752643585
# loss sur train dans epoch 892:  0.36565160751342773
# loss sur train dans epoch 893:  0.3656060993671417
# loss sur train dans epoch 894:  0.36556077003479004
# loss sur train dans epoch 895:  0.36551544070243835
# loss sur train dans epoch 896:  0.3654702305793762
# loss sur train dans epoch 897:  0.365425169467926
# loss sur train dans epoch 898:  0.3653801679611206
# loss sur train dans epoch 899:  0.36533528566360474
# loss sur train dans epoch 900:  0.36529046297073364
# loss sur train dans epoch 901:  0.3652457594871521
# loss sur train dans epoch 902:  0.3652011752128601
# loss sur train dans epoch 903:  0.3651566505432129
# loss sur train dans epoch 904:  0.3651122450828552
# loss sur train dans epoch 905:  0.36506789922714233
# loss sur train dans epoch 906:  0.3650237023830414
# loss sur train dans epoch 907:  0.3649795651435852
# loss sur train dans epoch 908:  0.36493557691574097
# loss sur train dans epoch 909:  0.36489158868789673
# loss sur train dans epoch 910:  0.3648477792739868
# loss sur train dans epoch 911:  0.36480405926704407
# loss sur train dans epoch 912:  0.3647603392601013
# loss sur train dans epoch 913:  0.3647167682647705
# loss sur train dans epoch 914:  0.36467331647872925
# loss sur train dans epoch 915:  0.36462992429733276
# loss sur train dans epoch 916:  0.36458665132522583
# loss sur train dans epoch 917:  0.36454343795776367
# loss sur train dans epoch 918:  0.36450034379959106
# loss sur train dans epoch 919:  0.36445730924606323
# loss sur train dans epoch 920:  0.36441439390182495
# loss sur train dans epoch 921:  0.36437156796455383
# loss sur train dans epoch 922:  0.3643288314342499
# loss sur train dans epoch 923:  0.3642861843109131
# loss sur train dans epoch 924:  0.36424359679222107
# loss sur train dans epoch 925:  0.3642011284828186
# loss sur train dans epoch 926:  0.3641587793827057
# loss sur train dans epoch 927:  0.3641164302825928
# loss sur train dans epoch 928:  0.3640742301940918
# loss sur train dans epoch 929:  0.3640320897102356
# loss sur train dans epoch 930:  0.36399006843566895
# loss sur train dans epoch 931:  0.36394816637039185
# loss sur train dans epoch 932:  0.36390623450279236
# loss sur train dans epoch 933:  0.3638644814491272
# loss sur train dans epoch 934:  0.3638227581977844
# loss sur train dans epoch 935:  0.3637811541557312
# loss sur train dans epoch 936:  0.36373966932296753
# loss sur train dans epoch 937:  0.36369824409484863
# loss sur train dans epoch 938:  0.36365681886672974
# loss sur train dans epoch 939:  0.36361560225486755
# loss sur train dans epoch 940:  0.36357441544532776
# loss sur train dans epoch 941:  0.3635333180427551
# loss sur train dans epoch 942:  0.36349231004714966
# loss sur train dans epoch 943:  0.36345136165618896
# loss sur train dans epoch 944:  0.36341050267219543
# loss sur train dans epoch 945:  0.36336976289749146
# loss sur train dans epoch 946:  0.36332911252975464
# loss sur train dans epoch 947:  0.3632884919643402
# loss sur train dans epoch 948:  0.36324799060821533
# loss sur train dans epoch 949:  0.36320754885673523
# loss sur train dans epoch 950:  0.3631671965122223
# loss sur train dans epoch 951:  0.3631269335746765
# loss sur train dans epoch 952:  0.3630867600440979
# loss sur train dans epoch 953:  0.3630466163158417
# loss sur train dans epoch 954:  0.3630066215991974
# loss sur train dans epoch 955:  0.3629666864871979
# loss sur train dans epoch 956:  0.36292681097984314
# loss sur train dans epoch 957:  0.3628869950771332
# loss sur train dans epoch 958:  0.36284729838371277
# loss sur train dans epoch 959:  0.36280766129493713
# loss sur train dans epoch 960:  0.36276811361312866
# loss sur train dans epoch 961:  0.36272865533828735
# loss sur train dans epoch 962:  0.3626892864704132
# loss sur train dans epoch 963:  0.3626498878002167
# loss sur train dans epoch 964:  0.36261069774627686
# loss sur train dans epoch 965:  0.3625715672969818
# loss sur train dans epoch 966:  0.36253246665000916
# loss sur train dans epoch 967:  0.36249345541000366
# loss sur train dans epoch 968:  0.3624545633792877
# loss sur train dans epoch 969:  0.36241573095321655
# loss sur train dans epoch 970:  0.36237695813179016
# loss sur train dans epoch 971:  0.36233821511268616
# loss sur train dans epoch 972:  0.3622996211051941
# loss sur train dans epoch 973:  0.362261027097702
# loss sur train dans epoch 974:  0.3622226119041443
# loss sur train dans epoch 975:  0.36218422651290894
# loss sur train dans epoch 976:  0.36214590072631836
# loss sur train dans epoch 977:  0.36210766434669495
# loss sur train dans epoch 978:  0.36206942796707153
# loss sur train dans epoch 979:  0.36203140020370483
# loss sur train dans epoch 980:  0.36199337244033813
# loss sur train dans epoch 981:  0.3619554042816162
# loss sur train dans epoch 982:  0.36191755533218384
# loss sur train dans epoch 983:  0.36187976598739624
# loss sur train dans epoch 984:  0.36184200644493103
# loss sur train dans epoch 985:  0.36180436611175537
# loss sur train dans epoch 986:  0.3617668151855469
# loss sur train dans epoch 987:  0.36172929406166077
# loss sur train dans epoch 988:  0.3616918623447418
# loss sur train dans epoch 989:  0.36165449023246765
# loss sur train dans epoch 990:  0.36161720752716064
# loss sur train dans epoch 991:  0.3615799844264984
# loss sur train dans epoch 992:  0.36154282093048096
# loss sur train dans epoch 993:  0.36150577664375305
# loss sur train dans epoch 994:  0.36146876215934753
# loss sur train dans epoch 995:  0.3614317774772644
# loss sur train dans epoch 996:  0.361395001411438
# loss sur train dans epoch 997:  0.3613581359386444
# loss sur train dans epoch 998:  0.36132144927978516
# loss sur train dans epoch 999:  0.3612847924232483

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.4 Simplification de SGD avec torch.optim </font><font color='#87CEFA'> torch.optim</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. Initialisation d'un Modèle de Réseau de Neurones pour la Classification  avec PyTorch</font></h3>

# %%
def init_model_auto(nx, nh, ny, eta):
    model = torch.nn.Sequential(
        torch.nn.Linear(nx, nh), # Couche linéaire d'entrée à la couche cachée
        torch.nn.ReLU(),         # Fonction d'activation ReLU pour la couche cachée max(0, z)
        torch.nn.Linear(nh, ny), # Couche linéaire de la couche cachée à la couche de sortie
        torch.nn.Softmax(dim=1)  # Fonction d'activation Softmax pour la couche de sortie (classification du multiclasse)
        #torch.nn.Sigmoid()
        
    )
    # Définition de la fonction de perte CrossEntropyLoss pour une tâche de classification multiclasse
    loss = torch.nn.CrossEntropyLoss()
    # Définition de l'optimiseur stochastique de descente de gradient (SGD) avec le taux d'apprentissage (eta) spécifié
    optim = torch.optim.SGD(model.parameters(), lr=eta)
    return model, loss, optim

# %% [markdown]
# <h3><font color='#1E90FF'> B. Application</font></h3>

# %%
N_epoch = 100 #nombre des epoch
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate
#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
# Convertir les arrays NumPy en tensors PyTorch
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.int64)

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []

#initialiser les paramètres du modèle 
model_auto, loss_auto, optim_auto = init_model_auto(2, 4, 2, 0.02)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    loss_glob = 0 #Réinitialiser la perte  du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[j:i * batch, :]
        Y_epoch = Y[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.    
    if (N % batch != 0 and i ==  N // batch ) : 
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[ j : N, :]
        Y_epoch = Y[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss_glob /= (N // batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} : ", loss_glob.item())
    loss_history.append(loss_glob.item())
    
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 :  0.7110154032707214
# loss sur train dans epoch 1 :  0.7038998603820801
# loss sur train dans epoch 2 :  0.6968902349472046
# loss sur train dans epoch 3 :  0.6900039911270142
# loss sur train dans epoch 4 :  0.6832350492477417
# loss sur train dans epoch 5 :  0.6765393018722534
# loss sur train dans epoch 6 :  0.6699451208114624
# loss sur train dans epoch 7 :  0.6634668111801147
# loss sur train dans epoch 8 :  0.6571285128593445
# loss sur train dans epoch 9 :  0.6509382724761963
# loss sur train dans epoch 10 :  0.6448994874954224
# loss sur train dans epoch 11 :  0.6389721632003784
# loss sur train dans epoch 12 :  0.6330785751342773
# loss sur train dans epoch 13 :  0.6272883415222168
# loss sur train dans epoch 14 :  0.6216424107551575
# loss sur train dans epoch 15 :  0.6160999536514282
# loss sur train dans epoch 16 :  0.6106903553009033
# loss sur train dans epoch 17 :  0.6054092645645142
# loss sur train dans epoch 18 :  0.6002484560012817
# loss sur train dans epoch 19 :  0.595199465751648
# loss sur train dans epoch 20 :  0.590251624584198
# loss sur train dans epoch 21 :  0.5853930115699768
# loss sur train dans epoch 22 :  0.5805869102478027
# loss sur train dans epoch 23 :  0.5757575035095215
# loss sur train dans epoch 24 :  0.5709863901138306
# loss sur train dans epoch 25 :  0.566267192363739
# loss sur train dans epoch 26 :  0.5615299940109253
# loss sur train dans epoch 27 :  0.5567867159843445
# loss sur train dans epoch 28 :  0.5520726442337036
# loss sur train dans epoch 29 :  0.5473819971084595
# loss sur train dans epoch 30 :  0.5427125692367554
# loss sur train dans epoch 31 :  0.5380604267120361
# loss sur train dans epoch 32 :  0.5334492325782776
# loss sur train dans epoch 33 :  0.5288059711456299
# loss sur train dans epoch 34 :  0.5240076780319214
# loss sur train dans epoch 35 :  0.5191470384597778
# loss sur train dans epoch 36 :  0.5143154263496399
# loss sur train dans epoch 37 :  0.5095185041427612
# loss sur train dans epoch 38 :  0.5046905279159546
# loss sur train dans epoch 39 :  0.4998825192451477
# loss sur train dans epoch 40 :  0.4951291084289551
# loss sur train dans epoch 41 :  0.49043789505958557
# loss sur train dans epoch 42 :  0.48585882782936096
# loss sur train dans epoch 43 :  0.4813612103462219
# loss sur train dans epoch 44 :  0.4769420623779297
# loss sur train dans epoch 45 :  0.4726155400276184
# loss sur train dans epoch 46 :  0.4683874547481537
# loss sur train dans epoch 47 :  0.4641682505607605
# loss sur train dans epoch 48 :  0.46002036333084106
# loss sur train dans epoch 49 :  0.4559861123561859
# loss sur train dans epoch 50 :  0.45206665992736816
# loss sur train dans epoch 51 :  0.4482645094394684
# loss sur train dans epoch 52 :  0.44458135962486267
# loss sur train dans epoch 53 :  0.44101816415786743
# loss sur train dans epoch 54 :  0.4375752806663513
# loss sur train dans epoch 55 :  0.4342525601387024
# loss sur train dans epoch 56 :  0.4310036599636078
# loss sur train dans epoch 57 :  0.4277164041996002
# loss sur train dans epoch 58 :  0.42454513907432556
# loss sur train dans epoch 59 :  0.42148858308792114
# loss sur train dans epoch 60 :  0.4185447096824646
# loss sur train dans epoch 61 :  0.4157114624977112
# loss sur train dans epoch 62 :  0.41301974654197693
# loss sur train dans epoch 63 :  0.41047435998916626
# loss sur train dans epoch 64 :  0.40806251764297485
# loss sur train dans epoch 65 :  0.40574613213539124
# loss sur train dans epoch 66 :  0.403522253036499
# loss sur train dans epoch 67 :  0.4013877809047699
# loss sur train dans epoch 68 :  0.39933955669403076
# loss sur train dans epoch 69 :  0.3973856270313263
# loss sur train dans epoch 70 :  0.395511656999588
# loss sur train dans epoch 71 :  0.3937145471572876
# loss sur train dans epoch 72 :  0.3919912576675415
# loss sur train dans epoch 73 :  0.39033883810043335
# loss sur train dans epoch 74 :  0.3887542188167572
# loss sur train dans epoch 75 :  0.3872346580028534
# loss sur train dans epoch 76 :  0.38577723503112793
# loss sur train dans epoch 77 :  0.38437941670417786
# loss sur train dans epoch 78 :  0.3830384314060211
# loss sur train dans epoch 79 :  0.38161033391952515
# loss sur train dans epoch 80 :  0.38018763065338135
# loss sur train dans epoch 81 :  0.3788447082042694
# loss sur train dans epoch 82 :  0.37756672501564026
# loss sur train dans epoch 83 :  0.37633445858955383
# loss sur train dans epoch 84 :  0.375149667263031
# loss sur train dans epoch 85 :  0.3740057051181793
# loss sur train dans epoch 86 :  0.37290269136428833
# loss sur train dans epoch 87 :  0.3718535900115967
# loss sur train dans epoch 88 :  0.3708544075489044
# loss sur train dans epoch 89 :  0.3698873519897461
# loss sur train dans epoch 90 :  0.36895397305488586
# loss sur train dans epoch 91 :  0.36805349588394165
# loss sur train dans epoch 92 :  0.367185115814209
# loss sur train dans epoch 93 :  0.36634403467178345
# loss sur train dans epoch 94 :  0.3655354380607605
# loss sur train dans epoch 95 :  0.3647511601448059
# loss sur train dans epoch 96 :  0.363993376493454
# loss sur train dans epoch 97 :  0.363262414932251
# loss sur train dans epoch 98 :  0.3625534176826477
# loss sur train dans epoch 99 :  0.36187031865119934

# %% [markdown]
# <center>
# 	<h2 style="color:#e56b6f">
# 		<b>
# 			2.5 Application à MNIST
# 		</b>
# 	</h2>
# </center>

# %%
# Load the MNIST dataset
from tensorflow.keras.datasets import mnist

# (train_images, train_labels) : Ensemble d'entraînement
# (test_images, test_labels) : Ensemble de test
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Aplatir les images du jeu de données en vecteurs
test_images = test_images.reshape((test_images.shape[0],-1))
train_images = train_images.reshape((train_images.shape[0], -1))

# %%
N_epoch = 100 #nombre des epoch
batch = 256 # taille du batch
N = train_images.shape[0] # taille des donnees
eta =  0.01 #  learning rate
# le nombre de classes (0 --> 9)
nombre_de_classes = np.unique(test_labels).shape[0] 
# Convertir les arrays NumPy en tensors PyTorch
train_images = torch.tensor(train_images, dtype=torch.float32)
train_labels = torch.tensor(train_labels, dtype=torch.int64)
test_images = torch.tensor(test_images, dtype=torch.float32)
test_labels = torch.tensor(test_labels, dtype=torch.int64)

# %%
# dictionnaire pour stocker la perte du modèle pour chaque époque (train)
loss_history = []
# dictionnaire pour stocker la perte du modèle pour chaque époque (test-validation)
loss_validation_history = []

#initialiser les paramètres du modèle 
model_auto, loss_auto, optim_auto = init_model_auto(train_images.shape[1], 5, nombre_de_classes, eta)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    loss_glob , loss_val = 0 , 0 #Réinitialiser la perte  du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = train_images[j:i * batch, :]
        Y_epoch = train_labels[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los 
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.     
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données 
        X_epoch = train_images[ j : N, :]
        Y_epoch = train_labels[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss_glob /=(N // batch) 
    loss_val = loss_auto(model_auto(test_images), test_labels)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoche {epoch} est : ", loss_glob.item())
    #Afficher la perte et la précision calculées sur l'ensemble de Validation pour chaque époque.
    print(f"loss sur validation  dans epoche {epoch} est : ", loss_val.item())
    loss_history.append(loss_glob.item())
    loss_validation_history.append(loss_val.item())

# %%
# Tracer la courbe de la perte sur l'ensemble d'entraînement et de validation au fil des itérations
plt.plot(loss_history, label='Entraînement')
plt.plot(loss_validation_history, label='Validation')
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.legend()  # Ajouter une légende pour distinguer les courbes
plt.show()
