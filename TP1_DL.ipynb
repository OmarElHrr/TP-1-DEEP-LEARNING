# %% [markdown]
# <div style="text-align:center; border-bottom: 2px solid #FF7E7E;">
#     <h1><font color='#FF0000'>TP 1 : DEEP LEARNING</font></h1>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">réalisé par :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Assklou Meriem</li>
# <li>El Hariri Omar</li>
# <li>Louardi Ikram</li>
# <li>Mesrar Hamza </li>
# <li>Nabouzi Yasser</li>
# </ul>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">Encadre par  :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Prof. Khalfi Hamza</li>
# </ul>
# </div>
# </div>

# %% [markdown]
# <div style="padding-top:1px;padding-left:20px;">

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 1 – Formalisation mathematique</font></h2>
# </div>

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. A quoi servent les ensembles d’apprentissage, de validation et de test ?
#
# </font>

# %% [markdown]
# - Les ensembles d'apprentissage, de validation et de test sont utilisés respectivement pour entraîner un modèle, ajuster les hyperparamètres, et évaluer sa performance finale. Ils contribuent à éviter le surajustement et fournissent une évaluation impartiale sur des données non vues pendant l'entraînement.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. Quelle est l’influence du nombre $N$ d’exemples ?
#
# </font>

# %% [markdown]
# - Le nombre $ N $ d'exemples dans l'ensemble d'apprentissage peut influencer la performance du modèle. Un nombre insuffisant peut entraîner un surajustement, tandis qu'un grand nombre peut aider le modèle à généraliser mieux aux nouvelles données,

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 3. Pourquoi est-il important d’ajouter des fonctions d’activation entre des transformations lineaires ?
#
# </font>

# %% [markdown]
# - L'ajout de fonctions d'activation entre des transformations linéaires introduit une non-linéarité, permettant au modèle d'apprendre des motifs complexes et de représenter des relations non linéaires entre les caractéristiques.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 4. Quelles sont les tailles $ n_{x}, n_{h}, n_{y} $ sur la figure 1  ? En pratique, comment ces tailles sont-elles choisies ?
#
# </font>

# %% [markdown]
# <div style="text-align:center;">
# <img src="./model.png"  width="600">
# </div>

# %% [markdown]
# - $ n_{x} $ = 2 : Nombre d'entrées $ (n_{x}) $ Correspond au nombre de Variables dans les données .
# - $ n_{h} $ = 4 : Nombre de neurones cachés .
# - $ n_{y} $ : Nombre de sorties  (pour la classification ce nombre egale a nombre des classes dans les données)

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 5. Que représentent les vecteurs $ y $ et $ \hat{y} $ ? Quelle est la différence entre ces deux quantités ?
#
# </font>

# %% [markdown]
# - $ \hat{y} $ : est généralement la sortie du modèle après avoir appliqué la fonction d'activation softmax.un vecteur de probabilités normalisées. représente la probabilité estimée d'appartenir à la classe correspondante.
# - $ y $ : représente le vecteur des vraies étiquettes de classe associées aux exemples d'entraînement.
# - $ \hat{y} $ est la prédiction du modèle, tandis que $ y $ est la vérité de terrain.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 6. Pourquoi utiliser une fonction $ SoftMax $ en sortie ?
#
# </font>

# %% [markdown]
# - La fonction $ softmax $ est utilisée en sortie des réseaux de neurones pour convertir les scores en probabilités, facilitant l'interprétation des prédictions et permettant l'utilisation de la rétropropagation avec une fonction de perte comme l'entropie croisée pour l'entraînement

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 7. Écrire les équations mathématiques permettant d'effectuer la passe forward du réseau de neurones, produisant successivement $ \tilde{h}, \hat{h}, \tilde{y}, $ et $ \hat{y} $ à partir de $ x $.
#
# </font>

# %% [markdown]
# - Combinaison linéaire pour la couche cachée :
#
#     $$ \tilde{h} = W_{h} \times x + b_{h} $$
#
# - Activation de la couche cachée ( avec la fonction d'activation tanh ) :
#
#     $$ \hat{h} = tanh(\tilde{h}) $$
#
# - Combinaison linéaire pour la couche de sortie :
#
#   $$ \tilde{y} = W_{y} \times \hat{h} + b_{y} $$
#
# - Activation de la couche de sortie avec softmax :
#
#    $$ \hat{y} = softmax(\tilde{y}) $$

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 8. Pendant l’apprentissage, on cherche à minimiser la fonction de coût. Pour l’entropie croisée et l’erreur quadratique, comment les $ \hat{y}_i $ doivent-ils varier pour faire diminuer la loss ?
#
# </font>

# %% [markdown]
# - Pour minimiser l'entropie croisée, $ \hat{y}_i $  les doivent s'ajuster vers les valeurs réelles, augmentant lorsque $ y_i $
# est 1 et diminuant lorsque $ \hat{y} $  est 0. Pour l'erreur quadratique, l'ajustement vise à réduire la différence quadratique entre
# $ \hat{y}_i $  et $ y_i $

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 9. En quoi ces fonctions sont-elles plus adaptées aux problèmes de classification ou de régression ?
#
# </font>

# %% [markdown]
# - L'entropie croisée est adaptée à la classification en mesurant la divergence de probabilité, tandis que l'erreur quadratique est appropriée à la régression en évaluant les écarts entre prédictions et valeurs réelles.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 10. Quels semblent etre les avantages et inconvenients des diverses variantes de descente de gradient entre les versions classique, stochastique sur mini-batch et stochastique online ? Laquelle semble la plus raisonnable a utiliser dans le cas general ?
#
# </font>

# %% [markdown]
# | Method                                         | Avantages                                                      | Inconvénients                                                                                                                                                               |
# | ---------------------------------------------- | -------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Descente de Gradient Classique (Batch Gradient Descent) | - Convergence stable vers un minimum global en utilisant l'ensemble des données d'entraînement. | - Peut être coûteuse en termes de mémoire et de calcul, surtout pour de grands ensembles de données. - Les mises à jour ne sont effectuées qu'après avoir parcouru l'ensemble des données. |
# | Descente de Gradient Stochastique (Stochastic Gradient Descent - SGD) sur Mini-Batch | - Moins exigeante en termes de mémoire et de calcul, mise à jour des poids à chaque mini-batch, ce qui peut conduire à une convergence plus rapide. | - Moins stable que la descente de gradient classique en raison de l'aspect stochastique. - Les mises à jour fréquentes peuvent rendre la convergence plus bruitée, mais peuvent être utiles pour sortir de minima locaux. |
# | Descente de Gradient Stochastique Online     | - Mise à jour des poids après chaque exemple d'entraînement, adaptée aux flux de données en ligne. - Réagit rapidement aux changements de distribution. | - Plus sujette au bruit, peut converger vers des minima locaux. - Peut être moins stable que SGD sur mini-batch.     |

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 11. Quelle est l’influence du learning rate $ η $ sur l’apprentissage ?
#
# </font>

# %% [markdown]
# - Le taux d'apprentissage (η) dans le deep learning influence la convergence du modèle. Un taux trop élevé peut entraîner des instabilités et une convergence inefficace, tandis qu'un taux trop faible peut ralentir l'apprentissage. Trouver un équilibre est crucial pour optimiser la performance et la stabilité du modèle.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 12. Comparer la complexité (en fonction du nombre de couches du réseau)  du calcul des gradients de la loss par rapport aux paramètres, en utilisant l'approche naïve et l'algorithme de l’algorithme de backprop .
#
# </font>

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 13. Quel critère doit respecter l’architecture du réseau pour permettre la backpropagation ?
#
# </font>

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 14.La fonction $ SoftMax $ et la loss de cross-entropy sont souvent utilisées ensemble et leur gradient est très simple. Montrez que la loss se simplifie en :
# </font>

# %% [markdown]
# $$ l = - \sum_{i} y_i \tilde{y}_i + \log( \sum_{i} \exp(\tilde{y}_i) )$$

# %% [markdown]
# - on a:    $$ l(y, \hat{y}) = -\sum_{i} y_i \log(\hat{y}_i) $$

# %% [markdown]
# - et : $$ \hat{y} = \text{softmax}(\tilde{y}) $$

# %% [markdown]
# $$ \text{softmax}(\mathbf{\tilde{y}})_i = \frac{e^{\tilde{y}_i}}{\sum_{j=1}^{n} e^{\tilde{y}_j}} $$

# %% [markdown]
#    $$ l(y, \hat{y}) = -\sum_{i} y_i \log(\text{softmax}(\mathbf{\tilde{y}})_i) $$

# %% [markdown]
# $$ \log(\text{softmax}(\mathbf{\tilde{y}})_i) = \log\left(\frac{e^{\tilde{y}_i}}{\sum_{j=1}^{n} e^{\tilde{y}_j}}\right) = \log(e^{\tilde{y}_i}) - \log\left(\sum_{j=1}^{n} e^{\tilde{y}_j}\right)
# $$

# %% [markdown]
#   $$ l(y, \hat{y}) = -\sum_{i} y_i (\log(e^{\tilde{y}_i}) - \log\left(\sum_{j=1}^{n} e^{\tilde{y}_j}\right))  $$

# %% [markdown]
#    $$ l(y, \hat{y}) = -\sum_{i} y_i \tilde{y}_i + \sum_{i} y_i  \log\left(\sum_{i=1}^{n} e^{\tilde{y}_i}\right)  et   \sum_{i} y_i  = 1$$

# %% [markdown]
# $$ l = - \sum_{i} y_i \tilde{y}_i + \log( \sum_{i} \exp(\tilde{y}_i) )$$

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 2 – Implémentation </font></h2>
# </div>

# %%
import torch.nn as nn #  module neuronal
import torch.nn.functional as F #utililitaire de loss fonctionelle
import torch.optim as optim # algorithme d'optimisation
import torch.utils.data as data # dataset,  dataLoader
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_classification

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.1 Forward et backward manuels</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones</font></h3>

# %%
def init_params(nx, nh, ny):
   # nx :  Le nombre de variables d'entrée.
   # nh: Le nombre de neurones dans la couche cachée.
   # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx))
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1))
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh))
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1))

    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3><font color='#1E90FF'> B. la fonction qui effectue la propagation avant</font></h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1'] #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                           # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2']# Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0) # Application de la fonction softmax

    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }

    return outputs

# %% [markdown]
# <h3><font color='#1E90FF'> C. la fonction de Perte et Taux de Précision</font></h3>

# %%
def loss_accuracy(Yhat, Y):

    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0)) #La perte est calculée en utilisant la cross-entropy

    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)

    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)

     #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3><font color='#1E90FF'> D. Propagation du Gradient pour la Mise à Jour des Paramètres</font></h3>

# %%
def backward(params, outputs,  Y):

    # Initialisation des gradients à zéro
    dW1 = torch.zeros_like(params['W1'])
    dB1 = torch.zeros_like(params['B1'])
    dW2 = torch.zeros_like(params['W2'])
    dB2 = torch.zeros_like(params['B2'])

    # Calcul du gradient de la couche de sortie
    dZ2 = outputs['Yhat'] - Y
    dW2 += torch.mm(dZ2, outputs['A1'].t()) / Y.shape[1]
    dB2 += torch.sum(dZ2, dim=1, keepdim=True) / Y.shape[1]

    # Calcul du gradient de la couche cachée
    dZ1 = torch.mm(params['W2'].t(), dZ2) * (1 - torch.tanh(outputs['Z1'])**2)
    dW1 += torch.mm(dZ1, outputs['X'].t()) / Y.shape[1]
    dB1 += torch.sum(dZ1, dim=1, keepdim=True) / Y.shape[1]

    gradients = {
        'dW1': dW1,
        'dB1': dB1,
        'dW2': dW2,
        'dB2': dB2
    }

    return gradients

# %% [markdown]
# <h3><font color='#1E90FF'> E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres</font></h3>

# %%
def sgd(params, grads, eta):
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            params[par] = params[par] - eta * grads['d' + par] # Mise à Jour des Paramètres

    return params

# %% [markdown]
# <h3><font color='#1E90FF'> F. Application</font></h3>

# %%
N_epoch = 200 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)
#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()
# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )

        j = i * batch
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta)
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc = acc*100 / (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc)
    loss_history.append(loss)

    # affichage du frontière de décision pour chaque 20 epoch
    if epoch % 20 == 0:
        # Générer une grille d'échantillonnage pour l'espace de caractéristiques
        x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
        y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

        # Préparer les données pour les prédictions sur la grille
        grid_data = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32).t()
        grid_cach = forward(params, grid_data)
        Z = torch.argmax(grid_cach['Yhat'], dim=0)
        Z = Z.reshape(xx.shape)

        # Affichage de la frontière de décision et des points de données
        plt.contourf(xx, yy, Z, alpha=0.3)
        plt.scatter(X[0, :], X[1, :], c=Y_tensor.numpy(), edgecolors='k', marker='o')
        plt.xlabel('X 1')
        plt.ylabel('X 2')
        plt.title('Frontière de Décision du Modèle')
        plt.show()
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.7443078756332397
# la precision sur train dans epoch 0 est:  35.0
# loss sur train dans epoch 1 est:  0.7222777009010315
# la precision sur train dans epoch 1 est:  43.99999999999999
# loss sur train dans epoch 2 est:  0.7018430233001709
# la precision sur train dans epoch 2 est:  48.99999999999999
# loss sur train dans epoch 3 est:  0.6825467348098755
# la precision sur train dans epoch 3 est:  54.0
# loss sur train dans epoch 4 est:  0.664025068283081
# la precision sur train dans epoch 4 est:  54.0
# loss sur train dans epoch 5 est:  0.6459934115409851
# la precision sur train dans epoch 5 est:  59.999999999999986
# loss sur train dans epoch 6 est:  0.628235399723053
# la precision sur train dans epoch 6 est:  78.0
# loss sur train dans epoch 7 est:  0.6105943918228149
# la precision sur train dans epoch 7 est:  92.00000000000001
# loss sur train dans epoch 8 est:  0.5929663181304932
# la precision sur train dans epoch 8 est:  92.00000000000001
# loss sur train dans epoch 9 est:  0.5752934217453003
# la precision sur train dans epoch 9 est:  94.0
# loss sur train dans epoch 10 est:  0.557557225227356
# la precision sur train dans epoch 10 est:  96.99999999999999
# loss sur train dans epoch 11 est:  0.5397726893424988
# la precision sur train dans epoch 11 est:  96.99999999999999
# loss sur train dans epoch 12 est:  0.5219811201095581
# la precision sur train dans epoch 12 est:  96.99999999999999
# loss sur train dans epoch 13 est:  0.5042432546615601
# la precision sur train dans epoch 13 est:  98.00000000000001
# loss sur train dans epoch 14 est:  0.4866325855255127
# la precision sur train dans epoch 14 est:  98.00000000000001
# loss sur train dans epoch 15 est:  0.46922898292541504
# la precision sur train dans epoch 15 est:  99.0
# loss sur train dans epoch 16 est:  0.4521130621433258
# la precision sur train dans epoch 16 est:  99.0
# loss sur train dans epoch 17 est:  0.4353618025779724
# la precision sur train dans epoch 17 est:  99.0
# loss sur train dans epoch 18 est:  0.4190444052219391
# la precision sur train dans epoch 18 est:  99.0
# loss sur train dans epoch 19 est:  0.4032205045223236
# la precision sur train dans epoch 19 est:  99.0
# loss sur train dans epoch 20 est:  0.38793855905532837
# la precision sur train dans epoch 20 est:  98.00000000000001
# loss sur train dans epoch 21 est:  0.37323489785194397
# la precision sur train dans epoch 21 est:  98.00000000000001
# loss sur train dans epoch 22 est:  0.3591350317001343
# la precision sur train dans epoch 22 est:  98.00000000000001
# loss sur train dans epoch 23 est:  0.34565338492393494
# la precision sur train dans epoch 23 est:  98.00000000000001
# loss sur train dans epoch 24 est:  0.33279529213905334
# la precision sur train dans epoch 24 est:  98.00000000000001
# loss sur train dans epoch 25 est:  0.320557564496994
# la precision sur train dans epoch 25 est:  98.00000000000001
# loss sur train dans epoch 26 est:  0.3089306950569153
# la precision sur train dans epoch 26 est:  98.00000000000001
# loss sur train dans epoch 27 est:  0.2978995442390442
# la precision sur train dans epoch 27 est:  98.00000000000001
# loss sur train dans epoch 28 est:  0.28744491934776306
# la precision sur train dans epoch 28 est:  98.00000000000001
# loss sur train dans epoch 29 est:  0.2775447964668274
# la precision sur train dans epoch 29 est:  98.00000000000001
# loss sur train dans epoch 30 est:  0.26817482709884644
# la precision sur train dans epoch 30 est:  98.00000000000001
# loss sur train dans epoch 31 est:  0.25930967926979065
# la precision sur train dans epoch 31 est:  98.00000000000001
# loss sur train dans epoch 32 est:  0.25092336535453796
# la precision sur train dans epoch 32 est:  98.00000000000001
# loss sur train dans epoch 33 est:  0.24298982322216034
# la precision sur train dans epoch 33 est:  98.00000000000001
# loss sur train dans epoch 34 est:  0.23548340797424316
# la precision sur train dans epoch 34 est:  98.00000000000001
# loss sur train dans epoch 35 est:  0.2283790558576584
# la precision sur train dans epoch 35 est:  98.00000000000001
# loss sur train dans epoch 36 est:  0.22165271639823914
# la precision sur train dans epoch 36 est:  98.00000000000001
# loss sur train dans epoch 37 est:  0.21528127789497375
# la precision sur train dans epoch 37 est:  98.00000000000001
# loss sur train dans epoch 38 est:  0.20924273133277893
# la precision sur train dans epoch 38 est:  98.00000000000001
# loss sur train dans epoch 39 est:  0.20351628959178925
# la precision sur train dans epoch 39 est:  98.00000000000001
# loss sur train dans epoch 40 est:  0.1980823278427124
# la precision sur train dans epoch 40 est:  98.00000000000001
# loss sur train dans epoch 41 est:  0.1929224729537964
# la precision sur train dans epoch 41 est:  98.00000000000001
# loss sur train dans epoch 42 est:  0.18801942467689514
# la precision sur train dans epoch 42 est:  98.00000000000001
# loss sur train dans epoch 43 est:  0.1833570897579193
# la precision sur train dans epoch 43 est:  98.00000000000001
# loss sur train dans epoch 44 est:  0.17892038822174072
# la precision sur train dans epoch 44 est:  98.00000000000001
# loss sur train dans epoch 45 est:  0.17469525337219238
# la precision sur train dans epoch 45 est:  98.00000000000001
# loss sur train dans epoch 46 est:  0.1706686168909073
# la precision sur train dans epoch 46 est:  98.00000000000001
# loss sur train dans epoch 47 est:  0.16682825982570648
# la precision sur train dans epoch 47 est:  98.00000000000001
# loss sur train dans epoch 48 est:  0.16316291689872742
# la precision sur train dans epoch 48 est:  98.00000000000001
# loss sur train dans epoch 49 est:  0.15966200828552246
# la precision sur train dans epoch 49 est:  98.00000000000001
# loss sur train dans epoch 50 est:  0.15631574392318726
# la precision sur train dans epoch 50 est:  98.00000000000001
# loss sur train dans epoch 51 est:  0.15311498939990997
# la precision sur train dans epoch 51 est:  98.00000000000001
# loss sur train dans epoch 52 est:  0.1500512659549713
# la precision sur train dans epoch 52 est:  98.00000000000001
# loss sur train dans epoch 53 est:  0.14711666107177734
# la precision sur train dans epoch 53 est:  98.00000000000001
# loss sur train dans epoch 54 est:  0.1443038284778595
# la precision sur train dans epoch 54 est:  98.00000000000001
# loss sur train dans epoch 55 est:  0.14160586893558502
# la precision sur train dans epoch 55 est:  98.00000000000001
# loss sur train dans epoch 56 est:  0.13901644945144653
# la precision sur train dans epoch 56 est:  98.00000000000001
# loss sur train dans epoch 57 est:  0.1365295946598053
# la precision sur train dans epoch 57 est:  98.00000000000001
# loss sur train dans epoch 58 est:  0.13413973152637482
# la precision sur train dans epoch 58 est:  98.00000000000001
# loss sur train dans epoch 59 est:  0.13184168934822083
# la precision sur train dans epoch 59 est:  98.00000000000001
# loss sur train dans epoch 60 est:  0.12963059544563293
# la precision sur train dans epoch 60 est:  98.00000000000001
# loss sur train dans epoch 61 est:  0.12750190496444702
# la precision sur train dans epoch 61 est:  98.00000000000001
# loss sur train dans epoch 62 est:  0.12545143067836761
# la precision sur train dans epoch 62 est:  98.00000000000001
# loss sur train dans epoch 63 est:  0.1234750896692276
# la precision sur train dans epoch 63 est:  98.00000000000001
# loss sur train dans epoch 64 est:  0.12156926095485687
# la precision sur train dans epoch 64 est:  98.00000000000001
# loss sur train dans epoch 65 est:  0.1197303757071495
# la precision sur train dans epoch 65 est:  98.00000000000001
# loss sur train dans epoch 66 est:  0.11795520782470703
# la precision sur train dans epoch 66 est:  98.00000000000001
# loss sur train dans epoch 67 est:  0.11624065786600113
# la precision sur train dans epoch 67 est:  98.00000000000001
# loss sur train dans epoch 68 est:  0.11458383500576019
# la precision sur train dans epoch 68 est:  98.00000000000001
# loss sur train dans epoch 69 est:  0.11298203468322754
# la precision sur train dans epoch 69 est:  98.00000000000001
# loss sur train dans epoch 70 est:  0.11143264919519424
# la precision sur train dans epoch 70 est:  98.00000000000001
# loss sur train dans epoch 71 est:  0.10993333160877228
# la precision sur train dans epoch 71 est:  98.00000000000001
# loss sur train dans epoch 72 est:  0.1084817424416542
# la precision sur train dans epoch 72 est:  98.00000000000001
# loss sur train dans epoch 73 est:  0.10707581043243408
# la precision sur train dans epoch 73 est:  99.0
# loss sur train dans epoch 74 est:  0.10571344196796417
# la precision sur train dans epoch 74 est:  99.0
# loss sur train dans epoch 75 est:  0.10439276695251465
# la precision sur train dans epoch 75 est:  99.0
# loss sur train dans epoch 76 est:  0.10311198234558105
# la precision sur train dans epoch 76 est:  99.0
# loss sur train dans epoch 77 est:  0.1018693670630455
# la precision sur train dans epoch 77 est:  99.0
# loss sur train dans epoch 78 est:  0.10066331923007965
# la precision sur train dans epoch 78 est:  99.0
# loss sur train dans epoch 79 est:  0.09949227422475815
# la precision sur train dans epoch 79 est:  99.0
# loss sur train dans epoch 80 est:  0.09835481643676758
# la precision sur train dans epoch 80 est:  99.0
# loss sur train dans epoch 81 est:  0.09724956750869751
# la precision sur train dans epoch 81 est:  99.0
# loss sur train dans epoch 82 est:  0.09617523849010468
# la precision sur train dans epoch 82 est:  99.0
# loss sur train dans epoch 83 est:  0.09513060003519058
# la precision sur train dans epoch 83 est:  99.0
# loss sur train dans epoch 84 est:  0.09411443024873734
# la precision sur train dans epoch 84 est:  99.0
# loss sur train dans epoch 85 est:  0.09312564879655838
# la precision sur train dans epoch 85 est:  99.0
# loss sur train dans epoch 86 est:  0.09216319024562836
# la precision sur train dans epoch 86 est:  99.0
# loss sur train dans epoch 87 est:  0.09122607856988907
# la precision sur train dans epoch 87 est:  99.0
# loss sur train dans epoch 88 est:  0.09031330049037933
# la precision sur train dans epoch 88 est:  99.0
# loss sur train dans epoch 89 est:  0.08942398428916931
# la precision sur train dans epoch 89 est:  99.0
# loss sur train dans epoch 90 est:  0.08855725824832916
# la precision sur train dans epoch 90 est:  99.0
# loss sur train dans epoch 91 est:  0.08771227300167084
# la precision sur train dans epoch 91 est:  99.0
# loss sur train dans epoch 92 est:  0.08688824623823166
# la precision sur train dans epoch 92 est:  99.0
# loss sur train dans epoch 93 est:  0.08608444780111313
# la precision sur train dans epoch 93 est:  99.0
# loss sur train dans epoch 94 est:  0.08530014008283615
# la precision sur train dans epoch 94 est:  99.0
# loss sur train dans epoch 95 est:  0.08453463017940521
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.08378729969263077
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.0830574631690979
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.08234457671642303
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.08164803683757782
# la precision sur train dans epoch 99 est:  99.0
# loss sur train dans epoch 100 est:  0.08096732199192047
# la precision sur train dans epoch 100 est:  99.0
# loss sur train dans epoch 101 est:  0.08030188083648682
# la precision sur train dans epoch 101 est:  99.0
# loss sur train dans epoch 102 est:  0.07965124398469925
# la precision sur train dans epoch 102 est:  99.0
# loss sur train dans epoch 103 est:  0.07901487499475479
# la precision sur train dans epoch 103 est:  99.0
# loss sur train dans epoch 104 est:  0.07839237153530121
# la precision sur train dans epoch 104 est:  99.0
# loss sur train dans epoch 105 est:  0.0777832493185997
# la precision sur train dans epoch 105 est:  99.0
# loss sur train dans epoch 106 est:  0.07718710601329803
# la precision sur train dans epoch 106 est:  99.0
# loss sur train dans epoch 107 est:  0.07660355418920517
# la precision sur train dans epoch 107 est:  99.0
# loss sur train dans epoch 108 est:  0.07603217661380768
# la precision sur train dans epoch 108 est:  99.0
# loss sur train dans epoch 109 est:  0.07547260820865631
# la precision sur train dans epoch 109 est:  99.0
# loss sur train dans epoch 110 est:  0.07492449879646301
# la precision sur train dans epoch 110 est:  99.0
# loss sur train dans epoch 111 est:  0.07438744604587555
# la precision sur train dans epoch 111 est:  99.0
# loss sur train dans epoch 112 est:  0.07386119663715363
# la precision sur train dans epoch 112 est:  99.0
# loss sur train dans epoch 113 est:  0.07334538549184799
# la precision sur train dans epoch 113 est:  99.0
# loss sur train dans epoch 114 est:  0.07283973693847656
# la precision sur train dans epoch 114 est:  99.0
# loss sur train dans epoch 115 est:  0.07234392315149307
# la precision sur train dans epoch 115 est:  99.0
# loss sur train dans epoch 116 est:  0.07185766845941544
# la precision sur train dans epoch 116 est:  99.0
# loss sur train dans epoch 117 est:  0.07138070464134216
# la precision sur train dans epoch 117 est:  99.0
# loss sur train dans epoch 118 est:  0.07091279327869415
# la precision sur train dans epoch 118 est:  99.0
# loss sur train dans epoch 119 est:  0.07045363634824753
# la precision sur train dans epoch 119 est:  99.0
# loss sur train dans epoch 120 est:  0.07000301778316498
# la precision sur train dans epoch 120 est:  99.0
# loss sur train dans epoch 121 est:  0.06956066936254501
# la precision sur train dans epoch 121 est:  99.0
# loss sur train dans epoch 122 est:  0.06912640482187271
# la precision sur train dans epoch 122 est:  99.0
# loss sur train dans epoch 123 est:  0.06869999319314957
# la precision sur train dans epoch 123 est:  99.0
# loss sur train dans epoch 124 est:  0.06828121095895767
# la precision sur train dans epoch 124 est:  99.0
# loss sur train dans epoch 125 est:  0.06786986440420151
# la precision sur train dans epoch 125 est:  99.0
# loss sur train dans epoch 126 est:  0.06746575236320496
# la precision sur train dans epoch 126 est:  99.0
# loss sur train dans epoch 127 est:  0.0670686811208725
# la precision sur train dans epoch 127 est:  99.0
# loss sur train dans epoch 128 est:  0.06667846441268921
# la precision sur train dans epoch 128 est:  99.0
# loss sur train dans epoch 129 est:  0.06629492342472076
# la precision sur train dans epoch 129 est:  99.0
# loss sur train dans epoch 130 est:  0.06591791659593582
# la precision sur train dans epoch 130 est:  99.0
# loss sur train dans epoch 131 est:  0.06554724276065826
# la precision sur train dans epoch 131 est:  99.0
# loss sur train dans epoch 132 est:  0.06518274545669556
# la precision sur train dans epoch 132 est:  99.0
# loss sur train dans epoch 133 est:  0.06482429802417755
# la precision sur train dans epoch 133 est:  99.0
# loss sur train dans epoch 134 est:  0.06447172909975052
# la precision sur train dans epoch 134 est:  99.0
# loss sur train dans epoch 135 est:  0.06412489712238312
# la precision sur train dans epoch 135 est:  99.0
# loss sur train dans epoch 136 est:  0.06378363817930222
# la precision sur train dans epoch 136 est:  99.0
# loss sur train dans epoch 137 est:  0.06344787031412125
# la precision sur train dans epoch 137 est:  99.0
# loss sur train dans epoch 138 est:  0.06311742961406708
# la precision sur train dans epoch 138 est:  99.0
# loss sur train dans epoch 139 est:  0.06279217451810837
# la precision sur train dans epoch 139 est:  99.0
# loss sur train dans epoch 140 est:  0.06247199699282646
# la precision sur train dans epoch 140 est:  99.0
# loss sur train dans epoch 141 est:  0.06215677410364151
# la precision sur train dans epoch 141 est:  99.0
# loss sur train dans epoch 142 est:  0.06184641644358635
# la precision sur train dans epoch 142 est:  99.0
# loss sur train dans epoch 143 est:  0.06154076009988785
# la precision sur train dans epoch 143 est:  99.0
# loss sur train dans epoch 144 est:  0.06123974919319153
# la precision sur train dans epoch 144 est:  99.0
# loss sur train dans epoch 145 est:  0.060943253338336945
# la precision sur train dans epoch 145 est:  99.0
# loss sur train dans epoch 146 est:  0.06065114215016365
# la precision sur train dans epoch 146 est:  99.0
# loss sur train dans epoch 147 est:  0.06036336347460747
# la precision sur train dans epoch 147 est:  99.0
# loss sur train dans epoch 148 est:  0.060079801827669144
# la precision sur train dans epoch 148 est:  99.0
# loss sur train dans epoch 149 est:  0.05980036407709122
# la precision sur train dans epoch 149 est:  99.0
# loss sur train dans epoch 150 est:  0.05952494591474533
# la precision sur train dans epoch 150 est:  99.0
# loss sur train dans epoch 151 est:  0.05925348401069641
# la precision sur train dans epoch 151 est:  99.0
# loss sur train dans epoch 152 est:  0.0589858815073967
# la precision sur train dans epoch 152 est:  99.0
# loss sur train dans epoch 153 est:  0.05872204899787903
# la precision sur train dans epoch 153 est:  99.0
# loss sur train dans epoch 154 est:  0.05846192315220833
# la precision sur train dans epoch 154 est:  99.0
# loss sur train dans epoch 155 est:  0.05820539593696594
# la precision sur train dans epoch 155 est:  99.0
# loss sur train dans epoch 156 est:  0.05795242637395859
# la precision sur train dans epoch 156 est:  99.0
# loss sur train dans epoch 157 est:  0.057702917605638504
# la precision sur train dans epoch 157 est:  99.0
# loss sur train dans epoch 158 est:  0.05745679885149002
# la precision sur train dans epoch 158 est:  99.0
# loss sur train dans epoch 159 est:  0.05721399933099747
# la precision sur train dans epoch 159 est:  99.0
# loss sur train dans epoch 160 est:  0.05697445943951607
# la precision sur train dans epoch 160 est:  99.0
# loss sur train dans epoch 161 est:  0.05673810839653015
# la precision sur train dans epoch 161 est:  99.0
# loss sur train dans epoch 162 est:  0.056504882872104645
# la precision sur train dans epoch 162 est:  99.0
# loss sur train dans epoch 163 est:  0.05627468228340149
# la precision sur train dans epoch 163 est:  99.0
# loss sur train dans epoch 164 est:  0.05604752153158188
# la precision sur train dans epoch 164 est:  99.0
# loss sur train dans epoch 165 est:  0.05582328885793686
# la precision sur train dans epoch 165 est:  99.0
# loss sur train dans epoch 166 est:  0.05560194328427315
# la precision sur train dans epoch 166 est:  99.0
# loss sur train dans epoch 167 est:  0.05538342148065567
# la precision sur train dans epoch 167 est:  99.0
# loss sur train dans epoch 168 est:  0.05516766756772995
# la precision sur train dans epoch 168 est:  99.0
# loss sur train dans epoch 169 est:  0.054954636842012405
# la precision sur train dans epoch 169 est:  99.0
# loss sur train dans epoch 170 est:  0.054744262248277664
# la precision sur train dans epoch 170 est:  99.0
# loss sur train dans epoch 171 est:  0.054536499083042145
# la precision sur train dans epoch 171 est:  99.0
# loss sur train dans epoch 172 est:  0.05433129519224167
# la precision sur train dans epoch 172 est:  99.0
# loss sur train dans epoch 173 est:  0.05412860959768295
# la precision sur train dans epoch 173 est:  99.0
# loss sur train dans epoch 174 est:  0.05392839387059212
# la precision sur train dans epoch 174 est:  99.0
# loss sur train dans epoch 175 est:  0.05373059958219528
# la precision sur train dans epoch 175 est:  99.0
# loss sur train dans epoch 176 est:  0.053535182029008865
# la precision sur train dans epoch 176 est:  99.0
# loss sur train dans epoch 177 est:  0.05334210395812988
# la precision sur train dans epoch 177 est:  99.0
# loss sur train dans epoch 178 est:  0.053151316940784454
# la precision sur train dans epoch 178 est:  99.0
# loss sur train dans epoch 179 est:  0.0529627688229084
# la precision sur train dans epoch 179 est:  99.0
# loss sur train dans epoch 180 est:  0.05277641862630844
# la precision sur train dans epoch 180 est:  99.0
# loss sur train dans epoch 181 est:  0.05259225517511368
# la precision sur train dans epoch 181 est:  99.0
# loss sur train dans epoch 182 est:  0.05241020768880844
# la precision sur train dans epoch 182 est:  99.0
# loss sur train dans epoch 183 est:  0.05223025009036064
# la precision sur train dans epoch 183 est:  99.0
# loss sur train dans epoch 184 est:  0.052052367478609085
# la precision sur train dans epoch 184 est:  99.0
# loss sur train dans epoch 185 est:  0.0518764927983284
# la precision sur train dans epoch 185 est:  99.0
# loss sur train dans epoch 186 est:  0.051702599972486496
# la precision sur train dans epoch 186 est:  99.0
# loss sur train dans epoch 187 est:  0.05153066664934158
# la precision sur train dans epoch 187 est:  99.0
# loss sur train dans epoch 188 est:  0.05136062577366829
# la precision sur train dans epoch 188 est:  99.0
# loss sur train dans epoch 189 est:  0.05119248479604721
# la precision sur train dans epoch 189 est:  99.0
# loss sur train dans epoch 190 est:  0.05102619528770447
# la precision sur train dans epoch 190 est:  99.0
# loss sur train dans epoch 191 est:  0.05086173489689827
# la precision sur train dans epoch 191 est:  99.0
# loss sur train dans epoch 192 est:  0.050699055194854736
# la precision sur train dans epoch 192 est:  99.0
# loss sur train dans epoch 193 est:  0.050538115203380585
# la precision sur train dans epoch 193 est:  99.0
# loss sur train dans epoch 194 est:  0.05037892609834671
# la precision sur train dans epoch 194 est:  99.0
# loss sur train dans epoch 195 est:  0.05022142082452774
# la precision sur train dans epoch 195 est:  99.0
# loss sur train dans epoch 196 est:  0.050065599381923676
# la precision sur train dans epoch 196 est:  99.0
# loss sur train dans epoch 197 est:  0.04991142451763153
# la precision sur train dans epoch 197 est:  99.0
# loss sur train dans epoch 198 est:  0.049758873879909515
# la precision sur train dans epoch 198 est:  99.0
# loss sur train dans epoch 199 est:  0.04960789903998375
# la precision sur train dans epoch 199 est:  99.0

# %% [markdown]
# <center>
# 	<h2 style="color:#e56b6f">
# 		<b>
# 			2.2 Simplification du backward avec <span style="color:#eaac8b"> torch.autograd</span>
# 		</b>
# 	</h2>
# </center>

# %% [markdown]
# <h3 style="color:#00a896;font-weight:bold;">
#
#  A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones
#
# </h3>

# %%
def init_params(nx, nh, ny):
    # nx :  Le nombre de variables d'entrée.
    # nh: Le nombre de neurones dans la couche cachée.
    # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    #activation du autograde pour la methode de toch
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx),requires_grad=True)
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1), requires_grad=True)
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh), requires_grad=True)
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1), requires_grad=True)
    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;" >
# 	B. la fonction qui effectue la propagation avant
# </h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1']  #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                            # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2'] # Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0)  # Application de la fonction softmax
    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }
    return outputs

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	C. la fonction de Perte et Taux de Précision
# </h3>

# %%
def loss_accuracy(Yhat, Y):
    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    #La perte est calculée en utilisant la cross-entropy
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0))
    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)
    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)
    #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	D. Propagation du Gradient pour la Mise à Jour des Paramètres
# </h3>

# %%
def backward_auto(params, outputs, Y):
    # Réinitialiser les gradients des paramètres
    for par in params:
        if params[par].grad is not None:
            params[par].grad.zero_()
    # Calculer la perte
    loss = loss_accuracy(outputs['Yhat'], Y)[0]
    # Rétropropagation automatique
    loss.backward()
    # Extraire les gradients des paramètres après rétropropagation
    gradients = {
        'dW1': params['W1'].grad,
        'dB1': params['B1'].grad,
        'dW2': params['W2'].grad,
        'dB2': params['B2'].grad,
    }

    return gradients

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres
# </h3>

# %%
def sgd(params, grads, eta):
    # Assurez-vous d'utiliser torch.no_grad() pour éviter de calculer les gradients lors de la mise à jour des paramètres
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            # Mise à jour des paramètres avec la descente de gradient
            params[par] = params[par] - eta * grads['d' + par]
            # Activer à nouveau le suivi des gradients pour les paramètres
            params[par].requires_grad_(True)
    return params

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	F. Application
# </h3>

# %%
N_epoch = 100 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)

#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
         # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
        j = i * batch

    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc  = acc * 100 /  (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc )
    loss_history.append(loss.item())

#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.7481135129928589
# la precision sur train dans epoch 0 est:  50.0
# loss sur train dans epoch 1 est:  0.6881303191184998
# la precision sur train dans epoch 1 est:  50.0
# loss sur train dans epoch 2 est:  0.6358149647712708
# la precision sur train dans epoch 2 est:  50.0
# loss sur train dans epoch 3 est:  0.5899810194969177
# la precision sur train dans epoch 3 est:  52.0
# loss sur train dans epoch 4 est:  0.5496391654014587
# la precision sur train dans epoch 4 est:  68.0
# loss sur train dans epoch 5 est:  0.5139687061309814
# la precision sur train dans epoch 5 est:  85.0
# loss sur train dans epoch 6 est:  0.482290118932724
# la precision sur train dans epoch 6 est:  91.00000000000001
# loss sur train dans epoch 7 est:  0.45403894782066345
# la precision sur train dans epoch 7 est:  94.0
# loss sur train dans epoch 8 est:  0.4287432134151459
# la precision sur train dans epoch 8 est:  95.0
# loss sur train dans epoch 9 est:  0.40600547194480896
# la precision sur train dans epoch 9 est:  96.99999999999999
# loss sur train dans epoch 10 est:  0.3854883909225464
# la precision sur train dans epoch 10 est:  96.99999999999999
# loss sur train dans epoch 11 est:  0.3669050335884094
# la precision sur train dans epoch 11 est:  96.99999999999999
# loss sur train dans epoch 12 est:  0.3500100076198578
# la precision sur train dans epoch 12 est:  96.0
# loss sur train dans epoch 13 est:  0.33459359407424927
# la precision sur train dans epoch 13 est:  96.0
# loss sur train dans epoch 14 est:  0.3204762637615204
# la precision sur train dans epoch 14 est:  96.0
# loss sur train dans epoch 15 est:  0.3075041174888611
# la precision sur train dans epoch 15 est:  96.0
# loss sur train dans epoch 16 est:  0.29554545879364014
# la precision sur train dans epoch 16 est:  95.0
# loss sur train dans epoch 17 est:  0.28448671102523804
# la precision sur train dans epoch 17 est:  95.0
# loss sur train dans epoch 18 est:  0.274230420589447
# la precision sur train dans epoch 18 est:  95.0
# loss sur train dans epoch 19 est:  0.2646922469139099
# la precision sur train dans epoch 19 est:  95.0
# loss sur train dans epoch 20 est:  0.25579920411109924
# la precision sur train dans epoch 20 est:  96.0
# loss sur train dans epoch 21 est:  0.24748781323432922
# la precision sur train dans epoch 21 est:  96.0
# loss sur train dans epoch 22 est:  0.2397027462720871
# la precision sur train dans epoch 22 est:  96.0
# loss sur train dans epoch 23 est:  0.23239552974700928
# la precision sur train dans epoch 23 est:  96.99999999999999
# loss sur train dans epoch 24 est:  0.225523442029953
# la precision sur train dans epoch 24 est:  96.0
# loss sur train dans epoch 25 est:  0.21904902160167694
# la precision sur train dans epoch 25 est:  96.0
# loss sur train dans epoch 26 est:  0.21293887495994568
# la precision sur train dans epoch 26 est:  96.0
# loss sur train dans epoch 27 est:  0.20716342329978943
# la precision sur train dans epoch 27 est:  96.0
# loss sur train dans epoch 28 est:  0.20169620215892792
# la precision sur train dans epoch 28 est:  96.0
# loss sur train dans epoch 29 est:  0.19651363790035248
# la precision sur train dans epoch 29 est:  96.0
# loss sur train dans epoch 30 est:  0.19159449636936188
# la precision sur train dans epoch 30 est:  96.0
# loss sur train dans epoch 31 est:  0.18691959977149963
# la precision sur train dans epoch 31 est:  96.0
# loss sur train dans epoch 32 est:  0.18247169256210327
# la precision sur train dans epoch 32 est:  96.0
# loss sur train dans epoch 33 est:  0.17823508381843567
# la precision sur train dans epoch 33 est:  96.0
# loss sur train dans epoch 34 est:  0.1741955280303955
# la precision sur train dans epoch 34 est:  96.0
# loss sur train dans epoch 35 est:  0.17034009099006653
# la precision sur train dans epoch 35 est:  96.99999999999999
# loss sur train dans epoch 36 est:  0.16665689647197723
# la precision sur train dans epoch 36 est:  96.99999999999999
# loss sur train dans epoch 37 est:  0.1631351262331009
# la precision sur train dans epoch 37 est:  96.99999999999999
# loss sur train dans epoch 38 est:  0.15976481139659882
# la precision sur train dans epoch 38 est:  96.99999999999999
# loss sur train dans epoch 39 est:  0.1565367579460144
# la precision sur train dans epoch 39 est:  96.99999999999999
# loss sur train dans epoch 40 est:  0.1534426361322403
# la precision sur train dans epoch 40 est:  96.99999999999999
# loss sur train dans epoch 41 est:  0.15047459304332733
# la precision sur train dans epoch 41 est:  96.99999999999999
# loss sur train dans epoch 42 est:  0.14762549102306366
# la precision sur train dans epoch 42 est:  96.99999999999999
# loss sur train dans epoch 43 est:  0.14488865435123444
# la precision sur train dans epoch 43 est:  96.99999999999999
# loss sur train dans epoch 44 est:  0.14225786924362183
# la precision sur train dans epoch 44 est:  96.99999999999999
# loss sur train dans epoch 45 est:  0.13972750306129456
# la precision sur train dans epoch 45 est:  96.99999999999999
# loss sur train dans epoch 46 est:  0.1372920721769333
# la precision sur train dans epoch 46 est:  96.99999999999999
# loss sur train dans epoch 47 est:  0.13494670391082764
# la precision sur train dans epoch 47 est:  96.99999999999999
# loss sur train dans epoch 48 est:  0.1326867640018463
# la precision sur train dans epoch 48 est:  96.99999999999999
# loss sur train dans epoch 49 est:  0.1305079162120819
# la precision sur train dans epoch 49 est:  96.99999999999999
# loss sur train dans epoch 50 est:  0.1284061074256897
# la precision sur train dans epoch 50 est:  96.99999999999999
# loss sur train dans epoch 51 est:  0.12637750804424286
# la precision sur train dans epoch 51 est:  96.99999999999999
# loss sur train dans epoch 52 est:  0.12441863864660263
# la precision sur train dans epoch 52 est:  96.99999999999999
# loss sur train dans epoch 53 est:  0.12252610921859741
# la precision sur train dans epoch 53 est:  96.99999999999999
# loss sur train dans epoch 54 est:  0.12069680541753769
# la precision sur train dans epoch 54 est:  96.99999999999999
# loss sur train dans epoch 55 est:  0.11892785131931305
# la precision sur train dans epoch 55 est:  96.99999999999999
# loss sur train dans epoch 56 est:  0.11721639335155487
# la precision sur train dans epoch 56 est:  96.99999999999999
# loss sur train dans epoch 57 est:  0.11555985361337662
# la precision sur train dans epoch 57 est:  96.99999999999999
# loss sur train dans epoch 58 est:  0.1139557957649231
# la precision sur train dans epoch 58 est:  96.99999999999999
# loss sur train dans epoch 59 est:  0.11240188777446747
# la precision sur train dans epoch 59 est:  96.99999999999999
# loss sur train dans epoch 60 est:  0.11089595407247543
# la precision sur train dans epoch 60 est:  96.99999999999999
# loss sur train dans epoch 61 est:  0.10943593084812164
# la precision sur train dans epoch 61 est:  96.99999999999999
# loss sur train dans epoch 62 est:  0.10801984369754791
# la precision sur train dans epoch 62 est:  96.99999999999999
# loss sur train dans epoch 63 est:  0.1066458597779274
# la precision sur train dans epoch 63 est:  96.99999999999999
# loss sur train dans epoch 64 est:  0.10531226545572281
# la precision sur train dans epoch 64 est:  96.99999999999999
# loss sur train dans epoch 65 est:  0.10401733964681625
# la precision sur train dans epoch 65 est:  96.99999999999999
# loss sur train dans epoch 66 est:  0.10275954008102417
# la precision sur train dans epoch 66 est:  96.99999999999999
# loss sur train dans epoch 67 est:  0.10153738409280777
# la precision sur train dans epoch 67 est:  96.99999999999999
# loss sur train dans epoch 68 est:  0.10034946352243423
# la precision sur train dans epoch 68 est:  96.99999999999999
# loss sur train dans epoch 69 est:  0.09919443726539612
# la precision sur train dans epoch 69 est:  96.99999999999999
# loss sur train dans epoch 70 est:  0.09807099401950836
# la precision sur train dans epoch 70 est:  96.99999999999999
# loss sur train dans epoch 71 est:  0.09697794914245605
# la precision sur train dans epoch 71 est:  96.99999999999999
# loss sur train dans epoch 72 est:  0.09591412544250488
# la precision sur train dans epoch 72 est:  96.99999999999999
# loss sur train dans epoch 73 est:  0.09487845003604889
# la precision sur train dans epoch 73 est:  96.99999999999999
# loss sur train dans epoch 74 est:  0.09386985003948212
# la precision sur train dans epoch 74 est:  96.99999999999999
# loss sur train dans epoch 75 est:  0.09288731962442398
# la precision sur train dans epoch 75 est:  96.99999999999999
# loss sur train dans epoch 76 est:  0.09192994236946106
# la precision sur train dans epoch 76 est:  96.99999999999999
# loss sur train dans epoch 77 est:  0.09099678695201874
# la precision sur train dans epoch 77 est:  96.99999999999999
# loss sur train dans epoch 78 est:  0.09008698910474777
# la precision sur train dans epoch 78 est:  98.00000000000001
# loss sur train dans epoch 79 est:  0.08919975161552429
# la precision sur train dans epoch 79 est:  98.00000000000001
# loss sur train dans epoch 80 est:  0.08833424746990204
# la precision sur train dans epoch 80 est:  98.00000000000001
# loss sur train dans epoch 81 est:  0.08748973906040192
# la precision sur train dans epoch 81 est:  98.00000000000001
# loss sur train dans epoch 82 est:  0.08666548877954483
# la precision sur train dans epoch 82 est:  98.00000000000001
# loss sur train dans epoch 83 est:  0.08586081862449646
# la precision sur train dans epoch 83 est:  98.00000000000001
# loss sur train dans epoch 84 est:  0.08507506549358368
# la precision sur train dans epoch 84 est:  99.0
# loss sur train dans epoch 85 est:  0.08430759608745575
# la precision sur train dans epoch 85 est:  99.0
# loss sur train dans epoch 86 est:  0.08355779945850372
# la precision sur train dans epoch 86 est:  99.0
# loss sur train dans epoch 87 est:  0.08282510191202164
# la precision sur train dans epoch 87 est:  99.0
# loss sur train dans epoch 88 est:  0.08210892975330353
# la precision sur train dans epoch 88 est:  99.0
# loss sur train dans epoch 89 est:  0.08140876144170761
# la precision sur train dans epoch 89 est:  99.0
# loss sur train dans epoch 90 est:  0.08072413504123688
# la precision sur train dans epoch 90 est:  99.0
# loss sur train dans epoch 91 est:  0.08005446195602417
# la precision sur train dans epoch 91 est:  99.0
# loss sur train dans epoch 92 est:  0.07939933985471725
# la precision sur train dans epoch 92 est:  99.0
# loss sur train dans epoch 93 est:  0.07875829935073853
# la precision sur train dans epoch 93 est:  99.0
# loss sur train dans epoch 94 est:  0.07813090085983276
# la precision sur train dans epoch 94 est:  99.0
# loss sur train dans epoch 95 est:  0.07751674950122833
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.07691541314125061
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.07632652670145035
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.0757497102022171
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.07518460601568222
# la precision sur train dans epoch 99 est:  99.0

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.3 Simplification du forward avec les couches </font><font color='#87CEFA'> torch.nn</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. Initialisation d'un Modèle de Réseau de Neurones pour la Classification  avec PyTorch</font></h3>

# %%
def init_model(nx, nh, ny):
    model = torch.nn.Sequential(
        torch.nn.Linear(nx, nh), # Couche linéaire d'entrée à la couche cachée
        torch.nn.ReLU(),         # Fonction d'activation ReLU pour la couche cachée max(0, z)
        torch.nn.Linear(nh, ny), # Couche linéaire de la couche cachée à la couche de sortie
        torch.nn.Sigmoid()       # Fonction d'activation Sigmoid pour la couche de sortie
        #torch.nn.Softmax(dim=1)
    )
    
    # Définition de la fonction de perte CrossEntropyLoss pour une tâche de classification multiclasse
    loss = torch.nn.CrossEntropyLoss()
    return model, loss

# %% [markdown]
# <h3><font color='#1E90FF'> B. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres</font></h3>

# %%
def sgd(model, eta):
    # Assurez-vous d'utiliser torch.no_grad() pour éviter de calculer les gradients lors de la mise à jour des paramètres
    with torch.no_grad():
        for param in model.parameters():
            # Mise à jour des paramètres avec la descente de gradient
            param -= eta * param.grad
        
        # Réinitialiser les gradients après la mise à jour des paramètres
        model.zero_grad()

# %% [markdown]
# <h3><font color='#1E90FF'> C. Application</font></h3>

# %%
N_epoch = 1000 #nombre des epoqu
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)
X = X_tensor
Y = Y_tensor

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle 
model , loss= init_model(2,4,2)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    los_glob = 0 #Réinitialiser la perte du modèle pour chaque époque.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[j:i * batch, :]
        Y_epoch = Y[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model(X_epoch)
        # calculer la perte pour le mini-batch actuel
        los_batch = loss(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los_batch.backward()
        sgd(model, eta )
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        los_glob += los_batch
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.   
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données 
        X_epoch = X[ j : N, :]
        Y_epoch = Y[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model(X_epoch)
        # calculer la perte pour le mini-batch actuel
        los_batch = loss(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los_batch.backward()
        sgd(model, eta )
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        los_glob += los_batch
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    los_glob /= (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch}: ", los_glob.item())
    loss_history.append(los_glob.item())
    
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0:  0.7030916213989258
# loss sur train dans epoch 1:  0.7011252641677856
# loss sur train dans epoch 2:  0.699195384979248
# loss sur train dans epoch 3:  0.6973048448562622
# loss sur train dans epoch 4:  0.6954506635665894
# loss sur train dans epoch 5:  0.6936261057853699
# loss sur train dans epoch 6:  0.6918283104896545
# loss sur train dans epoch 7:  0.690056562423706
# loss sur train dans epoch 8:  0.6883052587509155
# loss sur train dans epoch 9:  0.6865741014480591
# loss sur train dans epoch 10:  0.6848636269569397
# loss sur train dans epoch 11:  0.6831732392311096
# loss sur train dans epoch 12:  0.6815010905265808
# loss sur train dans epoch 13:  0.6798467040061951
# loss sur train dans epoch 14:  0.6782097816467285
# loss sur train dans epoch 15:  0.6765908002853394
# loss sur train dans epoch 16:  0.6749888062477112
# loss sur train dans epoch 17:  0.6733982563018799
# loss sur train dans epoch 18:  0.6718197464942932
# loss sur train dans epoch 19:  0.6702558398246765
# loss sur train dans epoch 20:  0.6687017679214478
# loss sur train dans epoch 21:  0.6671561002731323
# loss sur train dans epoch 22:  0.6656181216239929
# loss sur train dans epoch 23:  0.6640897989273071
# loss sur train dans epoch 24:  0.6625692844390869
# loss sur train dans epoch 25:  0.6610586643218994
# loss sur train dans epoch 26:  0.6595548391342163
# loss sur train dans epoch 27:  0.6580559015274048
# loss sur train dans epoch 28:  0.6565610766410828
# loss sur train dans epoch 29:  0.6550697088241577
# loss sur train dans epoch 30:  0.6535813212394714
# loss sur train dans epoch 31:  0.6520951986312866
# loss sur train dans epoch 32:  0.6506116986274719
# loss sur train dans epoch 33:  0.6491321921348572
# loss sur train dans epoch 34:  0.6476547718048096
# loss sur train dans epoch 35:  0.6461783647537231
# loss sur train dans epoch 36:  0.6447018384933472
# loss sur train dans epoch 37:  0.6432250738143921
# loss sur train dans epoch 38:  0.6417476534843445
# loss sur train dans epoch 39:  0.6402701735496521
# loss sur train dans epoch 40:  0.6387907266616821
# loss sur train dans epoch 41:  0.6373093724250793
# loss sur train dans epoch 42:  0.6358263492584229
# loss sur train dans epoch 43:  0.6343428492546082
# loss sur train dans epoch 44:  0.6328561902046204
# loss sur train dans epoch 45:  0.6313697695732117
# loss sur train dans epoch 46:  0.6298815608024597
# loss sur train dans epoch 47:  0.6283894181251526
# loss sur train dans epoch 48:  0.626893162727356
# loss sur train dans epoch 49:  0.625392735004425
# loss sur train dans epoch 50:  0.6238878965377808
# loss sur train dans epoch 51:  0.6223782300949097
# loss sur train dans epoch 52:  0.6208641529083252
# loss sur train dans epoch 53:  0.6193472146987915
# loss sur train dans epoch 54:  0.6178246140480042
# loss sur train dans epoch 55:  0.6162987947463989
# loss sur train dans epoch 56:  0.614768385887146
# loss sur train dans epoch 57:  0.6132318377494812
# loss sur train dans epoch 58:  0.611689031124115
# loss sur train dans epoch 59:  0.6101400256156921
# loss sur train dans epoch 60:  0.6085843443870544
# loss sur train dans epoch 61:  0.6070218682289124
# loss sur train dans epoch 62:  0.605452299118042
# loss sur train dans epoch 63:  0.603876531124115
# loss sur train dans epoch 64:  0.6022955179214478
# loss sur train dans epoch 65:  0.6007096767425537
# loss sur train dans epoch 66:  0.599117636680603
# loss sur train dans epoch 67:  0.5975181460380554
# loss sur train dans epoch 68:  0.5959112644195557
# loss sur train dans epoch 69:  0.5942968130111694
# loss sur train dans epoch 70:  0.592674732208252
# loss sur train dans epoch 71:  0.5910448431968689
# loss sur train dans epoch 72:  0.589407205581665
# loss sur train dans epoch 73:  0.5877617001533508
# loss sur train dans epoch 74:  0.5861082077026367
# loss sur train dans epoch 75:  0.5844467878341675
# loss sur train dans epoch 76:  0.5827785134315491
# loss sur train dans epoch 77:  0.5811048150062561
# loss sur train dans epoch 78:  0.5794228315353394
# loss sur train dans epoch 79:  0.5777332186698914
# loss sur train dans epoch 80:  0.5760389566421509
# loss sur train dans epoch 81:  0.5743374824523926
# loss sur train dans epoch 82:  0.5726304054260254
# loss sur train dans epoch 83:  0.5709162354469299
# loss sur train dans epoch 84:  0.5691948533058167
# loss sur train dans epoch 85:  0.5674662590026855
# loss sur train dans epoch 86:  0.5657345652580261
# loss sur train dans epoch 87:  0.5640023350715637
# loss sur train dans epoch 88:  0.5622636079788208
# loss sur train dans epoch 89:  0.5605188012123108
# loss sur train dans epoch 90:  0.5587677359580994
# loss sur train dans epoch 91:  0.557016134262085
# loss sur train dans epoch 92:  0.5552645921707153
# loss sur train dans epoch 93:  0.5535087585449219
# loss sur train dans epoch 94:  0.5517481565475464
# loss sur train dans epoch 95:  0.5499829053878784
# loss sur train dans epoch 96:  0.548209547996521
# loss sur train dans epoch 97:  0.5464255809783936
# loss sur train dans epoch 98:  0.5446376204490662
# loss sur train dans epoch 99:  0.5428460836410522
# loss sur train dans epoch 100:  0.5410513877868652
# loss sur train dans epoch 101:  0.5392555594444275
# loss sur train dans epoch 102:  0.5374584794044495
# loss sur train dans epoch 103:  0.5356594920158386
# loss sur train dans epoch 104:  0.5338589549064636
# loss sur train dans epoch 105:  0.5320584177970886
# loss sur train dans epoch 106:  0.5302629470825195
# loss sur train dans epoch 107:  0.5284758806228638
# loss sur train dans epoch 108:  0.526689887046814
# loss sur train dans epoch 109:  0.5249061584472656
# loss sur train dans epoch 110:  0.5231239795684814
# loss sur train dans epoch 111:  0.5213443636894226
# loss sur train dans epoch 112:  0.5195684432983398
# loss sur train dans epoch 113:  0.5177956223487854
# loss sur train dans epoch 114:  0.5160263180732727
# loss sur train dans epoch 115:  0.5142630934715271
# loss sur train dans epoch 116:  0.5125056505203247
# loss sur train dans epoch 117:  0.5107532739639282
# loss sur train dans epoch 118:  0.5090101361274719
# loss sur train dans epoch 119:  0.5072748064994812
# loss sur train dans epoch 120:  0.5055461525917053
# loss sur train dans epoch 121:  0.5038245320320129
# loss sur train dans epoch 122:  0.502110481262207
# loss sur train dans epoch 123:  0.5004042983055115
# loss sur train dans epoch 124:  0.4987066686153412
# loss sur train dans epoch 125:  0.4970201551914215
# loss sur train dans epoch 126:  0.4953508973121643
# loss sur train dans epoch 127:  0.49369144439697266
# loss sur train dans epoch 128:  0.49204206466674805
# loss sur train dans epoch 129:  0.49040332436561584
# loss sur train dans epoch 130:  0.4887755513191223
# loss sur train dans epoch 131:  0.48716145753860474
# loss sur train dans epoch 132:  0.4855601191520691
# loss sur train dans epoch 133:  0.4839720129966736
# loss sur train dans epoch 134:  0.48239603638648987
# loss sur train dans epoch 135:  0.4808325171470642
# loss sur train dans epoch 136:  0.47928181290626526
# loss sur train dans epoch 137:  0.47774404287338257
# loss sur train dans epoch 138:  0.47621965408325195
# loss sur train dans epoch 139:  0.4747087061405182
# loss sur train dans epoch 140:  0.47321146726608276
# loss sur train dans epoch 141:  0.47172850370407104
# loss sur train dans epoch 142:  0.4702613949775696
# loss sur train dans epoch 143:  0.46880850195884705
# loss sur train dans epoch 144:  0.4673701822757721
# loss sur train dans epoch 145:  0.4659481942653656
# loss sur train dans epoch 146:  0.4645414352416992
# loss sur train dans epoch 147:  0.46314936876296997
# loss sur train dans epoch 148:  0.46177205443382263
# loss sur train dans epoch 149:  0.460409551858902
# loss sur train dans epoch 150:  0.459061861038208
# loss sur train dans epoch 151:  0.45772919058799744
# loss sur train dans epoch 152:  0.45641136169433594
# loss sur train dans epoch 153:  0.455108642578125
# loss sur train dans epoch 154:  0.45382362604141235
# loss sur train dans epoch 155:  0.45255833864212036
# loss sur train dans epoch 156:  0.45130783319473267
# loss sur train dans epoch 157:  0.45007213950157166
# loss sur train dans epoch 158:  0.4488513469696045
# loss sur train dans epoch 159:  0.4476451873779297
# loss sur train dans epoch 160:  0.4464538097381592
# loss sur train dans epoch 161:  0.44527697563171387
# loss sur train dans epoch 162:  0.4441147744655609
# loss sur train dans epoch 163:  0.44296693801879883
# loss sur train dans epoch 164:  0.4418334364891052
# loss sur train dans epoch 165:  0.44071435928344727
# loss sur train dans epoch 166:  0.43960943818092346
# loss sur train dans epoch 167:  0.4385184645652771
# loss sur train dans epoch 168:  0.4374415874481201
# loss sur train dans epoch 169:  0.4363784193992615
# loss sur train dans epoch 170:  0.43532904982566833
# loss sur train dans epoch 171:  0.43429332971572876
# loss sur train dans epoch 172:  0.4332711100578308
# loss sur train dans epoch 173:  0.4322628080844879
# loss sur train dans epoch 174:  0.4312675893306732
# loss sur train dans epoch 175:  0.4302855134010315
# loss sur train dans epoch 176:  0.42931628227233887
# loss sur train dans epoch 177:  0.4283598065376282
# loss sur train dans epoch 178:  0.4274159073829651
# loss sur train dans epoch 179:  0.42648452520370483
# loss sur train dans epoch 180:  0.42556557059288025
# loss sur train dans epoch 181:  0.4246586859226227
# loss sur train dans epoch 182:  0.4237637519836426
# loss sur train dans epoch 183:  0.4228816032409668
# loss sur train dans epoch 184:  0.42201346158981323
# loss sur train dans epoch 185:  0.4211568832397461
# loss sur train dans epoch 186:  0.4203117787837982
# loss sur train dans epoch 187:  0.4194779396057129
# loss sur train dans epoch 188:  0.4186552166938782
# loss sur train dans epoch 189:  0.4178434908390045
# loss sur train dans epoch 190:  0.41704249382019043
# loss sur train dans epoch 191:  0.4162522256374359
# loss sur train dans epoch 192:  0.4154724180698395
# loss sur train dans epoch 193:  0.41470304131507874
# loss sur train dans epoch 194:  0.4139438569545746
# loss sur train dans epoch 195:  0.4131951928138733
# loss sur train dans epoch 196:  0.41245704889297485
# loss sur train dans epoch 197:  0.41172870993614197
# loss sur train dans epoch 198:  0.4110099673271179
# loss sur train dans epoch 199:  0.41030067205429077
# loss sur train dans epoch 200:  0.40960073471069336
# loss sur train dans epoch 201:  0.40890997648239136
# loss sur train dans epoch 202:  0.4082282483577728
# loss sur train dans epoch 203:  0.407555490732193
# loss sur train dans epoch 204:  0.40689143538475037
# loss sur train dans epoch 205:  0.4062359929084778
# loss sur train dans epoch 206:  0.4055919647216797
# loss sur train dans epoch 207:  0.40495628118515015
# loss sur train dans epoch 208:  0.4043288826942444
# loss sur train dans epoch 209:  0.4037095606327057
# loss sur train dans epoch 210:  0.4030986726284027
# loss sur train dans epoch 211:  0.4024960398674011
# loss sur train dans epoch 212:  0.40190115571022034
# loss sur train dans epoch 213:  0.4013138711452484
# loss sur train dans epoch 214:  0.4007340371608734
# loss sur train dans epoch 215:  0.40016159415245056
# loss sur train dans epoch 216:  0.3995964229106903
# loss sur train dans epoch 217:  0.3990383744239807
# loss sur train dans epoch 218:  0.3984873294830322
# loss sur train dans epoch 219:  0.3979432284832001
# loss sur train dans epoch 220:  0.3974059224128723
# loss sur train dans epoch 221:  0.39687538146972656
# loss sur train dans epoch 222:  0.3963513970375061
# loss sur train dans epoch 223:  0.39583390951156616
# loss sur train dans epoch 224:  0.39532309770584106
# loss sur train dans epoch 225:  0.394819051027298
# loss sur train dans epoch 226:  0.39432209730148315
# loss sur train dans epoch 227:  0.39383411407470703
# loss sur train dans epoch 228:  0.3933519721031189
# loss sur train dans epoch 229:  0.39287570118904114
# loss sur train dans epoch 230:  0.39240512251853943
# loss sur train dans epoch 231:  0.3919402062892914
# loss sur train dans epoch 232:  0.39148086309432983
# loss sur train dans epoch 233:  0.39102694392204285
# loss sur train dans epoch 234:  0.3905784785747528
# loss sur train dans epoch 235:  0.3901352286338806
# loss sur train dans epoch 236:  0.38969725370407104
# loss sur train dans epoch 237:  0.38926440477371216
# loss sur train dans epoch 238:  0.3888366222381592
# loss sur train dans epoch 239:  0.38841384649276733
# loss sur train dans epoch 240:  0.38799598813056946
# loss sur train dans epoch 241:  0.3875828981399536
# loss sur train dans epoch 242:  0.3871755003929138
# loss sur train dans epoch 243:  0.38677459955215454
# loss sur train dans epoch 244:  0.38637861609458923
# loss sur train dans epoch 245:  0.38598716259002686
# loss sur train dans epoch 246:  0.38560017943382263
# loss sur train dans epoch 247:  0.3852171003818512
# loss sur train dans epoch 248:  0.3848397135734558
# loss sur train dans epoch 249:  0.3844665586948395
# loss sur train dans epoch 250:  0.3840976059436798
# loss sur train dans epoch 251:  0.3837328255176544
# loss sur train dans epoch 252:  0.3833720088005066
# loss sur train dans epoch 253:  0.3830152153968811
# loss sur train dans epoch 254:  0.3826623558998108
# loss sur train dans epoch 255:  0.38231340050697327
# loss sur train dans epoch 256:  0.38196825981140137
# loss sur train dans epoch 257:  0.38162684440612793
# loss sur train dans epoch 258:  0.38128918409347534
# loss sur train dans epoch 259:  0.38095518946647644
# loss sur train dans epoch 260:  0.38062480092048645
# loss sur train dans epoch 261:  0.3802979588508606
# loss sur train dans epoch 262:  0.3799746334552765
# loss sur train dans epoch 263:  0.37965479493141174
# loss sur train dans epoch 264:  0.3793382942676544
# loss sur train dans epoch 265:  0.3790251612663269
# loss sur train dans epoch 266:  0.3787153661251068
# loss sur train dans epoch 267:  0.37840884923934937
# loss sur train dans epoch 268:  0.378105491399765
# loss sur train dans epoch 269:  0.37780535221099854
# loss sur train dans epoch 270:  0.377508282661438
# loss sur train dans epoch 271:  0.37721437215805054
# loss sur train dans epoch 272:  0.37692347168922424
# loss sur train dans epoch 273:  0.3766355514526367
# loss sur train dans epoch 274:  0.3763505816459656
# loss sur train dans epoch 275:  0.3760685324668884
# loss sur train dans epoch 276:  0.37578943371772766
# loss sur train dans epoch 277:  0.37551307678222656
# loss sur train dans epoch 278:  0.3752395808696747
# loss sur train dans epoch 279:  0.37496882677078247
# loss sur train dans epoch 280:  0.37470078468322754
# loss sur train dans epoch 281:  0.3744353950023651
# loss sur train dans epoch 282:  0.3741726577281952
# loss sur train dans epoch 283:  0.3739125728607178
# loss sur train dans epoch 284:  0.37365520000457764
# loss sur train dans epoch 285:  0.3734002709388733
# loss sur train dans epoch 286:  0.3731479048728943
# loss sur train dans epoch 287:  0.37289801239967346
# loss sur train dans epoch 288:  0.37265053391456604
# loss sur train dans epoch 289:  0.3724055290222168
# loss sur train dans epoch 290:  0.3721628487110138
# loss sur train dans epoch 291:  0.3719225227832794
# loss sur train dans epoch 292:  0.3716844618320465
# loss sur train dans epoch 293:  0.3714487850666046
# loss sur train dans epoch 294:  0.371215283870697
# loss sur train dans epoch 295:  0.3709840476512909
# loss sur train dans epoch 296:  0.37075501680374146
# loss sur train dans epoch 297:  0.3705281615257263
# loss sur train dans epoch 298:  0.3703034222126007
# loss sur train dans epoch 299:  0.37008076906204224
# loss sur train dans epoch 300:  0.3698602318763733
# loss sur train dans epoch 301:  0.3696417510509491
# loss sur train dans epoch 302:  0.36942535638809204
# loss sur train dans epoch 303:  0.3692108988761902
# loss sur train dans epoch 304:  0.3689984381198883
# loss sur train dans epoch 305:  0.3687880039215088
# loss sur train dans epoch 306:  0.3685809373855591
# loss sur train dans epoch 307:  0.3683757185935974
# loss sur train dans epoch 308:  0.36817240715026855
# loss sur train dans epoch 309:  0.36797091364860535
# loss sur train dans epoch 310:  0.3677712380886078
# loss sur train dans epoch 311:  0.3675733804702759
# loss sur train dans epoch 312:  0.36737728118896484
# loss sur train dans epoch 313:  0.3671829104423523
# loss sur train dans epoch 314:  0.36699026823043823
# loss sur train dans epoch 315:  0.36679935455322266
# loss sur train dans epoch 316:  0.36661022901535034
# loss sur train dans epoch 317:  0.3664229214191437
# loss sur train dans epoch 318:  0.36623719334602356
# loss sur train dans epoch 319:  0.36605316400527954
# loss sur train dans epoch 320:  0.3658706247806549
# loss sur train dans epoch 321:  0.365689754486084
# loss sur train dans epoch 322:  0.36551058292388916
# loss sur train dans epoch 323:  0.3653339445590973
# loss sur train dans epoch 324:  0.3651587963104248
# loss sur train dans epoch 325:  0.36498507857322693
# loss sur train dans epoch 326:  0.3648129105567932
# loss sur train dans epoch 327:  0.3646422028541565
# loss sur train dans epoch 328:  0.364472895860672
# loss sur train dans epoch 329:  0.3643050491809845
# loss sur train dans epoch 330:  0.36413854360580444
# loss sur train dans epoch 331:  0.3639734387397766
# loss sur train dans epoch 332:  0.3638097047805786
# loss sur train dans epoch 333:  0.36364737153053284
# loss sur train dans epoch 334:  0.36348631978034973
# loss sur train dans epoch 335:  0.3633270263671875
# loss sur train dans epoch 336:  0.36316993832588196
# loss sur train dans epoch 337:  0.36301419138908386
# loss sur train dans epoch 338:  0.3628596067428589
# loss sur train dans epoch 339:  0.36270633339881897
# loss sur train dans epoch 340:  0.36255425214767456
# loss sur train dans epoch 341:  0.36240339279174805
# loss sur train dans epoch 342:  0.36225372552871704
# loss sur train dans epoch 343:  0.36210525035858154
# loss sur train dans epoch 344:  0.3619579076766968
# loss sur train dans epoch 345:  0.3618117868900299
# loss sur train dans epoch 346:  0.361666738986969
# loss sur train dans epoch 347:  0.3615228533744812
# loss sur train dans epoch 348:  0.36138004064559937
# loss sur train dans epoch 349:  0.36123839020729065
# loss sur train dans epoch 350:  0.3610978126525879
# loss sur train dans epoch 351:  0.3609583079814911
# loss sur train dans epoch 352:  0.36081987619400024
# loss sur train dans epoch 353:  0.36068254709243774
# loss sur train dans epoch 354:  0.36054617166519165
# loss sur train dans epoch 355:  0.3604108691215515
# loss sur train dans epoch 356:  0.36027660965919495
# loss sur train dans epoch 357:  0.3601433336734772
# loss sur train dans epoch 358:  0.3600110709667206
# loss sur train dans epoch 359:  0.3598797917366028
# loss sur train dans epoch 360:  0.3597494959831238
# loss sur train dans epoch 361:  0.3596201539039612
# loss sur train dans epoch 362:  0.3594917953014374
# loss sur train dans epoch 363:  0.35936439037323
# loss sur train dans epoch 364:  0.3592378497123718
# loss sur train dans epoch 365:  0.35911232233047485
# loss sur train dans epoch 366:  0.3589876890182495
# loss sur train dans epoch 367:  0.3588639199733734
# loss sur train dans epoch 368:  0.3587411344051361
# loss sur train dans epoch 369:  0.35861915349960327
# loss sur train dans epoch 370:  0.35849815607070923
# loss sur train dans epoch 371:  0.3583779036998749
# loss sur train dans epoch 372:  0.3582586348056793
# loss sur train dans epoch 373:  0.35814014077186584
# loss sur train dans epoch 374:  0.3580224812030792
# loss sur train dans epoch 375:  0.35790571570396423
# loss sur train dans epoch 376:  0.3577897250652313
# loss sur train dans epoch 377:  0.35767459869384766
# loss sur train dans epoch 378:  0.3575602173805237
# loss sur train dans epoch 379:  0.35744673013687134
# loss sur train dans epoch 380:  0.3573339581489563
# loss sur train dans epoch 381:  0.35722196102142334
# loss sur train dans epoch 382:  0.3571108281612396
# loss sur train dans epoch 383:  0.3570004105567932
# loss sur train dans epoch 384:  0.3568907380104065
# loss sur train dans epoch 385:  0.35678184032440186
# loss sur train dans epoch 386:  0.3566737174987793
# loss sur train dans epoch 387:  0.35656633973121643
# loss sur train dans epoch 388:  0.3564596474170685
# loss sur train dans epoch 389:  0.3563537001609802
# loss sur train dans epoch 390:  0.3562484383583069
# loss sur train dans epoch 391:  0.3561439514160156
# loss sur train dans epoch 392:  0.35604017972946167
# loss sur train dans epoch 393:  0.35593700408935547
# loss sur train dans epoch 394:  0.35583460330963135
# loss sur train dans epoch 395:  0.35573282837867737
# loss sur train dans epoch 396:  0.3556317687034607
# loss sur train dans epoch 397:  0.35553139448165894
# loss sur train dans epoch 398:  0.3554316461086273
# loss sur train dans epoch 399:  0.355332612991333
# loss sur train dans epoch 400:  0.35523420572280884
# loss sur train dans epoch 401:  0.3551363945007324
# loss sur train dans epoch 402:  0.3550392985343933
# loss sur train dans epoch 403:  0.3549427390098572
# loss sur train dans epoch 404:  0.35484689474105835
# loss sur train dans epoch 405:  0.3547516465187073
# loss sur train dans epoch 406:  0.35465699434280396
# loss sur train dans epoch 407:  0.3545629382133484
# loss sur train dans epoch 408:  0.35446950793266296
# loss sur train dans epoch 409:  0.3543767035007477
# loss sur train dans epoch 410:  0.35428446531295776
# loss sur train dans epoch 411:  0.3541927933692932
# loss sur train dans epoch 412:  0.3541017174720764
# loss sur train dans epoch 413:  0.3540112376213074
# loss sur train dans epoch 414:  0.3539213538169861
# loss sur train dans epoch 415:  0.3538319766521454
# loss sur train dans epoch 416:  0.35374316573143005
# loss sur train dans epoch 417:  0.3536549508571625
# loss sur train dans epoch 418:  0.3535672128200531
# loss sur train dans epoch 419:  0.3534800708293915
# loss sur train dans epoch 420:  0.35339346528053284
# loss sur train dans epoch 421:  0.35330742597579956
# loss sur train dans epoch 422:  0.3532218635082245
# loss sur train dans epoch 423:  0.3531368374824524
# loss sur train dans epoch 424:  0.3530523478984833
# loss sur train dans epoch 425:  0.3529684245586395
# loss sur train dans epoch 426:  0.3528849184513092
# loss sur train dans epoch 427:  0.35280197858810425
# loss sur train dans epoch 428:  0.3527195155620575
# loss sur train dans epoch 429:  0.35263755917549133
# loss sur train dans epoch 430:  0.3525560796260834
# loss sur train dans epoch 431:  0.352475106716156
# loss sur train dans epoch 432:  0.35239464044570923
# loss sur train dans epoch 433:  0.35231465101242065
# loss sur train dans epoch 434:  0.3522351384162903
# loss sur train dans epoch 435:  0.35215601325035095
# loss sur train dans epoch 436:  0.3520774245262146
# loss sur train dans epoch 437:  0.35199931263923645
# loss sur train dans epoch 438:  0.35192161798477173
# loss sur train dans epoch 439:  0.3518444001674652
# loss sur train dans epoch 440:  0.3517676889896393
# loss sur train dans epoch 441:  0.351691335439682
# loss sur train dans epoch 442:  0.35161545872688293
# loss sur train dans epoch 443:  0.3515400290489197
# loss sur train dans epoch 444:  0.35146504640579224
# loss sur train dans epoch 445:  0.351390540599823
# loss sur train dans epoch 446:  0.35131630301475525
# loss sur train dans epoch 447:  0.35124263167381287
# loss sur train dans epoch 448:  0.3511693775653839
# loss sur train dans epoch 449:  0.351096510887146
# loss sur train dans epoch 450:  0.3510240912437439
# loss sur train dans epoch 451:  0.3509519696235657
# loss sur train dans epoch 452:  0.35088038444519043
# loss sur train dans epoch 453:  0.35080915689468384
# loss sur train dans epoch 454:  0.3507383465766907
# loss sur train dans epoch 455:  0.35066789388656616
# loss sur train dans epoch 456:  0.3505978584289551
# loss sur train dans epoch 457:  0.3505282402038574
# loss sur train dans epoch 458:  0.35045894980430603
# loss sur train dans epoch 459:  0.35039010643959045
# loss sur train dans epoch 460:  0.3503216505050659
# loss sur train dans epoch 461:  0.35025349259376526
# loss sur train dans epoch 462:  0.3501858115196228
# loss sur train dans epoch 463:  0.35011836886405945
# loss sur train dans epoch 464:  0.3500513732433319
# loss sur train dans epoch 465:  0.3499847948551178
# loss sur train dans epoch 466:  0.34991851449012756
# loss sur train dans epoch 467:  0.34985262155532837
# loss sur train dans epoch 468:  0.34978705644607544
# loss sur train dans epoch 469:  0.34972184896469116
# loss sur train dans epoch 470:  0.34965699911117554
# loss sur train dans epoch 471:  0.34959250688552856
# loss sur train dans epoch 472:  0.34952840209007263
# loss sur train dans epoch 473:  0.3494645357131958
# loss sur train dans epoch 474:  0.3494011163711548
# loss sur train dans epoch 475:  0.34933799505233765
# loss sur train dans epoch 476:  0.3492752015590668
# loss sur train dans epoch 477:  0.34921273589134216
# loss sur train dans epoch 478:  0.3491505980491638
# loss sur train dans epoch 479:  0.3490888178348541
# loss sur train dans epoch 480:  0.3490273356437683
# loss sur train dans epoch 481:  0.348966121673584
# loss sur train dans epoch 482:  0.3489052653312683
# loss sur train dans epoch 483:  0.34884482622146606
# loss sur train dans epoch 484:  0.34878456592559814
# loss sur train dans epoch 485:  0.34872469305992126
# loss sur train dans epoch 486:  0.34866511821746826
# loss sur train dans epoch 487:  0.34860581159591675
# loss sur train dans epoch 488:  0.3485468626022339
# loss sur train dans epoch 489:  0.3484881520271301
# loss sur train dans epoch 490:  0.348429799079895
# loss sur train dans epoch 491:  0.348371684551239
# loss sur train dans epoch 492:  0.34831398725509644
# loss sur train dans epoch 493:  0.3482564389705658
# loss sur train dans epoch 494:  0.3481992781162262
# loss sur train dans epoch 495:  0.3481423556804657
# loss sur train dans epoch 496:  0.3480857312679291
# loss sur train dans epoch 497:  0.34802940487861633
# loss sur train dans epoch 498:  0.3479733467102051
# loss sur train dans epoch 499:  0.3479175865650177
# loss sur train dans epoch 500:  0.3478620648384094
# loss sur train dans epoch 501:  0.3478069007396698
# loss sur train dans epoch 502:  0.3477518856525421
# loss sur train dans epoch 503:  0.3476972281932831
# loss sur train dans epoch 504:  0.34764283895492554
# loss sur train dans epoch 505:  0.3475887179374695
# loss sur train dans epoch 506:  0.34753483533859253
# loss sur train dans epoch 507:  0.34748122096061707
# loss sur train dans epoch 508:  0.34742793440818787
# loss sur train dans epoch 509:  0.34737491607666016
# loss sur train dans epoch 510:  0.34732216596603394
# loss sur train dans epoch 511:  0.3472696542739868
# loss sur train dans epoch 512:  0.3472173810005188
# loss sur train dans epoch 513:  0.34716537594795227
# loss sur train dans epoch 514:  0.34711357951164246
# loss sur train dans epoch 515:  0.3470621407032013
# loss sur train dans epoch 516:  0.34701085090637207
# loss sur train dans epoch 517:  0.3469598591327667
# loss sur train dans epoch 518:  0.3469090461730957
# loss sur train dans epoch 519:  0.34685853123664856
# loss sur train dans epoch 520:  0.34680822491645813
# loss sur train dans epoch 521:  0.3467581868171692
# loss sur train dans epoch 522:  0.34670835733413696
# loss sur train dans epoch 523:  0.34665876626968384
# loss sur train dans epoch 524:  0.3466094136238098
# loss sur train dans epoch 525:  0.3465602993965149
# loss sur train dans epoch 526:  0.3465113937854767
# loss sur train dans epoch 527:  0.3464627265930176
# loss sur train dans epoch 528:  0.3464142680168152
# loss sur train dans epoch 529:  0.34636610746383667
# loss sur train dans epoch 530:  0.3463180661201477
# loss sur train dans epoch 531:  0.34627029299736023
# loss sur train dans epoch 532:  0.34622272849082947
# loss sur train dans epoch 533:  0.3461753726005554
# loss sur train dans epoch 534:  0.34612828493118286
# loss sur train dans epoch 535:  0.34608137607574463
# loss sur train dans epoch 536:  0.3460347056388855
# loss sur train dans epoch 537:  0.3459882140159607
# loss sur train dans epoch 538:  0.3459419012069702
# loss sur train dans epoch 539:  0.34589582681655884
# loss sur train dans epoch 540:  0.34585005044937134
# loss sur train dans epoch 541:  0.3458043336868286
# loss sur train dans epoch 542:  0.3457588851451874
# loss sur train dans epoch 543:  0.34571367502212524
# loss sur train dans epoch 544:  0.34566861391067505
# loss sur train dans epoch 545:  0.34562379121780396
# loss sur train dans epoch 546:  0.3455791473388672
# loss sur train dans epoch 547:  0.3455347418785095
# loss sur train dans epoch 548:  0.3454904854297638
# loss sur train dans epoch 549:  0.3454464375972748
# loss sur train dans epoch 550:  0.3454025685787201
# loss sur train dans epoch 551:  0.3453589081764221
# loss sur train dans epoch 552:  0.34531542658805847
# loss sur train dans epoch 553:  0.3452721834182739
# loss sur train dans epoch 554:  0.3452290892601013
# loss sur train dans epoch 555:  0.34518617391586304
# loss sur train dans epoch 556:  0.3451434373855591
# loss sur train dans epoch 557:  0.34510093927383423
# loss sur train dans epoch 558:  0.3450585603713989
# loss sur train dans epoch 559:  0.3450164198875427
# loss sur train dans epoch 560:  0.34497445821762085
# loss sur train dans epoch 561:  0.3449326157569885
# loss sur train dans epoch 562:  0.3448910117149353
# loss sur train dans epoch 563:  0.344849556684494
# loss sur train dans epoch 564:  0.34480828046798706
# loss sur train dans epoch 565:  0.34476715326309204
# loss sur train dans epoch 566:  0.3447262644767761
# loss sur train dans epoch 567:  0.34468549489974976
# loss sur train dans epoch 568:  0.3446449339389801
# loss sur train dans epoch 569:  0.3446045517921448
# loss sur train dans epoch 570:  0.3445643186569214
# loss sur train dans epoch 571:  0.3445242941379547
# loss sur train dans epoch 572:  0.3444843292236328
# loss sur train dans epoch 573:  0.3444445729255676
# loss sur train dans epoch 574:  0.34440499544143677
# loss sur train dans epoch 575:  0.3443656265735626
# loss sur train dans epoch 576:  0.3443264067173004
# loss sur train dans epoch 577:  0.34428730607032776
# loss sur train dans epoch 578:  0.34424838423728943
# loss sur train dans epoch 579:  0.34420961141586304
# loss sur train dans epoch 580:  0.34417104721069336
# loss sur train dans epoch 581:  0.34413260221481323
# loss sur train dans epoch 582:  0.3440943658351898
# loss sur train dans epoch 583:  0.34405621886253357
# loss sur train dans epoch 584:  0.34401822090148926
# loss sur train dans epoch 585:  0.34398043155670166
# loss sur train dans epoch 586:  0.3439427316188812
# loss sur train dans epoch 587:  0.3439052402973175
# loss sur train dans epoch 588:  0.3438678979873657
# loss sur train dans epoch 589:  0.3438306748867035
# loss sur train dans epoch 590:  0.3437936007976532
# loss sur train dans epoch 591:  0.3437567353248596
# loss sur train dans epoch 592:  0.3437199294567108
# loss sur train dans epoch 593:  0.34368330240249634
# loss sur train dans epoch 594:  0.3436468243598938
# loss sur train dans epoch 595:  0.343610554933548
# loss sur train dans epoch 596:  0.3435743451118469
# loss sur train dans epoch 597:  0.3435382843017578
# loss sur train dans epoch 598:  0.3435024321079254
# loss sur train dans epoch 599:  0.3434666395187378
# loss sur train dans epoch 600:  0.3434310555458069
# loss sur train dans epoch 601:  0.34339556097984314
# loss sur train dans epoch 602:  0.3433602452278137
# loss sur train dans epoch 603:  0.34332507848739624
# loss sur train dans epoch 604:  0.3432900011539459
# loss sur train dans epoch 605:  0.34325510263442993
# loss sur train dans epoch 606:  0.3432202935218811
# loss sur train dans epoch 607:  0.3431856334209442
# loss sur train dans epoch 608:  0.34315112233161926
# loss sur train dans epoch 609:  0.34311676025390625
# loss sur train dans epoch 610:  0.3430824875831604
# loss sur train dans epoch 611:  0.3430483639240265
# loss sur train dans epoch 612:  0.3430143892765045
# loss sur train dans epoch 613:  0.3429805040359497
# loss sur train dans epoch 614:  0.34294676780700684
# loss sur train dans epoch 615:  0.3429132103919983
# loss sur train dans epoch 616:  0.3428797423839569
# loss sur train dans epoch 617:  0.3428463339805603
# loss sur train dans epoch 618:  0.3428131639957428
# loss sur train dans epoch 619:  0.34278005361557007
# loss sur train dans epoch 620:  0.3427470922470093
# loss sur train dans epoch 621:  0.34271425008773804
# loss sur train dans epoch 622:  0.34268152713775635
# loss sur train dans epoch 623:  0.3426489233970642
# loss sur train dans epoch 624:  0.342616468667984
# loss sur train dans epoch 625:  0.34258413314819336
# loss sur train dans epoch 626:  0.3425518870353699
# loss sur train dans epoch 627:  0.34251973032951355
# loss sur train dans epoch 628:  0.34248775243759155
# loss sur train dans epoch 629:  0.3424559235572815
# loss sur train dans epoch 630:  0.3424241244792938
# loss sur train dans epoch 631:  0.3423924744129181
# loss sur train dans epoch 632:  0.3423609137535095
# loss sur train dans epoch 633:  0.3423295319080353
# loss sur train dans epoch 634:  0.3422982394695282
# loss sur train dans epoch 635:  0.34226706624031067
# loss sur train dans epoch 636:  0.3422359526157379
# loss sur train dans epoch 637:  0.3422050178050995
# loss sur train dans epoch 638:  0.3421741724014282
# loss sur train dans epoch 639:  0.3421434760093689
# loss sur train dans epoch 640:  0.34211283922195435
# loss sur train dans epoch 641:  0.34208235144615173
# loss sur train dans epoch 642:  0.3420519530773163
# loss sur train dans epoch 643:  0.342021644115448
# loss sur train dans epoch 644:  0.34199148416519165
# loss sur train dans epoch 645:  0.3419613838195801
# loss sur train dans epoch 646:  0.34193143248558044
# loss sur train dans epoch 647:  0.341901570558548
# loss sur train dans epoch 648:  0.34187182784080505
# loss sur train dans epoch 649:  0.3418422043323517
# loss sur train dans epoch 650:  0.3418126702308655
# loss sur train dans epoch 651:  0.34178319573402405
# loss sur train dans epoch 652:  0.34175387024879456
# loss sur train dans epoch 653:  0.3417246341705322
# loss sur train dans epoch 654:  0.34169554710388184
# loss sur train dans epoch 655:  0.3416665196418762
# loss sur train dans epoch 656:  0.34163758158683777
# loss sur train dans epoch 657:  0.34160876274108887
# loss sur train dans epoch 658:  0.34158000349998474
# loss sur train dans epoch 659:  0.34155142307281494
# loss sur train dans epoch 660:  0.3415229022502899
# loss sur train dans epoch 661:  0.34149444103240967
# loss sur train dans epoch 662:  0.34146612882614136
# loss sur train dans epoch 663:  0.3414379060268402
# loss sur train dans epoch 664:  0.3414098024368286
# loss sur train dans epoch 665:  0.3413817584514618
# loss sur train dans epoch 666:  0.3413538336753845
# loss sur train dans epoch 667:  0.341325968503952
# loss sur train dans epoch 668:  0.34129825234413147
# loss sur train dans epoch 669:  0.3412706255912781
# loss sur train dans epoch 670:  0.34124302864074707
# loss sur train dans epoch 671:  0.341215580701828
# loss sur train dans epoch 672:  0.3411882519721985
# loss sur train dans epoch 673:  0.34116095304489136
# loss sur train dans epoch 674:  0.3411337435245514
# loss sur train dans epoch 675:  0.34110671281814575
# loss sur train dans epoch 676:  0.3410796821117401
# loss sur train dans epoch 677:  0.341052770614624
# loss sur train dans epoch 678:  0.3410259485244751
# loss sur train dans epoch 679:  0.34099921584129333
# loss sur train dans epoch 680:  0.34097257256507874
# loss sur train dans epoch 681:  0.3409460484981537
# loss sur train dans epoch 682:  0.340919554233551
# loss sur train dans epoch 683:  0.3408932089805603
# loss sur train dans epoch 684:  0.34086689352989197
# loss sur train dans epoch 685:  0.3408406972885132
# loss sur train dans epoch 686:  0.34081459045410156
# loss sur train dans epoch 687:  0.3407885730266571
# loss sur train dans epoch 688:  0.3407626748085022
# loss sur train dans epoch 689:  0.34073683619499207
# loss sur train dans epoch 690:  0.3407110869884491
# loss sur train dans epoch 691:  0.3406854271888733
# loss sur train dans epoch 692:  0.3406599164009094
# loss sur train dans epoch 693:  0.3406343460083008
# loss sur train dans epoch 694:  0.34060895442962646
# loss sur train dans epoch 695:  0.3405836224555969
# loss sur train dans epoch 696:  0.34055835008621216
# loss sur train dans epoch 697:  0.34053319692611694
# loss sur train dans epoch 698:  0.3405081331729889
# loss sur train dans epoch 699:  0.3404831290245056
# loss sur train dans epoch 700:  0.3404581546783447
# loss sur train dans epoch 701:  0.3404332995414734
# loss sur train dans epoch 702:  0.3404085636138916
# loss sur train dans epoch 703:  0.3403838574886322
# loss sur train dans epoch 704:  0.34035927057266235
# loss sur train dans epoch 705:  0.3403347432613373
# loss sur train dans epoch 706:  0.340310275554657
# loss sur train dans epoch 707:  0.34028592705726624
# loss sur train dans epoch 708:  0.3402616083621979
# loss sur train dans epoch 709:  0.3402373790740967
# loss sur train dans epoch 710:  0.34021326899528503
# loss sur train dans epoch 711:  0.3401891887187958
# loss sur train dans epoch 712:  0.3401651978492737
# loss sur train dans epoch 713:  0.34014129638671875
# loss sur train dans epoch 714:  0.3401174545288086
# loss sur train dans epoch 715:  0.3400936722755432
# loss sur train dans epoch 716:  0.3400699496269226
# loss sur train dans epoch 717:  0.34004634618759155
# loss sur train dans epoch 718:  0.34002283215522766
# loss sur train dans epoch 719:  0.33999937772750854
# loss sur train dans epoch 720:  0.3399759531021118
# loss sur train dans epoch 721:  0.33995261788368225
# loss sur train dans epoch 722:  0.33992940187454224
# loss sur train dans epoch 723:  0.3399061858654022
# loss sur train dans epoch 724:  0.33988308906555176
# loss sur train dans epoch 725:  0.3398600220680237
# loss sur train dans epoch 726:  0.33983710408210754
# loss sur train dans epoch 727:  0.3398142158985138
# loss sur train dans epoch 728:  0.3397913873195648
# loss sur train dans epoch 729:  0.3397686183452606
# loss sur train dans epoch 730:  0.3397459387779236
# loss sur train dans epoch 731:  0.3397233486175537
# loss sur train dans epoch 732:  0.3397007882595062
# loss sur train dans epoch 733:  0.3396782875061035
# loss sur train dans epoch 734:  0.33965587615966797
# loss sur train dans epoch 735:  0.3396335244178772
# loss sur train dans epoch 736:  0.339611291885376
# loss sur train dans epoch 737:  0.33958905935287476
# loss sur train dans epoch 738:  0.3395668864250183
# loss sur train dans epoch 739:  0.3395448625087738
# loss sur train dans epoch 740:  0.3395228385925293
# loss sur train dans epoch 741:  0.33950087428092957
# loss sur train dans epoch 742:  0.3394790291786194
# loss sur train dans epoch 743:  0.3394572138786316
# loss sur train dans epoch 744:  0.3394354283809662
# loss sur train dans epoch 745:  0.3394137918949127
# loss sur train dans epoch 746:  0.33939215540885925
# loss sur train dans epoch 747:  0.33937057852745056
# loss sur train dans epoch 748:  0.3393491208553314
# loss sur train dans epoch 749:  0.33932769298553467
# loss sur train dans epoch 750:  0.3393063545227051
# loss sur train dans epoch 751:  0.33928507566452026
# loss sur train dans epoch 752:  0.33926382660865784
# loss sur train dans epoch 753:  0.3392426371574402
# loss sur train dans epoch 754:  0.3392215669155121
# loss sur train dans epoch 755:  0.3392004668712616
# loss sur train dans epoch 756:  0.33917948603630066
# loss sur train dans epoch 757:  0.3391585946083069
# loss sur train dans epoch 758:  0.3391377329826355
# loss sur train dans epoch 759:  0.3391169011592865
# loss sur train dans epoch 760:  0.3390961289405823
# loss sur train dans epoch 761:  0.33907550573349
# loss sur train dans epoch 762:  0.33905482292175293
# loss sur train dans epoch 763:  0.3390342593193054
# loss sur train dans epoch 764:  0.3390137553215027
# loss sur train dans epoch 765:  0.3389933109283447
# loss sur train dans epoch 766:  0.33897295594215393
# loss sur train dans epoch 767:  0.33895260095596313
# loss sur train dans epoch 768:  0.3389323353767395
# loss sur train dans epoch 769:  0.33891209959983826
# loss sur train dans epoch 770:  0.33889198303222656
# loss sur train dans epoch 771:  0.33887186646461487
# loss sur train dans epoch 772:  0.33885183930397034
# loss sur train dans epoch 773:  0.3388318419456482
# loss sur train dans epoch 774:  0.3388119041919708
# loss sur train dans epoch 775:  0.33879202604293823
# loss sur train dans epoch 776:  0.3387722373008728
# loss sur train dans epoch 777:  0.33875247836112976
# loss sur train dans epoch 778:  0.3387327492237091
# loss sur train dans epoch 779:  0.3387131094932556
# loss sur train dans epoch 780:  0.3386934697628021
# loss sur train dans epoch 781:  0.33867397904396057
# loss sur train dans epoch 782:  0.3386545181274414
# loss sur train dans epoch 783:  0.33863508701324463
# loss sur train dans epoch 784:  0.3386157155036926
# loss sur train dans epoch 785:  0.3385964035987854
# loss sur train dans epoch 786:  0.33857712149620056
# loss sur train dans epoch 787:  0.3385578989982605
# loss sur train dans epoch 788:  0.3385387361049652
# loss sur train dans epoch 789:  0.3385196328163147
# loss sur train dans epoch 790:  0.3385005593299866
# loss sur train dans epoch 791:  0.338481605052948
# loss sur train dans epoch 792:  0.3384626507759094
# loss sur train dans epoch 793:  0.33844369649887085
# loss sur train dans epoch 794:  0.3384249806404114
# loss sur train dans epoch 795:  0.3384063243865967
# loss sur train dans epoch 796:  0.338387668132782
# loss sur train dans epoch 797:  0.33836913108825684
# loss sur train dans epoch 798:  0.3383505940437317
# loss sur train dans epoch 799:  0.3383321464061737
# loss sur train dans epoch 800:  0.3383137285709381
# loss sur train dans epoch 801:  0.3382953703403473
# loss sur train dans epoch 802:  0.33827701210975647
# loss sur train dans epoch 803:  0.3382587730884552
# loss sur train dans epoch 804:  0.33824053406715393
# loss sur train dans epoch 805:  0.3382224142551422
# loss sur train dans epoch 806:  0.3382042944431305
# loss sur train dans epoch 807:  0.33818620443344116
# loss sur train dans epoch 808:  0.33816808462142944
# loss sur train dans epoch 809:  0.3381502032279968
# loss sur train dans epoch 810:  0.33813223242759705
# loss sur train dans epoch 811:  0.3381143808364868
# loss sur train dans epoch 812:  0.3380965292453766
# loss sur train dans epoch 813:  0.3380787670612335
# loss sur train dans epoch 814:  0.33806100487709045
# loss sur train dans epoch 815:  0.33804330229759216
# loss sur train dans epoch 816:  0.33802568912506104
# loss sur train dans epoch 817:  0.3380080759525299
# loss sur train dans epoch 818:  0.33799052238464355
# loss sur train dans epoch 819:  0.3379729986190796
# loss sur train dans epoch 820:  0.3379555344581604
# loss sur train dans epoch 821:  0.337938129901886
# loss sur train dans epoch 822:  0.3379207253456116
# loss sur train dans epoch 823:  0.3379034101963043
# loss sur train dans epoch 824:  0.33788612484931946
# loss sur train dans epoch 825:  0.33786889910697937
# loss sur train dans epoch 826:  0.33785170316696167
# loss sur train dans epoch 827:  0.33783453702926636
# loss sur train dans epoch 828:  0.3378174304962158
# loss sur train dans epoch 829:  0.33780038356781006
# loss sur train dans epoch 830:  0.3377833962440491
# loss sur train dans epoch 831:  0.3377663791179657
# loss sur train dans epoch 832:  0.3377494812011719
# loss sur train dans epoch 833:  0.33773255348205566
# loss sur train dans epoch 834:  0.337715744972229
# loss sur train dans epoch 835:  0.33769893646240234
# loss sur train dans epoch 836:  0.33768218755722046
# loss sur train dans epoch 837:  0.33766549825668335
# loss sur train dans epoch 838:  0.33764877915382385
# loss sur train dans epoch 839:  0.3376321792602539
# loss sur train dans epoch 840:  0.33761557936668396
# loss sur train dans epoch 841:  0.3375987112522125
# loss sur train dans epoch 842:  0.3375822901725769
# loss sur train dans epoch 843:  0.33756598830223083
# loss sur train dans epoch 844:  0.33754968643188477
# loss sur train dans epoch 845:  0.3375333845615387
# loss sur train dans epoch 846:  0.3375171720981598
# loss sur train dans epoch 847:  0.33750101923942566
# loss sur train dans epoch 848:  0.3374848961830139
# loss sur train dans epoch 849:  0.3374687731266022
# loss sur train dans epoch 850:  0.33745265007019043
# loss sur train dans epoch 851:  0.3374366760253906
# loss sur train dans epoch 852:  0.33742067217826843
# loss sur train dans epoch 853:  0.337404727935791
# loss sur train dans epoch 854:  0.337388813495636
# loss sur train dans epoch 855:  0.33737295866012573
# loss sur train dans epoch 856:  0.33735716342926025
# loss sur train dans epoch 857:  0.3373413681983948
# loss sur train dans epoch 858:  0.3373256325721741
# loss sur train dans epoch 859:  0.33730992674827576
# loss sur train dans epoch 860:  0.33729425072669983
# loss sur train dans epoch 861:  0.3372786045074463
# loss sur train dans epoch 862:  0.3372630178928375
# loss sur train dans epoch 863:  0.33724749088287354
# loss sur train dans epoch 864:  0.33723193407058716
# loss sur train dans epoch 865:  0.33721643686294556
# loss sur train dans epoch 866:  0.3372010588645935
# loss sur train dans epoch 867:  0.3371856212615967
# loss sur train dans epoch 868:  0.337170273065567
# loss sur train dans epoch 869:  0.33715492486953735
# loss sur train dans epoch 870:  0.33713966608047485
# loss sur train dans epoch 871:  0.33712443709373474
# loss sur train dans epoch 872:  0.3371092677116394
# loss sur train dans epoch 873:  0.3370940685272217
# loss sur train dans epoch 874:  0.3370789885520935
# loss sur train dans epoch 875:  0.33706384897232056
# loss sur train dans epoch 876:  0.3370487689971924
# loss sur train dans epoch 877:  0.337033748626709
# loss sur train dans epoch 878:  0.33701878786087036
# loss sur train dans epoch 879:  0.33700382709503174
# loss sur train dans epoch 880:  0.3369888961315155
# loss sur train dans epoch 881:  0.33697405457496643
# loss sur train dans epoch 882:  0.33695918321609497
# loss sur train dans epoch 883:  0.3369443714618683
# loss sur train dans epoch 884:  0.336929589509964
# loss sur train dans epoch 885:  0.3369148373603821
# loss sur train dans epoch 886:  0.33690017461776733
# loss sur train dans epoch 887:  0.3368855118751526
# loss sur train dans epoch 888:  0.33687084913253784
# loss sur train dans epoch 889:  0.3368562161922455
# loss sur train dans epoch 890:  0.3368416428565979
# loss sur train dans epoch 891:  0.3368271291255951
# loss sur train dans epoch 892:  0.3368125855922699
# loss sur train dans epoch 893:  0.33679813146591187
# loss sur train dans epoch 894:  0.3367837369441986
# loss sur train dans epoch 895:  0.33676931262016296
# loss sur train dans epoch 896:  0.3367549479007721
# loss sur train dans epoch 897:  0.3367405831813812
# loss sur train dans epoch 898:  0.3367263376712799
# loss sur train dans epoch 899:  0.3367120623588562
# loss sur train dans epoch 900:  0.3366978168487549
# loss sur train dans epoch 901:  0.33668360114097595
# loss sur train dans epoch 902:  0.3366694748401642
# loss sur train dans epoch 903:  0.33665531873703003
# loss sur train dans epoch 904:  0.33664122223854065
# loss sur train dans epoch 905:  0.3366270959377289
# loss sur train dans epoch 906:  0.3366130590438843
# loss sur train dans epoch 907:  0.33659908175468445
# loss sur train dans epoch 908:  0.336585134267807
# loss sur train dans epoch 909:  0.3365711569786072
# loss sur train dans epoch 910:  0.3365572392940521
# loss sur train dans epoch 911:  0.33654338121414185
# loss sur train dans epoch 912:  0.33652955293655396
# loss sur train dans epoch 913:  0.3365156650543213
# loss sur train dans epoch 914:  0.3365018963813782
# loss sur train dans epoch 915:  0.33648818731307983
# loss sur train dans epoch 916:  0.3364744186401367
# loss sur train dans epoch 917:  0.33646076917648315
# loss sur train dans epoch 918:  0.3364470601081848
# loss sur train dans epoch 919:  0.336433470249176
# loss sur train dans epoch 920:  0.33641988039016724
# loss sur train dans epoch 921:  0.33640629053115845
# loss sur train dans epoch 922:  0.33639273047447205
# loss sur train dans epoch 923:  0.3363792300224304
# loss sur train dans epoch 924:  0.3363657295703888
# loss sur train dans epoch 925:  0.33635228872299194
# loss sur train dans epoch 926:  0.3363388776779175
# loss sur train dans epoch 927:  0.3363254964351654
# loss sur train dans epoch 928:  0.33631211519241333
# loss sur train dans epoch 929:  0.3362988531589508
# loss sur train dans epoch 930:  0.3362855315208435
# loss sur train dans epoch 931:  0.3362722396850586
# loss sur train dans epoch 932:  0.33625900745391846
# loss sur train dans epoch 933:  0.3362458050251007
# loss sur train dans epoch 934:  0.33623260259628296
# loss sur train dans epoch 935:  0.33621945977211
# loss sur train dans epoch 936:  0.336206316947937
# loss sur train dans epoch 937:  0.3361932337284088
# loss sur train dans epoch 938:  0.3361801505088806
# loss sur train dans epoch 939:  0.3361671268939972
# loss sur train dans epoch 940:  0.33615410327911377
# loss sur train dans epoch 941:  0.3361411392688751
# loss sur train dans epoch 942:  0.3361281752586365
# loss sur train dans epoch 943:  0.3361152410507202
# loss sur train dans epoch 944:  0.33610233664512634
# loss sur train dans epoch 945:  0.33608949184417725
# loss sur train dans epoch 946:  0.33607667684555054
# loss sur train dans epoch 947:  0.33606380224227905
# loss sur train dans epoch 948:  0.3360510468482971
# loss sur train dans epoch 949:  0.3360382914543152
# loss sur train dans epoch 950:  0.33602556586265564
# loss sur train dans epoch 951:  0.3360128700733185
# loss sur train dans epoch 952:  0.33600014448165894
# loss sur train dans epoch 953:  0.33598750829696655
# loss sur train dans epoch 954:  0.33597487211227417
# loss sur train dans epoch 955:  0.33596229553222656
# loss sur train dans epoch 956:  0.33594974875450134
# loss sur train dans epoch 957:  0.3359372019767761
# loss sur train dans epoch 958:  0.3359246850013733
# loss sur train dans epoch 959:  0.33591219782829285
# loss sur train dans epoch 960:  0.3358997404575348
# loss sur train dans epoch 961:  0.3358873128890991
# loss sur train dans epoch 962:  0.33587488532066345
# loss sur train dans epoch 963:  0.33586251735687256
# loss sur train dans epoch 964:  0.33585017919540405
# loss sur train dans epoch 965:  0.33583787083625793
# loss sur train dans epoch 966:  0.33582550287246704
# loss sur train dans epoch 967:  0.3358132541179657
# loss sur train dans epoch 968:  0.3358009457588196
# loss sur train dans epoch 969:  0.335788756608963
# loss sur train dans epoch 970:  0.33577656745910645
# loss sur train dans epoch 971:  0.33576440811157227
# loss sur train dans epoch 972:  0.3357522785663605
# loss sur train dans epoch 973:  0.3357401490211487
# loss sur train dans epoch 974:  0.3357280492782593
# loss sur train dans epoch 975:  0.33571597933769226
# loss sur train dans epoch 976:  0.33570393919944763
# loss sur train dans epoch 977:  0.3356918692588806
# loss sur train dans epoch 978:  0.33567988872528076
# loss sur train dans epoch 979:  0.3356679081916809
# loss sur train dans epoch 980:  0.33565595746040344
# loss sur train dans epoch 981:  0.33564406633377075
# loss sur train dans epoch 982:  0.3356321156024933
# loss sur train dans epoch 983:  0.33562028408050537
# loss sur train dans epoch 984:  0.33560842275619507
# loss sur train dans epoch 985:  0.33559662103652954
# loss sur train dans epoch 986:  0.335584819316864
# loss sur train dans epoch 987:  0.3355730473995209
# loss sur train dans epoch 988:  0.3355613052845001
# loss sur train dans epoch 989:  0.335549533367157
# loss sur train dans epoch 990:  0.335537850856781
# loss sur train dans epoch 991:  0.33552616834640503
# loss sur train dans epoch 992:  0.33551451563835144
# loss sur train dans epoch 993:  0.33550286293029785
# loss sur train dans epoch 994:  0.3354912996292114
# loss sur train dans epoch 995:  0.3354797065258026
# loss sur train dans epoch 996:  0.3354680836200714
# loss sur train dans epoch 997:  0.33545657992362976
# loss sur train dans epoch 998:  0.3354450762271881
# loss sur train dans epoch 999:  0.33543357253074646

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.4 Simplification de SGD avec torch.optim </font><font color='#87CEFA'> torch.optim</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. Initialisation d'un Modèle de Réseau de Neurones pour la Classification  avec PyTorch</font></h3>

# %%
def init_model_auto(nx, nh, ny, eta):
    model = torch.nn.Sequential(
        torch.nn.Linear(nx, nh), # Couche linéaire d'entrée à la couche cachée
        torch.nn.ReLU(),         # Fonction d'activation ReLU pour la couche cachée max(0, z)
        torch.nn.Linear(nh, ny), # Couche linéaire de la couche cachée à la couche de sortie
        torch.nn.Softmax(dim=1)  # Fonction d'activation Softmax pour la couche de sortie (classification du multiclasse)
        #torch.nn.Sigmoid()
        
    )
    # Définition de la fonction de perte CrossEntropyLoss pour une tâche de classification multiclasse
    loss = torch.nn.CrossEntropyLoss()
    # Définition de l'optimiseur stochastique de descente de gradient (SGD) avec le taux d'apprentissage (eta) spécifié
    optim = torch.optim.SGD(model.parameters(), lr=eta)
    return model, loss, optim

# %% [markdown]
# <h3><font color='#1E90FF'> B. Application</font></h3>

# %%
N_epoch = 100 #nombre des epoch
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate
#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
# Convertir les arrays NumPy en tensors PyTorch
X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.int64)

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []

#initialiser les paramètres du modèle 
model_auto, loss_auto, optim_auto = init_model_auto(2, 4, 2, 0.02)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    loss_glob = 0 #Réinitialiser la perte  du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[j:i * batch, :]
        Y_epoch = Y[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.    
    if (N % batch != 0 and i ==  N // batch ) : 
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[ j : N, :]
        Y_epoch = Y[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss_glob /= (N // batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} : ", loss_glob.item())
    loss_history.append(loss_glob.item())
    
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 :  0.6996732354164124
# loss sur train dans epoch 1 :  0.6980328559875488
# loss sur train dans epoch 2 :  0.6965259313583374
# loss sur train dans epoch 3 :  0.6950393915176392
# loss sur train dans epoch 4 :  0.6935787200927734
# loss sur train dans epoch 5 :  0.692114531993866
# loss sur train dans epoch 6 :  0.6906554698944092
# loss sur train dans epoch 7 :  0.6891611814498901
# loss sur train dans epoch 8 :  0.6875468492507935
# loss sur train dans epoch 9 :  0.6858446598052979
# loss sur train dans epoch 10 :  0.6840762495994568
# loss sur train dans epoch 11 :  0.6822506189346313
# loss sur train dans epoch 12 :  0.680362343788147
# loss sur train dans epoch 13 :  0.6783742308616638
# loss sur train dans epoch 14 :  0.6762621998786926
# loss sur train dans epoch 15 :  0.6740754246711731
# loss sur train dans epoch 16 :  0.6717655658721924
# loss sur train dans epoch 17 :  0.6693524122238159
# loss sur train dans epoch 18 :  0.6668480634689331
# loss sur train dans epoch 19 :  0.6641829609870911
# loss sur train dans epoch 20 :  0.6613874435424805
# loss sur train dans epoch 21 :  0.6584939360618591
# loss sur train dans epoch 22 :  0.6554706692695618
# loss sur train dans epoch 23 :  0.6523435115814209
# loss sur train dans epoch 24 :  0.6490839719772339
# loss sur train dans epoch 25 :  0.6456584930419922
# loss sur train dans epoch 26 :  0.6421019434928894
# loss sur train dans epoch 27 :  0.6384199261665344
# loss sur train dans epoch 28 :  0.6346606016159058
# loss sur train dans epoch 29 :  0.6308889985084534
# loss sur train dans epoch 30 :  0.6270264387130737
# loss sur train dans epoch 31 :  0.6229810118675232
# loss sur train dans epoch 32 :  0.6188132166862488
# loss sur train dans epoch 33 :  0.6145584583282471
# loss sur train dans epoch 34 :  0.6101731061935425
# loss sur train dans epoch 35 :  0.6057154536247253
# loss sur train dans epoch 36 :  0.6013225317001343
# loss sur train dans epoch 37 :  0.5968872308731079
# loss sur train dans epoch 38 :  0.5924192667007446
# loss sur train dans epoch 39 :  0.5879279971122742
# loss sur train dans epoch 40 :  0.5834234952926636
# loss sur train dans epoch 41 :  0.5789154767990112
# loss sur train dans epoch 42 :  0.5744104385375977
# loss sur train dans epoch 43 :  0.5699167847633362
# loss sur train dans epoch 44 :  0.5654503107070923
# loss sur train dans epoch 45 :  0.5610106587409973
# loss sur train dans epoch 46 :  0.5564828515052795
# loss sur train dans epoch 47 :  0.551918625831604
# loss sur train dans epoch 48 :  0.5473920702934265
# loss sur train dans epoch 49 :  0.5429232120513916
# loss sur train dans epoch 50 :  0.5385701060295105
# loss sur train dans epoch 51 :  0.5342735052108765
# loss sur train dans epoch 52 :  0.5300373435020447
# loss sur train dans epoch 53 :  0.525873064994812
# loss sur train dans epoch 54 :  0.5218722820281982
# loss sur train dans epoch 55 :  0.5179757475852966
# loss sur train dans epoch 56 :  0.5141513347625732
# loss sur train dans epoch 57 :  0.5104005336761475
# loss sur train dans epoch 58 :  0.50672447681427
# loss sur train dans epoch 59 :  0.5031260251998901
# loss sur train dans epoch 60 :  0.4996088147163391
# loss sur train dans epoch 61 :  0.4961780607700348
# loss sur train dans epoch 62 :  0.49284058809280396
# loss sur train dans epoch 63 :  0.4895785450935364
# loss sur train dans epoch 64 :  0.4863917827606201
# loss sur train dans epoch 65 :  0.4832799434661865
# loss sur train dans epoch 66 :  0.48024266958236694
# loss sur train dans epoch 67 :  0.47730961441993713
# loss sur train dans epoch 68 :  0.4744747579097748
# loss sur train dans epoch 69 :  0.47175711393356323
# loss sur train dans epoch 70 :  0.46910780668258667
# loss sur train dans epoch 71 :  0.46652549505233765
# loss sur train dans epoch 72 :  0.46400851011276245
# loss sur train dans epoch 73 :  0.46155548095703125
# loss sur train dans epoch 74 :  0.4591650366783142
# loss sur train dans epoch 75 :  0.45683544874191284
# loss sur train dans epoch 76 :  0.4545654356479645
# loss sur train dans epoch 77 :  0.4523535370826721
# loss sur train dans epoch 78 :  0.45019832253456116
# loss sur train dans epoch 79 :  0.44809824228286743
# loss sur train dans epoch 80 :  0.4460519254207611
# loss sur train dans epoch 81 :  0.4440580904483795
# loss sur train dans epoch 82 :  0.4421151578426361
# loss sur train dans epoch 83 :  0.4402220845222473
# loss sur train dans epoch 84 :  0.43837714195251465
# loss sur train dans epoch 85 :  0.43657922744750977
# loss sur train dans epoch 86 :  0.4348270297050476
# loss sur train dans epoch 87 :  0.4331192374229431
# loss sur train dans epoch 88 :  0.4314545691013336
# loss sur train dans epoch 89 :  0.42983150482177734
# loss sur train dans epoch 90 :  0.4282492697238922
# loss sur train dans epoch 91 :  0.42670661211013794
# loss sur train dans epoch 92 :  0.42520231008529663
# loss sur train dans epoch 93 :  0.42373546957969666
# loss sur train dans epoch 94 :  0.4223048686981201
# loss sur train dans epoch 95 :  0.4209079146385193
# loss sur train dans epoch 96 :  0.41956043243408203
# loss sur train dans epoch 97 :  0.41824522614479065
# loss sur train dans epoch 98 :  0.4169614315032959
# loss sur train dans epoch 99 :  0.41570812463760376

# %% [markdown]
# <center>
# 	<h2 style="color:#e56b6f">
# 		<b>
# 			2.5 Application à MNIST
# 		</b>
# 	</h2>
# </center>

# %%
# Load the MNIST dataset
from tensorflow.keras.datasets import mnist

# (train_images, train_labels) : Ensemble d'entraînement
# (test_images, test_labels) : Ensemble de test
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# Aplatir les images du jeu de données en vecteurs
test_images = test_images.reshape((test_images.shape[0],-1))
train_images = train_images.reshape((train_images.shape[0], -1))

# %%
N_epoch = 100 #nombre des epoch
batch = 256 # taille du batch
N = train_images.shape[0] # taille des donnees
eta =  0.01 #  learning rate
# le nombre de classes (0 --> 9)
nombre_de_classes = np.unique(test_labels).shape[0] 
# Convertir les arrays NumPy en tensors PyTorch
train_images = torch.tensor(train_images, dtype=torch.float32)
train_labels = torch.tensor(train_labels, dtype=torch.int64)
test_images = torch.tensor(test_images, dtype=torch.float32)
test_labels = torch.tensor(test_labels, dtype=torch.int64)

# %%
# dictionnaire pour stocker la perte du modèle pour chaque époque (train)
loss_history = []
# dictionnaire pour stocker la perte du modèle pour chaque époque (test-validation)
loss_validation_history = []

#initialiser les paramètres du modèle 
model_auto, loss_auto, optim_auto = init_model_auto(train_images.shape[1], 5, nombre_de_classes, eta)
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0 
    loss_glob , loss_val = 0 , 0 #Réinitialiser la perte  du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = train_images[j:i * batch, :]
        Y_epoch = train_labels[j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los 
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.     
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données 
        X_epoch = train_images[ j : N, :]
        Y_epoch = train_labels[j:N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        Y_hat = model_auto(X_epoch)
        # Remettre à zéro les gradients accumulés pour éviter l'accumulation d'informations de gradient d'une itération à l'autre.
        optim_auto.zero_grad()
        # calculer la perte pour le mini-batch actuel
        los = loss_auto(Y_hat, Y_epoch)
        # Rétropropagation et mise à jour des paramètres avec la descente de gradient stochastique
        los.backward()
        optim_auto.step()
        j = i * batch
        # Accumuler la perte pour le mini-batch actuel
        loss_glob += los
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss_glob /=(N // batch) 
    loss_val = loss_auto(model_auto(test_images), test_labels)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoche {epoch} est : ", loss_glob.item())
    #Afficher la perte et la précision calculées sur l'ensemble de Validation pour chaque époque.
    print(f"loss sur validation  dans epoche {epoch} est : ", loss_val.item())
    loss_history.append(loss_glob.item())
    loss_validation_history.append(loss_val.item())
# Out:
# loss sur train dans epoche 0 est :  2.019523859024048
# loss sur validation  dans epoche 0 est :  1.9366722106933594
# loss sur train dans epoche 1 est :  1.9245446920394897
# loss sur validation  dans epoche 1 est :  1.8486212491989136
# loss sur train dans epoche 2 est :  1.8572849035263062
# loss sur validation  dans epoche 2 est :  1.8471523523330688
# loss sur train dans epoche 3 est :  1.8478564023971558
# loss sur validation  dans epoche 3 est :  1.8349183797836304
# loss sur train dans epoche 4 est :  1.8421660661697388
# loss sur validation  dans epoche 4 est :  1.8336066007614136
# loss sur train dans epoche 5 est :  1.8394633531570435
# loss sur validation  dans epoche 5 est :  1.8261818885803223
# loss sur train dans epoche 6 est :  1.8365370035171509
# loss sur validation  dans epoche 6 est :  1.8309322595596313
# loss sur train dans epoche 7 est :  1.8332128524780273
# loss sur validation  dans epoche 7 est :  1.824402928352356
# loss sur train dans epoche 8 est :  1.814350962638855
# loss sur validation  dans epoche 8 est :  1.7799583673477173
# loss sur train dans epoche 9 est :  1.778531789779663
# loss sur validation  dans epoche 9 est :  1.77201247215271
# loss sur train dans epoche 10 est :  1.7721977233886719
# loss sur validation  dans epoche 10 est :  1.76399827003479
# loss sur train dans epoche 11 est :  1.7675668001174927
# loss sur validation  dans epoche 11 est :  1.7599818706512451
# loss sur train dans epoche 12 est :  1.7638589143753052
# loss sur validation  dans epoche 12 est :  1.7545967102050781
# loss sur train dans epoche 13 est :  1.7609272003173828
# loss sur validation  dans epoche 13 est :  1.7514748573303223
# loss sur train dans epoche 14 est :  1.7586543560028076
# loss sur validation  dans epoche 14 est :  1.751672625541687
# loss sur train dans epoche 15 est :  1.7559038400650024
# loss sur validation  dans epoche 15 est :  1.7536861896514893
# loss sur train dans epoche 16 est :  1.7541297674179077
# loss sur validation  dans epoche 16 est :  1.74473237991333
# loss sur train dans epoche 17 est :  1.752624273300171
# loss sur validation  dans epoche 17 est :  1.7478529214859009
# loss sur train dans epoche 18 est :  1.7508869171142578
# loss sur validation  dans epoche 18 est :  1.743212103843689
# loss sur train dans epoche 19 est :  1.7491954565048218
# loss sur validation  dans epoche 19 est :  1.7445833683013916
# loss sur train dans epoche 20 est :  1.7473771572113037
# loss sur validation  dans epoche 20 est :  1.740588665008545
# loss sur train dans epoche 21 est :  1.7454754114151
# loss sur validation  dans epoche 21 est :  1.7425105571746826
# loss sur train dans epoche 22 est :  1.7430707216262817
# loss sur validation  dans epoche 22 est :  1.7384085655212402
# loss sur train dans epoche 23 est :  1.7422785758972168
# loss sur validation  dans epoche 23 est :  1.7307724952697754
# loss sur train dans epoche 24 est :  1.7392396926879883
# loss sur validation  dans epoche 24 est :  1.7300019264221191
# loss sur train dans epoche 25 est :  1.738180160522461
# loss sur validation  dans epoche 25 est :  1.7311837673187256
# loss sur train dans epoche 26 est :  1.7370392084121704
# loss sur validation  dans epoche 26 est :  1.7266610860824585
# loss sur train dans epoche 27 est :  1.7359105348587036
# loss sur validation  dans epoche 27 est :  1.7305546998977661
# loss sur train dans epoche 28 est :  1.736611008644104
# loss sur validation  dans epoche 28 est :  1.7321468591690063
# loss sur train dans epoche 29 est :  1.7350585460662842
# loss sur validation  dans epoche 29 est :  1.7269818782806396
# loss sur train dans epoche 30 est :  1.7317367792129517
# loss sur validation  dans epoche 30 est :  1.7367007732391357
# loss sur train dans epoche 31 est :  1.7316282987594604
# loss sur validation  dans epoche 31 est :  1.7223964929580688
# loss sur train dans epoche 32 est :  1.7285740375518799
# loss sur validation  dans epoche 32 est :  1.7264695167541504
# loss sur train dans epoche 33 est :  1.7299517393112183
# loss sur validation  dans epoche 33 est :  1.7247816324234009
# loss sur train dans epoche 34 est :  1.7283461093902588
# loss sur validation  dans epoche 34 est :  1.7201108932495117
# loss sur train dans epoche 35 est :  1.727243423461914
# loss sur validation  dans epoche 35 est :  1.7169265747070312
# loss sur train dans epoche 36 est :  1.726294994354248
# loss sur validation  dans epoche 36 est :  1.7202064990997314
# loss sur train dans epoche 37 est :  1.7242892980575562
# loss sur validation  dans epoche 37 est :  1.7159031629562378
# loss sur train dans epoche 38 est :  1.7241334915161133
# loss sur validation  dans epoche 38 est :  1.714792013168335
# loss sur train dans epoche 39 est :  1.7224839925765991
# loss sur validation  dans epoche 39 est :  1.711315393447876
# loss sur train dans epoche 40 est :  1.7238314151763916
# loss sur validation  dans epoche 40 est :  1.7138724327087402
# loss sur train dans epoche 41 est :  1.7217212915420532
# loss sur validation  dans epoche 41 est :  1.7127397060394287
# loss sur train dans epoche 42 est :  1.7211077213287354
# loss sur validation  dans epoche 42 est :  1.7103722095489502
# loss sur train dans epoche 43 est :  1.7199864387512207
# loss sur validation  dans epoche 43 est :  1.7074490785598755
# loss sur train dans epoche 44 est :  1.7187080383300781
# loss sur validation  dans epoche 44 est :  1.71036696434021
# loss sur train dans epoche 45 est :  1.7188023328781128
# loss sur validation  dans epoche 45 est :  1.7128808498382568
# loss sur train dans epoche 46 est :  1.7177832126617432
# loss sur validation  dans epoche 46 est :  1.7104127407073975
# loss sur train dans epoche 47 est :  1.7164392471313477
# loss sur validation  dans epoche 47 est :  1.7061752080917358
# loss sur train dans epoche 48 est :  1.7165809869766235
# loss sur validation  dans epoche 48 est :  1.7094992399215698
# loss sur train dans epoche 49 est :  1.7156249284744263
# loss sur validation  dans epoche 49 est :  1.7081966400146484
# loss sur train dans epoche 50 est :  1.7150315046310425
# loss sur validation  dans epoche 50 est :  1.7098309993743896
# loss sur train dans epoche 51 est :  1.7136504650115967
# loss sur validation  dans epoche 51 est :  1.7034777402877808
# loss sur train dans epoche 52 est :  1.7129969596862793
# loss sur validation  dans epoche 52 est :  1.7095555067062378
# loss sur train dans epoche 53 est :  1.7120585441589355
# loss sur validation  dans epoche 53 est :  1.7176419496536255
# loss sur train dans epoche 54 est :  1.7113525867462158
# loss sur validation  dans epoche 54 est :  1.702202320098877
# loss sur train dans epoche 55 est :  1.7114934921264648
# loss sur validation  dans epoche 55 est :  1.7063902616500854
# loss sur train dans epoche 56 est :  1.7095850706100464
# loss sur validation  dans epoche 56 est :  1.7081996202468872
# loss sur train dans epoche 57 est :  1.709174633026123
# loss sur validation  dans epoche 57 est :  1.7043837308883667
# loss sur train dans epoche 58 est :  1.7080971002578735
# loss sur validation  dans epoche 58 est :  1.701880693435669
# loss sur train dans epoche 59 est :  1.706886887550354
# loss sur validation  dans epoche 59 est :  1.7023310661315918
# loss sur train dans epoche 60 est :  1.7072162628173828
# loss sur validation  dans epoche 60 est :  1.7039666175842285
# loss sur train dans epoche 61 est :  1.7047353982925415
# loss sur validation  dans epoche 61 est :  1.696953535079956
# loss sur train dans epoche 62 est :  1.70510733127594
# loss sur validation  dans epoche 62 est :  1.6993876695632935
# loss sur train dans epoche 63 est :  1.7038373947143555
# loss sur validation  dans epoche 63 est :  1.6994448900222778
# loss sur train dans epoche 64 est :  1.7041984796524048
# loss sur validation  dans epoche 64 est :  1.694367527961731
# loss sur train dans epoche 65 est :  1.7033209800720215
# loss sur validation  dans epoche 65 est :  1.6936901807785034
# loss sur train dans epoche 66 est :  1.701668620109558
# loss sur validation  dans epoche 66 est :  1.703317403793335
# loss sur train dans epoche 67 est :  1.7015007734298706
# loss sur validation  dans epoche 67 est :  1.6964679956436157
# loss sur train dans epoche 68 est :  1.7001564502716064
# loss sur validation  dans epoche 68 est :  1.694039225578308
# loss sur train dans epoche 69 est :  1.699599027633667
# loss sur validation  dans epoche 69 est :  1.6920193433761597
# loss sur train dans epoche 70 est :  1.6994799375534058
# loss sur validation  dans epoche 70 est :  1.6936384439468384
# loss sur train dans epoche 71 est :  1.6986875534057617
# loss sur validation  dans epoche 71 est :  1.6958494186401367
# loss sur train dans epoche 72 est :  1.698006510734558
# loss sur validation  dans epoche 72 est :  1.6937776803970337
# loss sur train dans epoche 73 est :  1.6973527669906616
# loss sur validation  dans epoche 73 est :  1.6917905807495117
# loss sur train dans epoche 74 est :  1.6964739561080933
# loss sur validation  dans epoche 74 est :  1.6857179403305054
# loss sur train dans epoche 75 est :  1.696027159690857
# loss sur validation  dans epoche 75 est :  1.6940040588378906
# loss sur train dans epoche 76 est :  1.6934221982955933
# loss sur validation  dans epoche 76 est :  1.687451720237732
# loss sur train dans epoche 77 est :  1.693555235862732
# loss sur validation  dans epoche 77 est :  1.6918495893478394
# loss sur train dans epoche 78 est :  1.6934760808944702
# loss sur validation  dans epoche 78 est :  1.6876049041748047
# loss sur train dans epoche 79 est :  1.6939855813980103
# loss sur validation  dans epoche 79 est :  1.6885480880737305
# loss sur train dans epoche 80 est :  1.6921778917312622
# loss sur validation  dans epoche 80 est :  1.6831403970718384
# loss sur train dans epoche 81 est :  1.6924582719802856
# loss sur validation  dans epoche 81 est :  1.6840893030166626
# loss sur train dans epoche 82 est :  1.69028639793396
# loss sur validation  dans epoche 82 est :  1.6955654621124268
# loss sur train dans epoche 83 est :  1.6927181482315063
# loss sur validation  dans epoche 83 est :  1.6841068267822266
# loss sur train dans epoche 84 est :  1.6912161111831665
# loss sur validation  dans epoche 84 est :  1.6904091835021973
# loss sur train dans epoche 85 est :  1.6889573335647583
# loss sur validation  dans epoche 85 est :  1.6826714277267456
# loss sur train dans epoche 86 est :  1.6868637800216675
# loss sur validation  dans epoche 86 est :  1.684944748878479
# loss sur train dans epoche 87 est :  1.688342571258545
# loss sur validation  dans epoche 87 est :  1.685137152671814
# loss sur train dans epoche 88 est :  1.6872824430465698
# loss sur validation  dans epoche 88 est :  1.6834542751312256
# loss sur train dans epoche 89 est :  1.6870837211608887
# loss sur validation  dans epoche 89 est :  1.6843763589859009
# loss sur train dans epoche 90 est :  1.6862709522247314
# loss sur validation  dans epoche 90 est :  1.6826859712600708
# loss sur train dans epoche 91 est :  1.6862446069717407
# loss sur validation  dans epoche 91 est :  1.6796832084655762
# loss sur train dans epoche 92 est :  1.6849992275238037
# loss sur validation  dans epoche 92 est :  1.680375337600708
# loss sur train dans epoche 93 est :  1.6853951215744019
# loss sur validation  dans epoche 93 est :  1.6775703430175781
# loss sur train dans epoche 94 est :  1.683467984199524
# loss sur validation  dans epoche 94 est :  1.680752158164978
# loss sur train dans epoche 95 est :  1.6834708452224731
# loss sur validation  dans epoche 95 est :  1.6765944957733154
# loss sur train dans epoche 96 est :  1.6819547414779663
# loss sur validation  dans epoche 96 est :  1.6797887086868286
# loss sur train dans epoche 97 est :  1.6813836097717285
# loss sur validation  dans epoche 97 est :  1.6752550601959229
# loss sur train dans epoche 98 est :  1.681117057800293
# loss sur validation  dans epoche 98 est :  1.67827308177948
# loss sur train dans epoche 99 est :  1.6804472208023071
# loss sur validation  dans epoche 99 est :  1.6781667470932007

# %%
# Tracer la courbe de la perte sur l'ensemble d'entraînement et de validation au fil des itérations
plt.plot(loss_history, label='Entraînement')
plt.plot(loss_validation_history, label='Validation')
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.legend()  # Ajouter une légende pour distinguer les courbes
plt.show()
