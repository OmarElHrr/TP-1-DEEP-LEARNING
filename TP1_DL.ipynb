# %% [markdown]
# <div style="text-align:center; border-bottom: 2px solid #FF7E7E;">
#     <h1><font color='#FF0000'>TP 1 : DEEP LEARNING</font></h1>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">réalisé par :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Assklou Meriem</li>
# <li>El Hariri Omar</li>
# <li>Louardi Ikram</li>
# <li>Mesrar Hamza </li>
# <li>Nabouzi Yasser</li>
# </ul>
# </div>
# <div style="padding-top:1px;padding-left:20px;">
# <h3 style="color:green;">Encadre par  :</h3>
# <div style="padding-left:80px;">
# <ul>
# <li>Prof. Khalfi Hamza</li>
# </ul>
# </div>
# </div>

# %% [markdown]
# <div style="padding-top:1px;padding-left:20px;">

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 1 – Formalisation mathematique</font></h2>
# </div>

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. A quoi servent les ensembles d’apprentissage, de validation et de test ?
#
# </font>

# %% [markdown]
# - Les ensembles d'apprentissage, de validation et de test sont utilisés respectivement pour entraîner un modèle, ajuster les hyperparamètres, et évaluer sa performance finale. Ils contribuent à éviter le surajustement et fournissent une évaluation impartiale sur des données non vues pendant l'entraînement.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 1. Quelle est l’influence du nombre $N$ d’exemples ?
#
# </font>

# %% [markdown]
# - Le nombre $ N $ d'exemples dans l'ensemble d'apprentissage peut influencer la performance du modèle. Un nombre insuffisant peut entraîner un surajustement, tandis qu'un grand nombre peut aider le modèle à généraliser mieux aux nouvelles données,

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 3. Pourquoi est-il important d’ajouter des fonctions d’activation entre des transformations lineaires ?
#
# </font>

# %% [markdown]
# - L'ajout de fonctions d'activation entre des transformations linéaires introduit une non-linéarité, permettant au modèle d'apprendre des motifs complexes et de représenter des relations non linéaires entre les caractéristiques.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 4. Quelles sont les tailles $ n_{x}, n_{h}, n_{y} $ sur la figure 1  ? En pratique, comment ces tailles sont-elles choisies ?
#
# </font>

# %% [markdown]
# <div style="text-align:center;">
# <img src="./model.png"  width="600">
# </div>

# %% [markdown]
# - $ n_{x} $ = 2 : Nombre d'entrées $ (n_{x}) $ Correspond au nombre de Variables dans les données .
# - $ n_{h} $ = 4 : Nombre de neurones cachés .
# - $ n_{y} $ : Nombre de sorties  (pour la classification ce nombre egale a nombre des classes dans les données)

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 5. Que représentent les vecteurs $ y $ et $ \hat{y} $ ? Quelle est la différence entre ces deux quantités ?
#
# </font>

# %% [markdown]
# - $ \hat{y} $ : est généralement la sortie du modèle après avoir appliqué la fonction d'activation softmax.un vecteur de probabilités normalisées. représente la probabilité estimée d'appartenir à la classe correspondante.
# - $ y $ : représente le vecteur des vraies étiquettes de classe associées aux exemples d'entraînement.
# - $ \hat{y} $ est la prédiction du modèle, tandis que $ y $ est la vérité de terrain.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 6. Pourquoi utiliser une fonction $ SoftMax $ en sortie ?
#
# </font>

# %% [markdown]
# - La fonction $ softmax $ est utilisée en sortie des réseaux de neurones pour convertir les scores en probabilités, facilitant l'interprétation des prédictions et permettant l'utilisation de la rétropropagation avec une fonction de perte comme l'entropie croisée pour l'entraînement

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 7. Écrire les équations mathématiques permettant d'effectuer la passe forward du réseau de neurones, produisant successivement $ \tilde{h}, \hat{h}, \tilde{y}, $ et $ \hat{y} $ à partir de $ x $.
#
# </font>

# %% [markdown]
# - Combinaison linéaire pour la couche cachée :
#
#     $$ \tilde{h} = W_{h} \times x + b_{h} $$
#
# - Activation de la couche cachée ( avec la fonction d'activation tanh ) :
#
#     $$ \hat{h} = tanh(\tilde{h}) $$
#
# - Combinaison linéaire pour la couche de sortie :
#
#   $$ \tilde{y} = W_{y} \times \hat{h} + b_{y} $$
#
# - Activation de la couche de sortie avec softmax :
#
#    $$ \hat{y} = softmax(\tilde{y}) $$

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 8. Pendant l’apprentissage, on cherche à minimiser la fonction de coût. Pour l’entropie croisée et l’erreur quadratique, comment les $ \hat{y}_i $ doivent-ils varier pour faire diminuer la loss ?
#
# </font>

# %% [markdown]
# - Pour minimiser l'entropie croisée, $ \hat{y}_i $  les doivent s'ajuster vers les valeurs réelles, augmentant lorsque $ y_i $
# est 1 et diminuant lorsque $ \hat{y} $  est 0. Pour l'erreur quadratique, l'ajustement vise à réduire la différence quadratique entre
# $ \hat{y}_i $  et $ y_i $

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 9. En quoi ces fonctions sont-elles plus adaptées aux problèmes de classification ou de régression ?
#
# </font>

# %% [markdown]
# - L'entropie croisée est adaptée à la classification en mesurant la divergence de probabilité, tandis que l'erreur quadratique est appropriée à la régression en évaluant les écarts entre prédictions et valeurs réelles.

# %% [markdown]
# <font color='#00C4F9'>
#
# #### 10. Quels semblent etre les avantages et inconvenients des diverses variantes de descente de gradient entre les versions classique, stochastique sur mini-batch et stochastique online ? Laquelle semble la plus raisonnable a utiliser dans le cas general ?
#
# </font>

# %% [markdown]
# | Method                                         | Avantages                                                      | Inconvénients                                                                                                                                                               |
# | ---------------------------------------------- | -------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Descente de Gradient Classique (Batch Gradient Descent) | - Convergence stable vers un minimum global en utilisant l'ensemble des données d'entraînement. | - Peut être coûteuse en termes de mémoire et de calcul, surtout pour de grands ensembles de données. - Les mises à jour ne sont effectuées qu'après avoir parcouru l'ensemble des données. |
# | Descente de Gradient Stochastique (Stochastic Gradient Descent - SGD) sur Mini-Batch | - Moins exigeante en termes de mémoire et de calcul, mise à jour des poids à chaque mini-batch, ce qui peut conduire à une convergence plus rapide. | - Moins stable que la descente de gradient classique en raison de l'aspect stochastique. - Les mises à jour fréquentes peuvent rendre la convergence plus bruitée, mais peuvent être utiles pour sortir de minima locaux. |
# | Descente de Gradient Stochastique Online     | - Mise à jour des poids après chaque exemple d'entraînement, adaptée aux flux de données en ligne. - Réagit rapidement aux changements de distribution. | - Plus sujette au bruit, peut converger vers des minima locaux. - Peut être moins stable que SGD sur mini-batch.     |

# %% [markdown]
# <div style="text-align:center;">
#     <h2><font color='#5DFA14'>Partie 2 – Implémentation </font></h2>
# </div>

# %%
import torch.nn as nn #  module neuronal
import torch.nn.functional as F #utililitaire de loss fonctionelle
import torch.optim as optim # algorithme d'optimisation
import torch.utils.data as data # dataset,  dataLoader
import torch
import matplotlib.pyplot as plt
import numpy as np
from sklearn.datasets import make_classification
from tqdm import tqdm

# %% [markdown]
# <div style="text-align:center;">
# <h3><font color='#00C4F9'> 2.1 Forward et backward manuels</font></h3>
# </div>

# %% [markdown]
# <h3><font color='#1E90FF'> A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones</font></h3>

# %%
def init_params(nx, nh, ny):
   # nx :  Le nombre de variables d'entrée.
   # nh: Le nombre de neurones dans la couche cachée.
   # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx))
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1))
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh))
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1))

    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3><font color='#1E90FF'> B. la fonction qui effectue la propagation avant</font></h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1'] #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                           # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2']# Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0) # Application de la fonction softmax

    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }

    return outputs

# %% [markdown]
# <h3><font color='#1E90FF'> C. la fonction de Perte et Taux de Précision</font></h3>

# %%
def loss_accuracy(Yhat, Y):

    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0)) #La perte est calculée en utilisant la cross-entropy

    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)

    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)

     #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3><font color='#1E90FF'> D. Propagation du Gradient pour la Mise à Jour des Paramètres</font></h3>

# %%
def backward(params, outputs,  Y):

    # Initialisation des gradients à zéro
    dW1 = torch.zeros_like(params['W1'])
    dB1 = torch.zeros_like(params['B1'])
    dW2 = torch.zeros_like(params['W2'])
    dB2 = torch.zeros_like(params['B2'])

    # Calcul du gradient de la couche de sortie
    dZ2 = outputs['Yhat'] - Y
    dW2 += torch.mm(dZ2, outputs['A1'].t()) / Y.shape[1]
    dB2 += torch.sum(dZ2, dim=1, keepdim=True) / Y.shape[1]

    # Calcul du gradient de la couche cachée
    dZ1 = torch.mm(params['W2'].t(), dZ2) * (1 - torch.tanh(outputs['Z1'])**2)
    dW1 += torch.mm(dZ1, outputs['X'].t()) / Y.shape[1]
    dB1 += torch.sum(dZ1, dim=1, keepdim=True) / Y.shape[1]

    gradients = {
        'dW1': dW1,
        'dB1': dB1,
        'dW2': dW2,
        'dB2': dB2
    }

    return gradients

# %% [markdown]
# <h3><font color='#1E90FF'> E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres</font></h3>

# %%
def sgd(params, grads, eta):
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            params[par] = params[par] - eta * grads['d' + par] # Mise à Jour des Paramètres

    return params

# %% [markdown]
# <h3><font color='#1E90FF'> F. Application</font></h3>

# %%
N_epoch = 200 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)
#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()
# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )

        j = i * batch
    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta)
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc = acc*100 / (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc)
    loss_history.append(loss)

    # affichage du frontière de décision pour chaque 20 epoch
    if epoch % 20 == 0:
        # Générer une grille d'échantillonnage pour l'espace de caractéristiques
        x_min, x_max = X[0, :].min() - 1, X[0, :].max() + 1
        y_min, y_max = X[1, :].min() - 1, X[1, :].max() + 1
        xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.1),
                     np.arange(y_min, y_max, 0.1))

        # Préparer les données pour les prédictions sur la grille
        grid_data = torch.tensor(np.c_[xx.ravel(), yy.ravel()], dtype=torch.float32).t()
        grid_cach = forward(params, grid_data)
        Z = torch.argmax(grid_cach['Yhat'], dim=0)
        Z = Z.reshape(xx.shape)

        # Affichage de la frontière de décision et des points de données
        plt.contourf(xx, yy, Z, alpha=0.3)
        plt.scatter(X[0, :], X[1, :], c=Y_tensor.numpy(), edgecolors='k', marker='o')
        plt.xlabel('X 1')
        plt.ylabel('X 2')
        plt.title('Frontière de Décision du Modèle')
        plt.show()
#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.6739436388015747
# la precision sur train dans epoch 0 est:  50.0
# loss sur train dans epoch 1 est:  0.6333677172660828
# la precision sur train dans epoch 1 est:  54.0
# loss sur train dans epoch 2 est:  0.5973172187805176
# la precision sur train dans epoch 2 est:  70.99999999999999
# loss sur train dans epoch 3 est:  0.5650933980941772
# la precision sur train dans epoch 3 est:  77.0
# loss sur train dans epoch 4 est:  0.5360883474349976
# la precision sur train dans epoch 4 est:  83.00000000000001
# loss sur train dans epoch 5 est:  0.5097869634628296
# la precision sur train dans epoch 5 est:  88.00000000000001
# loss sur train dans epoch 6 est:  0.4857620298862457
# la precision sur train dans epoch 6 est:  92.00000000000001
# loss sur train dans epoch 7 est:  0.4636668264865875
# la precision sur train dans epoch 7 est:  95.0
# loss sur train dans epoch 8 est:  0.443223237991333
# la precision sur train dans epoch 8 est:  95.0
# loss sur train dans epoch 9 est:  0.42421039938926697
# la precision sur train dans epoch 9 est:  96.0
# loss sur train dans epoch 10 est:  0.40645307302474976
# la precision sur train dans epoch 10 est:  95.0
# loss sur train dans epoch 11 est:  0.3898122310638428
# la precision sur train dans epoch 11 est:  96.0
# loss sur train dans epoch 12 est:  0.3741764426231384
# la precision sur train dans epoch 12 est:  96.99999999999999
# loss sur train dans epoch 13 est:  0.35945552587509155
# la precision sur train dans epoch 13 est:  96.99999999999999
# loss sur train dans epoch 14 est:  0.3455753028392792
# la precision sur train dans epoch 14 est:  96.99999999999999
# loss sur train dans epoch 15 est:  0.3324735164642334
# la precision sur train dans epoch 15 est:  96.99999999999999
# loss sur train dans epoch 16 est:  0.3200969099998474
# la precision sur train dans epoch 16 est:  98.00000000000001
# loss sur train dans epoch 17 est:  0.30839890241622925
# la precision sur train dans epoch 17 est:  98.00000000000001
# loss sur train dans epoch 18 est:  0.2973378598690033
# la precision sur train dans epoch 18 est:  98.00000000000001
# loss sur train dans epoch 19 est:  0.2868761122226715
# la precision sur train dans epoch 19 est:  98.00000000000001
# loss sur train dans epoch 20 est:  0.27697888016700745
# la precision sur train dans epoch 20 est:  98.00000000000001
# loss sur train dans epoch 21 est:  0.2676137387752533
# la precision sur train dans epoch 21 est:  98.00000000000001
# loss sur train dans epoch 22 est:  0.25875046849250793
# la precision sur train dans epoch 22 est:  98.00000000000001
# loss sur train dans epoch 23 est:  0.2503602206707001
# la precision sur train dans epoch 23 est:  98.00000000000001
# loss sur train dans epoch 24 est:  0.2424159049987793
# la precision sur train dans epoch 24 est:  98.00000000000001
# loss sur train dans epoch 25 est:  0.23489172756671906
# la precision sur train dans epoch 25 est:  98.00000000000001
# loss sur train dans epoch 26 est:  0.22776322066783905
# la precision sur train dans epoch 26 est:  98.00000000000001
# loss sur train dans epoch 27 est:  0.22100718319416046
# la precision sur train dans epoch 27 est:  98.00000000000001
# loss sur train dans epoch 28 est:  0.21460160613059998
# la precision sur train dans epoch 28 est:  98.00000000000001
# loss sur train dans epoch 29 est:  0.20852568745613098
# la precision sur train dans epoch 29 est:  98.00000000000001
# loss sur train dans epoch 30 est:  0.2027597427368164
# la precision sur train dans epoch 30 est:  98.00000000000001
# loss sur train dans epoch 31 est:  0.19728517532348633
# la precision sur train dans epoch 31 est:  99.0
# loss sur train dans epoch 32 est:  0.19208446145057678
# la precision sur train dans epoch 32 est:  99.0
# loss sur train dans epoch 33 est:  0.18714112043380737
# la precision sur train dans epoch 33 est:  99.0
# loss sur train dans epoch 34 est:  0.1824396699666977
# la precision sur train dans epoch 34 est:  99.0
# loss sur train dans epoch 35 est:  0.17796552181243896
# la precision sur train dans epoch 35 est:  99.0
# loss sur train dans epoch 36 est:  0.1737050861120224
# la precision sur train dans epoch 36 est:  99.0
# loss sur train dans epoch 37 est:  0.1696455478668213
# la precision sur train dans epoch 37 est:  99.0
# loss sur train dans epoch 38 est:  0.16577492654323578
# la precision sur train dans epoch 38 est:  99.0
# loss sur train dans epoch 39 est:  0.16208204627037048
# la precision sur train dans epoch 39 est:  99.0
# loss sur train dans epoch 40 est:  0.15855641663074493
# la precision sur train dans epoch 40 est:  99.0
# loss sur train dans epoch 41 est:  0.15518824756145477
# la precision sur train dans epoch 41 est:  99.0
# loss sur train dans epoch 42 est:  0.15196837484836578
# la precision sur train dans epoch 42 est:  99.0
# loss sur train dans epoch 43 est:  0.1488882452249527
# la precision sur train dans epoch 43 est:  99.0
# loss sur train dans epoch 44 est:  0.14593982696533203
# la precision sur train dans epoch 44 est:  99.0
# loss sur train dans epoch 45 est:  0.14311569929122925
# la precision sur train dans epoch 45 est:  99.0
# loss sur train dans epoch 46 est:  0.14040882885456085
# la precision sur train dans epoch 46 est:  99.0
# loss sur train dans epoch 47 est:  0.1378127634525299
# la precision sur train dans epoch 47 est:  99.0
# loss sur train dans epoch 48 est:  0.13532133400440216
# la precision sur train dans epoch 48 est:  99.0
# loss sur train dans epoch 49 est:  0.13292884826660156
# la precision sur train dans epoch 49 est:  99.0
# loss sur train dans epoch 50 est:  0.13062997162342072
# la precision sur train dans epoch 50 est:  99.0
# loss sur train dans epoch 51 est:  0.12841972708702087
# la precision sur train dans epoch 51 est:  99.0
# loss sur train dans epoch 52 est:  0.1262933909893036
# la precision sur train dans epoch 52 est:  99.0
# loss sur train dans epoch 53 est:  0.12424663454294205
# la precision sur train dans epoch 53 est:  99.0
# loss sur train dans epoch 54 est:  0.12227531522512436
# la precision sur train dans epoch 54 est:  99.0
# loss sur train dans epoch 55 est:  0.12037558853626251
# la precision sur train dans epoch 55 est:  99.0
# loss sur train dans epoch 56 est:  0.1185438483953476
# la precision sur train dans epoch 56 est:  99.0
# loss sur train dans epoch 57 est:  0.1167767196893692
# la precision sur train dans epoch 57 est:  99.0
# loss sur train dans epoch 58 est:  0.11507099866867065
# la precision sur train dans epoch 58 est:  99.0
# loss sur train dans epoch 59 est:  0.11342372745275497
# la precision sur train dans epoch 59 est:  99.0
# loss sur train dans epoch 60 est:  0.11183208227157593
# la precision sur train dans epoch 60 est:  99.0
# loss sur train dans epoch 61 est:  0.11029341071844101
# la precision sur train dans epoch 61 est:  99.0
# loss sur train dans epoch 62 est:  0.10880520194768906
# la precision sur train dans epoch 62 est:  99.0
# loss sur train dans epoch 63 est:  0.1073651909828186
# la precision sur train dans epoch 63 est:  99.0
# loss sur train dans epoch 64 est:  0.1059710830450058
# la precision sur train dans epoch 64 est:  99.0
# loss sur train dans epoch 65 est:  0.10462085902690887
# la precision sur train dans epoch 65 est:  99.0
# loss sur train dans epoch 66 est:  0.10331251472234726
# la precision sur train dans epoch 66 est:  99.0
# loss sur train dans epoch 67 est:  0.10204422473907471
# la precision sur train dans epoch 67 est:  99.0
# loss sur train dans epoch 68 est:  0.10081420838832855
# la precision sur train dans epoch 68 est:  99.0
# loss sur train dans epoch 69 est:  0.09962085634469986
# la precision sur train dans epoch 69 est:  99.0
# loss sur train dans epoch 70 est:  0.09846256673336029
# la precision sur train dans epoch 70 est:  99.0
# loss sur train dans epoch 71 est:  0.09733785688877106
# la precision sur train dans epoch 71 est:  99.0
# loss sur train dans epoch 72 est:  0.09624535590410233
# la precision sur train dans epoch 72 est:  99.0
# loss sur train dans epoch 73 est:  0.09518371522426605
# la precision sur train dans epoch 73 est:  99.0
# loss sur train dans epoch 74 est:  0.09415166079998016
# la precision sur train dans epoch 74 est:  99.0
# loss sur train dans epoch 75 est:  0.09314803034067154
# la precision sur train dans epoch 75 est:  99.0
# loss sur train dans epoch 76 est:  0.09217169135808945
# la precision sur train dans epoch 76 est:  99.0
# loss sur train dans epoch 77 est:  0.09122155606746674
# la precision sur train dans epoch 77 est:  99.0
# loss sur train dans epoch 78 est:  0.09029658883810043
# la precision sur train dans epoch 78 est:  99.0
# loss sur train dans epoch 79 est:  0.08939585089683533
# la precision sur train dans epoch 79 est:  99.0
# loss sur train dans epoch 80 est:  0.0885184109210968
# la precision sur train dans epoch 80 est:  99.0
# loss sur train dans epoch 81 est:  0.08766336739063263
# la precision sur train dans epoch 81 est:  99.0
# loss sur train dans epoch 82 est:  0.08682991564273834
# la precision sur train dans epoch 82 est:  99.0
# loss sur train dans epoch 83 est:  0.08601724356412888
# la precision sur train dans epoch 83 est:  99.0
# loss sur train dans epoch 84 est:  0.08522459864616394
# la precision sur train dans epoch 84 est:  99.0
# loss sur train dans epoch 85 est:  0.08445127308368683
# la precision sur train dans epoch 85 est:  99.0
# loss sur train dans epoch 86 est:  0.08369654417037964
# la precision sur train dans epoch 86 est:  99.0
# loss sur train dans epoch 87 est:  0.08295977115631104
# la precision sur train dans epoch 87 est:  99.0
# loss sur train dans epoch 88 est:  0.08224032819271088
# la precision sur train dans epoch 88 est:  99.0
# loss sur train dans epoch 89 est:  0.08153761923313141
# la precision sur train dans epoch 89 est:  99.0
# loss sur train dans epoch 90 est:  0.08085108548402786
# la precision sur train dans epoch 90 est:  99.0
# loss sur train dans epoch 91 est:  0.08018013089895248
# la precision sur train dans epoch 91 est:  99.0
# loss sur train dans epoch 92 est:  0.07952429354190826
# la precision sur train dans epoch 92 est:  99.0
# loss sur train dans epoch 93 est:  0.07888301461935043
# la precision sur train dans epoch 93 est:  99.0
# loss sur train dans epoch 94 est:  0.07825585454702377
# la precision sur train dans epoch 94 est:  99.0
# loss sur train dans epoch 95 est:  0.07764235138893127
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.07704203575849533
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.0764545127749443
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.07587938755750656
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.07531625032424927
# la precision sur train dans epoch 99 est:  99.0
# loss sur train dans epoch 100 est:  0.07476474344730377
# la precision sur train dans epoch 100 est:  99.0
# loss sur train dans epoch 101 est:  0.07422448694705963
# la precision sur train dans epoch 101 est:  99.0
# loss sur train dans epoch 102 est:  0.07369516044855118
# la precision sur train dans epoch 102 est:  99.0
# loss sur train dans epoch 103 est:  0.07317644357681274
# la precision sur train dans epoch 103 est:  99.0
# loss sur train dans epoch 104 est:  0.07266800105571747
# la precision sur train dans epoch 104 est:  99.0
# loss sur train dans epoch 105 est:  0.07216951996088028
# la precision sur train dans epoch 105 est:  99.0
# loss sur train dans epoch 106 est:  0.07168072462081909
# la precision sur train dans epoch 106 est:  99.0
# loss sur train dans epoch 107 est:  0.07120133936405182
# la precision sur train dans epoch 107 est:  99.0
# loss sur train dans epoch 108 est:  0.07073108851909637
# la precision sur train dans epoch 108 est:  99.0
# loss sur train dans epoch 109 est:  0.07026971876621246
# la precision sur train dans epoch 109 est:  99.0
# loss sur train dans epoch 110 est:  0.0698169618844986
# la precision sur train dans epoch 110 est:  99.0
# loss sur train dans epoch 111 est:  0.06937259435653687
# la precision sur train dans epoch 111 est:  99.0
# loss sur train dans epoch 112 est:  0.06893637031316757
# la precision sur train dans epoch 112 est:  99.0
# loss sur train dans epoch 113 est:  0.06850805878639221
# la precision sur train dans epoch 113 est:  99.0
# loss sur train dans epoch 114 est:  0.06808746606111526
# la precision sur train dans epoch 114 est:  99.0
# loss sur train dans epoch 115 est:  0.06767436861991882
# la precision sur train dans epoch 115 est:  99.0
# loss sur train dans epoch 116 est:  0.06726856529712677
# la precision sur train dans epoch 116 est:  99.0
# loss sur train dans epoch 117 est:  0.06686988472938538
# la precision sur train dans epoch 117 est:  99.0
# loss sur train dans epoch 118 est:  0.06647810339927673
# la precision sur train dans epoch 118 est:  99.0
# loss sur train dans epoch 119 est:  0.0660930797457695
# la precision sur train dans epoch 119 est:  99.0
# loss sur train dans epoch 120 est:  0.06571460515260696
# la precision sur train dans epoch 120 est:  99.0
# loss sur train dans epoch 121 est:  0.06534253060817719
# la precision sur train dans epoch 121 est:  99.0
# loss sur train dans epoch 122 est:  0.06497667729854584
# la precision sur train dans epoch 122 est:  99.0
# loss sur train dans epoch 123 est:  0.06461688876152039
# la precision sur train dans epoch 123 est:  99.0
# loss sur train dans epoch 124 est:  0.06426304578781128
# la precision sur train dans epoch 124 est:  99.0
# loss sur train dans epoch 125 est:  0.0639149621129036
# la precision sur train dans epoch 125 est:  99.0
# loss sur train dans epoch 126 est:  0.06357251107692719
# la precision sur train dans epoch 126 est:  99.0
# loss sur train dans epoch 127 est:  0.0632355585694313
# la precision sur train dans epoch 127 est:  99.0
# loss sur train dans epoch 128 est:  0.06290396302938461
# la precision sur train dans epoch 128 est:  99.0
# loss sur train dans epoch 129 est:  0.06257760524749756
# la precision sur train dans epoch 129 est:  99.0
# loss sur train dans epoch 130 est:  0.0622563473880291
# la precision sur train dans epoch 130 est:  99.0
# loss sur train dans epoch 131 est:  0.06194008141756058
# la precision sur train dans epoch 131 est:  99.0
# loss sur train dans epoch 132 est:  0.06162869185209274
# la precision sur train dans epoch 132 est:  99.0
# loss sur train dans epoch 133 est:  0.06132206320762634
# la precision sur train dans epoch 133 est:  99.0
# loss sur train dans epoch 134 est:  0.061020076274871826
# la precision sur train dans epoch 134 est:  99.0
# loss sur train dans epoch 135 est:  0.06072261184453964
# la precision sur train dans epoch 135 est:  99.0
# loss sur train dans epoch 136 est:  0.060429610311985016
# la precision sur train dans epoch 136 est:  99.0
# loss sur train dans epoch 137 est:  0.06014092639088631
# la precision sur train dans epoch 137 est:  99.0
# loss sur train dans epoch 138 est:  0.05985649302601814
# la precision sur train dans epoch 138 est:  99.0
# loss sur train dans epoch 139 est:  0.05957619100809097
# la precision sur train dans epoch 139 est:  99.0
# loss sur train dans epoch 140 est:  0.05929993465542793
# la precision sur train dans epoch 140 est:  99.0
# loss sur train dans epoch 141 est:  0.05902764946222305
# la precision sur train dans epoch 141 est:  99.0
# loss sur train dans epoch 142 est:  0.058759234845638275
# la precision sur train dans epoch 142 est:  99.0
# loss sur train dans epoch 143 est:  0.05849462002515793
# la precision sur train dans epoch 143 est:  99.0
# loss sur train dans epoch 144 est:  0.05823371559381485
# la precision sur train dans epoch 144 est:  99.0
# loss sur train dans epoch 145 est:  0.05797642469406128
# la precision sur train dans epoch 145 est:  99.0
# loss sur train dans epoch 146 est:  0.057722706347703934
# la precision sur train dans epoch 146 est:  99.0
# loss sur train dans epoch 147 est:  0.057472459971904755
# la precision sur train dans epoch 147 est:  99.0
# loss sur train dans epoch 148 est:  0.05722562596201897
# la precision sur train dans epoch 148 est:  99.0
# loss sur train dans epoch 149 est:  0.0569821298122406
# la precision sur train dans epoch 149 est:  99.0
# loss sur train dans epoch 150 est:  0.05674191191792488
# la precision sur train dans epoch 150 est:  99.0
# loss sur train dans epoch 151 est:  0.05650487542152405
# la precision sur train dans epoch 151 est:  99.0
# loss sur train dans epoch 152 est:  0.056270986795425415
# la precision sur train dans epoch 152 est:  99.0
# loss sur train dans epoch 153 est:  0.056040167808532715
# la precision sur train dans epoch 153 est:  99.0
# loss sur train dans epoch 154 est:  0.05581235885620117
# la precision sur train dans epoch 154 est:  99.0
# loss sur train dans epoch 155 est:  0.055587492883205414
# la precision sur train dans epoch 155 est:  99.0
# loss sur train dans epoch 156 est:  0.05536554008722305
# la precision sur train dans epoch 156 est:  99.0
# loss sur train dans epoch 157 est:  0.05514640361070633
# la precision sur train dans epoch 157 est:  99.0
# loss sur train dans epoch 158 est:  0.05493006855249405
# la precision sur train dans epoch 158 est:  99.0
# loss sur train dans epoch 159 est:  0.05471643805503845
# la precision sur train dans epoch 159 est:  99.0
# loss sur train dans epoch 160 est:  0.05450550466775894
# la precision sur train dans epoch 160 est:  99.0
# loss sur train dans epoch 161 est:  0.05429716780781746
# la precision sur train dans epoch 161 est:  99.0
# loss sur train dans epoch 162 est:  0.0540914349257946
# la precision sur train dans epoch 162 est:  99.0
# loss sur train dans epoch 163 est:  0.053888220340013504
# la precision sur train dans epoch 163 est:  99.0
# loss sur train dans epoch 164 est:  0.05368746444582939
# la precision sur train dans epoch 164 est:  99.0
# loss sur train dans epoch 165 est:  0.053489141166210175
# la precision sur train dans epoch 165 est:  99.0
# loss sur train dans epoch 166 est:  0.05329321697354317
# la precision sur train dans epoch 166 est:  99.0
# loss sur train dans epoch 167 est:  0.0530996210873127
# la precision sur train dans epoch 167 est:  99.0
# loss sur train dans epoch 168 est:  0.052908338606357574
# la precision sur train dans epoch 168 est:  99.0
# loss sur train dans epoch 169 est:  0.05271931365132332
# la precision sur train dans epoch 169 est:  99.0
# loss sur train dans epoch 170 est:  0.05253250151872635
# la precision sur train dans epoch 170 est:  99.0
# loss sur train dans epoch 171 est:  0.05234786123037338
# la precision sur train dans epoch 171 est:  99.0
# loss sur train dans epoch 172 est:  0.052165351808071136
# la precision sur train dans epoch 172 est:  99.0
# loss sur train dans epoch 173 est:  0.05198494717478752
# la precision sur train dans epoch 173 est:  99.0
# loss sur train dans epoch 174 est:  0.05180661007761955
# la precision sur train dans epoch 174 est:  99.0
# loss sur train dans epoch 175 est:  0.05163029953837395
# la precision sur train dans epoch 175 est:  99.0
# loss sur train dans epoch 176 est:  0.05145597457885742
# la precision sur train dans epoch 176 est:  99.0
# loss sur train dans epoch 177 est:  0.05128362029790878
# la precision sur train dans epoch 177 est:  99.0
# loss sur train dans epoch 178 est:  0.05111316964030266
# la precision sur train dans epoch 178 est:  99.0
# loss sur train dans epoch 179 est:  0.050944626331329346
# la precision sur train dans epoch 179 est:  99.0
# loss sur train dans epoch 180 est:  0.05077793076634407
# la precision sur train dans epoch 180 est:  99.0
# loss sur train dans epoch 181 est:  0.05061306804418564
# la precision sur train dans epoch 181 est:  99.0
# loss sur train dans epoch 182 est:  0.05044998973608017
# la precision sur train dans epoch 182 est:  99.0
# loss sur train dans epoch 183 est:  0.05028869956731796
# la precision sur train dans epoch 183 est:  99.0
# loss sur train dans epoch 184 est:  0.050129134207963943
# la precision sur train dans epoch 184 est:  99.0
# loss sur train dans epoch 185 est:  0.049971289932727814
# la precision sur train dans epoch 185 est:  99.0
# loss sur train dans epoch 186 est:  0.049815110862255096
# la precision sur train dans epoch 186 est:  99.0
# loss sur train dans epoch 187 est:  0.0496605820953846
# la precision sur train dans epoch 187 est:  99.0
# loss sur train dans epoch 188 est:  0.049507685005664825
# la precision sur train dans epoch 188 est:  99.0
# loss sur train dans epoch 189 est:  0.04935638979077339
# la precision sur train dans epoch 189 est:  99.0
# loss sur train dans epoch 190 est:  0.0492066815495491
# la precision sur train dans epoch 190 est:  99.0
# loss sur train dans epoch 191 est:  0.049058496952056885
# la precision sur train dans epoch 191 est:  99.0
# loss sur train dans epoch 192 est:  0.04891185089945793
# la precision sur train dans epoch 192 est:  99.0
# loss sur train dans epoch 193 est:  0.04876670241355896
# la precision sur train dans epoch 193 est:  99.0
# loss sur train dans epoch 194 est:  0.04862302169203758
# la precision sur train dans epoch 194 est:  99.0
# loss sur train dans epoch 195 est:  0.048480816185474396
# la precision sur train dans epoch 195 est:  99.0
# loss sur train dans epoch 196 est:  0.04834003001451492
# la precision sur train dans epoch 196 est:  99.0
# loss sur train dans epoch 197 est:  0.04820065200328827
# la precision sur train dans epoch 197 est:  99.0
# loss sur train dans epoch 198 est:  0.048062656074762344
# la precision sur train dans epoch 198 est:  99.0
# loss sur train dans epoch 199 est:  0.047926031053066254
# la precision sur train dans epoch 199 est:  99.0

# %% [markdown]
# <center>
# 	<h2 style="color:#e56b6f">
# 		<b>
# 			2.2 Simplification du backward avec <span style="color:#eaac8b"> torch.autograd</span>
# 		</b>
# 	</h2>
# </center>

# %% [markdown]
# <h3 style="color:#00a896;font-weight:bold;">
#
#  A. la fonction qui initialise les paramètres d'un modèle de réseau de neurones
#
# </h3>

# %%
def init_params(nx, nh, ny):
    # nx :  Le nombre de variables d'entrée.
    # nh: Le nombre de neurones dans la couche cachée.
    # ny: Le nombre de neurones dans la couche de sortie.
    moyenne = 0
    ecart_type = 0.3
    #activation du autograde pour la methode de toch
    W1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, nx),requires_grad=True)
    B1 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(nh, 1), requires_grad=True)
    W2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, nh), requires_grad=True)
    B2 = torch.normal(mean=torch.tensor(moyenne), std=torch.tensor(ecart_type), size=(ny, 1), requires_grad=True)
    params = {
        'W1' : W1,#Les poids de la première couche
        'B1' : B1,#Les biais de la première couche.
        'W2' : W2,#Les poids de la deuxième couche
        'B2' : B2,#Les biais de la deuxième couche.
    }
    return params #les paramètres du modèle

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;" >
# 	B. la fonction qui effectue la propagation avant
# </h3>

# %%
def forward(params, X) :
    Z1 = torch.mm(params['W1'], X) + params['B1']  #  Z1 = W1 * X + B1
    A1 = torch.tanh(Z1)                            # Application de la fonction tanh(Z1)
    Z2 = torch.mm(params['W2'], A1) + params['B2'] # Z2 = W2 * X + B2
    A2 = torch.exp(Z2) / torch.exp(Z2).sum(dim=0)  # Application de la fonction softmax
    outputs = {
        'X': X,
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'Yhat': A2,
    }
    return outputs

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	C. la fonction de Perte et Taux de Précision
# </h3>

# %%
def loss_accuracy(Yhat, Y):
    # Yhat la sortie prédite par le modèle
    # Y les valeurs réelles
    #La perte est calculée en utilisant la cross-entropy
    loss = -torch.mean(torch.sum(Y * torch.log(Yhat), dim=0))
    # Obtention des indices des classes réelles
    _, indsY = torch.max(Y, 0)
    # Obtention des indices des classes prédites
    _, indsYhat = torch.max(Yhat, 0)
    #La précision du modèle calcule le nombre d'individus correctement classés sur le nombre total d'individus.
    acc = torch.sum(indsY == indsYhat).item() / Y.shape[1]

    return loss, acc

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	D. Propagation du Gradient pour la Mise à Jour des Paramètres
# </h3>

# %%
def backward_auto(params, outputs, Y):
    # Réinitialiser les gradients des paramètres
    for par in params:
        if params[par].grad is not None:
            params[par].grad.zero_()
    # Calculer la perte
    loss = loss_accuracy(outputs['Yhat'], Y)[0]
    # Rétropropagation automatique
    loss.backward()
    # Extraire les gradients des paramètres après rétropropagation
    gradients = {
        'dW1': params['W1'].grad,
        'dB1': params['B1'].grad,
        'dW2': params['W2'].grad,
        'dB2': params['B2'].grad,
    }

    return gradients

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	E. Descente de Gradient Stochastique (SGD) pour la Mise à Jour des Paramètres
# </h3>

# %%
def sgd(params, grads, eta):
    # Assurez-vous d'utiliser torch.no_grad() pour éviter de calculer les gradients lors de la mise à jour des paramètres
    with torch.no_grad(): # Attention a bien utiliser torch.no_grad()
        for par in params:
            # Mise à jour des paramètres avec la descente de gradient
            params[par] = params[par] - eta * grads['d' + par]
            # Activer à nouveau le suivi des gradients pour les paramètres
            params[par].requires_grad_(True)
    return params

# %% [markdown]
# <h3 style="color:#00a896; font-weight:bold;">
# 	F. Application
# </h3>

# %%
N_epoch = 100 #nombre des époque
batch = 10 # taille du batch
N = 100 # taille des donnees
eta =  0.01 #  learning rate

#importation des données
X, Y= make_classification(n_samples=N, n_features=2, n_informative=2, n_redundant=0, random_state=42)
X = X.transpose()
# Convertir les arrays NumPy en tensors PyTorch
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.int64)

#effectuer le codage one-hot des étiquettes car en a deux nourons dans la couche de sortie
Y_one_hot = F.one_hot(Y_tensor)
X = X_tensor
Y = Y_one_hot.t()

# dictionnaire pour stocker la perte du modèle pour chaque époque
loss_history = []
#initialiser les paramètres du modèle
params = init_params(X.shape[0], 5, len(Y))
#Boucle pour l'entraînement du modèle par des époques.
for epoch in range(N_epoch):
    j = 0
    loss, acc = 0 , 0 #Réinitialiser la perte et la précision du modèle pour chaque époque.
    #Diviser les données sous forme de mini-batchs.
    #Boucle sur les mini-batchs.
    for i in range(1, N // batch + 1):
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:i * batch]
        Y_epoch = Y[:, j: i * batch]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
         # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], Y_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params,  cach, Y_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
        j = i * batch

    #Ce bloc de code gère le cas où la taille totale des données n'est pas un multiple de la taille du mini-batch.
    if (N % batch != 0 and i ==  N // batch ) :
        # Sélectionner un mini-batch à partir des données
        X_epoch = X[:, j:N]
        Y_epoch = Y[j : N]
        # Effectuer la propagation avant pour obtenir les prédictions du modèle
        cach = forward(params, X_epoch)
        # Accumuler la perte pour le mini-batch actuel
        loss =  loss + loss_accuracy(cach['Yhat'], X_epoch)[0]
        # Accumuler la précision pour le mini-batch actuel
        acc = acc + loss_accuracy(cach['Yhat'], Y_epoch)[1]
        # Effectuer la rétropropagation pour calculer les gradients
        grads = backward_auto(params, cach, X_epoch)
        # Mettre à jour les paramètres avec la descente de gradient
        params = sgd(params, grads, eta )
    # Normalisation de la perte moyenne sur l'ensemble des mini-batchs d'une époque
    loss = loss / (N / batch)
    acc  = acc * 100 /  (N / batch)
    #Afficher la perte et la précision calculées sur l'ensemble d'entraînement pour chaque époque.
    print(f"loss sur train dans epoch {epoch} est: ", loss.item())
    print(f"la precision sur train dans epoch {epoch} est: ", acc )
    loss_history.append(loss.item())

#graphique qui affiche l'évolution de la perte au cours des époques d'entraînement.
plt.plot(loss_history)
plt.xlabel('Itérations')
plt.ylabel('Perte')
plt.title('Évolution de la perte au fil des itérations')
plt.show()
# Out:
# loss sur train dans epoch 0 est:  0.7206880450248718
# la precision sur train dans epoch 0 est:  50.0
# loss sur train dans epoch 1 est:  0.6753783226013184
# la precision sur train dans epoch 1 est:  51.999999999999986
# loss sur train dans epoch 2 est:  0.6346083879470825
# la precision sur train dans epoch 2 est:  56.0
# loss sur train dans epoch 3 est:  0.5977874994277954
# la precision sur train dans epoch 3 est:  63.000000000000014
# loss sur train dans epoch 4 est:  0.5644077062606812
# la precision sur train dans epoch 4 est:  68.00000000000001
# loss sur train dans epoch 5 est:  0.534035325050354
# la precision sur train dans epoch 5 est:  78.00000000000001
# loss sur train dans epoch 6 est:  0.5063012838363647
# la precision sur train dans epoch 6 est:  81.00000000000001
# loss sur train dans epoch 7 est:  0.4808924198150635
# la precision sur train dans epoch 7 est:  85.0
# loss sur train dans epoch 8 est:  0.4575415551662445
# la precision sur train dans epoch 8 est:  88.00000000000001
# loss sur train dans epoch 9 est:  0.43602100014686584
# la precision sur train dans epoch 9 est:  91.00000000000001
# loss sur train dans epoch 10 est:  0.4161354601383209
# la precision sur train dans epoch 10 est:  93.00000000000001
# loss sur train dans epoch 11 est:  0.3977169096469879
# la precision sur train dans epoch 11 est:  93.00000000000001
# loss sur train dans epoch 12 est:  0.3806200921535492
# la precision sur train dans epoch 12 est:  94.0
# loss sur train dans epoch 13 est:  0.36471861600875854
# la precision sur train dans epoch 13 est:  94.0
# loss sur train dans epoch 14 est:  0.34990194439888
# la precision sur train dans epoch 14 est:  95.0
# loss sur train dans epoch 15 est:  0.336073100566864
# la precision sur train dans epoch 15 est:  95.0
# loss sur train dans epoch 16 est:  0.32314619421958923
# la precision sur train dans epoch 16 est:  96.00000000000001
# loss sur train dans epoch 17 est:  0.31104516983032227
# la precision sur train dans epoch 17 est:  96.00000000000001
# loss sur train dans epoch 18 est:  0.2997022271156311
# la precision sur train dans epoch 18 est:  96.00000000000001
# loss sur train dans epoch 19 est:  0.2890564501285553
# la precision sur train dans epoch 19 est:  96.00000000000001
# loss sur train dans epoch 20 est:  0.2790531814098358
# la precision sur train dans epoch 20 est:  96.0
# loss sur train dans epoch 21 est:  0.26964321732521057
# la precision sur train dans epoch 21 est:  96.0
# loss sur train dans epoch 22 est:  0.2607817053794861
# la precision sur train dans epoch 22 est:  96.0
# loss sur train dans epoch 23 est:  0.2524281442165375
# la precision sur train dans epoch 23 est:  96.0
# loss sur train dans epoch 24 est:  0.24454565346240997
# la precision sur train dans epoch 24 est:  96.0
# loss sur train dans epoch 25 est:  0.23710040748119354
# la precision sur train dans epoch 25 est:  96.0
# loss sur train dans epoch 26 est:  0.23006168007850647
# la precision sur train dans epoch 26 est:  96.0
# loss sur train dans epoch 27 est:  0.22340114414691925
# la precision sur train dans epoch 27 est:  96.0
# loss sur train dans epoch 28 est:  0.21709296107292175
# la precision sur train dans epoch 28 est:  96.0
# loss sur train dans epoch 29 est:  0.21111324429512024
# la precision sur train dans epoch 29 est:  96.0
# loss sur train dans epoch 30 est:  0.20544004440307617
# la precision sur train dans epoch 30 est:  96.0
# loss sur train dans epoch 31 est:  0.20005318522453308
# la precision sur train dans epoch 31 est:  96.0
# loss sur train dans epoch 32 est:  0.19493401050567627
# la precision sur train dans epoch 32 est:  96.99999999999999
# loss sur train dans epoch 33 est:  0.19006532430648804
# la precision sur train dans epoch 33 est:  96.99999999999999
# loss sur train dans epoch 34 est:  0.18543119728565216
# la precision sur train dans epoch 34 est:  96.99999999999999
# loss sur train dans epoch 35 est:  0.18101687729358673
# la precision sur train dans epoch 35 est:  96.99999999999999
# loss sur train dans epoch 36 est:  0.176808699965477
# la precision sur train dans epoch 36 est:  96.99999999999999
# loss sur train dans epoch 37 est:  0.1727941334247589
# la precision sur train dans epoch 37 est:  96.99999999999999
# loss sur train dans epoch 38 est:  0.16896134614944458
# la precision sur train dans epoch 38 est:  96.99999999999999
# loss sur train dans epoch 39 est:  0.16529950499534607
# la precision sur train dans epoch 39 est:  96.99999999999999
# loss sur train dans epoch 40 est:  0.16179850697517395
# la precision sur train dans epoch 40 est:  96.99999999999999
# loss sur train dans epoch 41 est:  0.15844890475273132
# la precision sur train dans epoch 41 est:  96.99999999999999
# loss sur train dans epoch 42 est:  0.1552419662475586
# la precision sur train dans epoch 42 est:  96.99999999999999
# loss sur train dans epoch 43 est:  0.1521696150302887
# la precision sur train dans epoch 43 est:  96.99999999999999
# loss sur train dans epoch 44 est:  0.1492241621017456
# la precision sur train dans epoch 44 est:  96.99999999999999
# loss sur train dans epoch 45 est:  0.14639857411384583
# la precision sur train dans epoch 45 est:  98.00000000000001
# loss sur train dans epoch 46 est:  0.14368632435798645
# la precision sur train dans epoch 46 est:  98.00000000000001
# loss sur train dans epoch 47 est:  0.14108118414878845
# la precision sur train dans epoch 47 est:  98.00000000000001
# loss sur train dans epoch 48 est:  0.138577401638031
# la precision sur train dans epoch 48 est:  98.00000000000001
# loss sur train dans epoch 49 est:  0.13616959750652313
# la precision sur train dans epoch 49 est:  98.00000000000001
# loss sur train dans epoch 50 est:  0.1338527500629425
# la precision sur train dans epoch 50 est:  98.00000000000001
# loss sur train dans epoch 51 est:  0.13162215054035187
# la precision sur train dans epoch 51 est:  98.00000000000001
# loss sur train dans epoch 52 est:  0.12947337329387665
# la precision sur train dans epoch 52 est:  98.00000000000001
# loss sur train dans epoch 53 est:  0.12740227580070496
# la precision sur train dans epoch 53 est:  98.00000000000001
# loss sur train dans epoch 54 est:  0.12540502846240997
# la precision sur train dans epoch 54 est:  98.00000000000001
# loss sur train dans epoch 55 est:  0.12347789853811264
# la precision sur train dans epoch 55 est:  98.00000000000001
# loss sur train dans epoch 56 est:  0.12161749601364136
# la precision sur train dans epoch 56 est:  99.0
# loss sur train dans epoch 57 est:  0.11982065439224243
# la precision sur train dans epoch 57 est:  99.0
# loss sur train dans epoch 58 est:  0.11808433383703232
# la precision sur train dans epoch 58 est:  99.0
# loss sur train dans epoch 59 est:  0.1164056807756424
# la precision sur train dans epoch 59 est:  99.0
# loss sur train dans epoch 60 est:  0.11478196084499359
# la precision sur train dans epoch 60 est:  99.0
# loss sur train dans epoch 61 est:  0.11321071535348892
# la precision sur train dans epoch 61 est:  99.0
# loss sur train dans epoch 62 est:  0.11168956756591797
# la precision sur train dans epoch 62 est:  99.0
# loss sur train dans epoch 63 est:  0.11021622270345688
# la precision sur train dans epoch 63 est:  99.0
# loss sur train dans epoch 64 est:  0.10878858715295792
# la precision sur train dans epoch 64 est:  99.0
# loss sur train dans epoch 65 est:  0.1074046641588211
# la precision sur train dans epoch 65 est:  99.0
# loss sur train dans epoch 66 est:  0.10606256872415543
# la precision sur train dans epoch 66 est:  99.0
# loss sur train dans epoch 67 est:  0.10476046800613403
# la precision sur train dans epoch 67 est:  99.0
# loss sur train dans epoch 68 est:  0.10349671542644501
# la precision sur train dans epoch 68 est:  99.0
# loss sur train dans epoch 69 est:  0.10226966440677643
# la precision sur train dans epoch 69 est:  99.0
# loss sur train dans epoch 70 est:  0.10107783228158951
# la precision sur train dans epoch 70 est:  99.0
# loss sur train dans epoch 71 est:  0.09991975128650665
# la precision sur train dans epoch 71 est:  99.0
# loss sur train dans epoch 72 est:  0.09879410266876221
# la precision sur train dans epoch 72 est:  99.0
# loss sur train dans epoch 73 est:  0.09769953787326813
# la precision sur train dans epoch 73 est:  99.0
# loss sur train dans epoch 74 est:  0.09663485735654831
# la precision sur train dans epoch 74 est:  99.0
# loss sur train dans epoch 75 est:  0.09559888392686844
# la precision sur train dans epoch 75 est:  99.0
# loss sur train dans epoch 76 est:  0.09459049999713898
# la precision sur train dans epoch 76 est:  99.0
# loss sur train dans epoch 77 est:  0.09360867738723755
# la precision sur train dans epoch 77 est:  99.0
# loss sur train dans epoch 78 est:  0.09265236556529999
# la precision sur train dans epoch 78 est:  99.0
# loss sur train dans epoch 79 est:  0.09172062575817108
# la precision sur train dans epoch 79 est:  99.0
# loss sur train dans epoch 80 est:  0.0908125787973404
# la precision sur train dans epoch 80 est:  99.0
# loss sur train dans epoch 81 est:  0.0899273082613945
# la precision sur train dans epoch 81 est:  99.0
# loss sur train dans epoch 82 est:  0.08906403183937073
# la precision sur train dans epoch 82 est:  99.0
# loss sur train dans epoch 83 est:  0.08822193741798401
# la precision sur train dans epoch 83 est:  99.0
# loss sur train dans epoch 84 est:  0.08740025758743286
# la precision sur train dans epoch 84 est:  99.0
# loss sur train dans epoch 85 est:  0.08659827709197998
# la precision sur train dans epoch 85 est:  99.0
# loss sur train dans epoch 86 est:  0.08581533282995224
# la precision sur train dans epoch 86 est:  99.0
# loss sur train dans epoch 87 est:  0.08505077660083771
# la precision sur train dans epoch 87 est:  99.0
# loss sur train dans epoch 88 est:  0.08430396020412445
# la precision sur train dans epoch 88 est:  99.0
# loss sur train dans epoch 89 est:  0.08357428014278412
# la precision sur train dans epoch 89 est:  99.0
# loss sur train dans epoch 90 est:  0.08286117017269135
# la precision sur train dans epoch 90 est:  99.0
# loss sur train dans epoch 91 est:  0.08216410130262375
# la precision sur train dans epoch 91 est:  99.0
# loss sur train dans epoch 92 est:  0.08148251473903656
# la precision sur train dans epoch 92 est:  99.0
# loss sur train dans epoch 93 est:  0.08081592619419098
# la precision sur train dans epoch 93 est:  99.0
# loss sur train dans epoch 94 est:  0.0801638662815094
# la precision sur train dans epoch 94 est:  99.0
# loss sur train dans epoch 95 est:  0.07952584326267242
# la precision sur train dans epoch 95 est:  99.0
# loss sur train dans epoch 96 est:  0.07890143245458603
# la precision sur train dans epoch 96 est:  99.0
# loss sur train dans epoch 97 est:  0.07829022407531738
# la precision sur train dans epoch 97 est:  99.0
# loss sur train dans epoch 98 est:  0.07769177854061127
# la precision sur train dans epoch 98 est:  99.0
# loss sur train dans epoch 99 est:  0.07710570842027664
# la precision sur train dans epoch 99 est:  99.0
